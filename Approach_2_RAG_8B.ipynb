# %% [markdown]
# # Pre-Requisites: Installation

# %% [markdown]
# ## Constants

# %%
USE_GROQ = True  # Set to False to use OpenAI
REQUEST_DELAY = 0.5

GROQ_MODEL = "llama3-8b-8192"

# %% [markdown]
# ## Install Libraries

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 5.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 7.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 4.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.6.0 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install openai
# !pip install groq
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.76.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Collecting groq
#   Downloading groq-0.24.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.0)
# Downloading groq-0.24.0-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.24.0

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 30.0 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %% [markdown]
# ## All Imports

# %%
# Core libraries
import os
import re
import json
from groq import Groq
import openai
import json
import ast
import warnings
import time

# Data handling
import pandas as pd
import numpy as np
from datasets import load_dataset
from collections import defaultdict


from sklearn.metrics import accuracy_score
import torch
from itertools import cycle
import faiss
from sentence_transformers import SentenceTransformer

from huggingface_hub import login
login("TOKEN")

# %% [markdown]
# ## Load Groq API Keys

# %%
# List of your GROQ API keys
GROQ_API_KEYS = [
     "API_KEY",

]

# Create a cycling iterator over the API keys
groq_clients = [Groq(api_key=key) for key in GROQ_API_KEYS]
groq_client_cycle = cycle(groq_clients)

# %% [markdown]
# ## Load Entire QA Dataset

# %%
dataset_name = "cardiffnlp/databench"
# semeval_train = load_dataset(dataset_name, name="semeval", split="train")
# semeval_dev = load_dataset(dataset_name, name="semeval", split="dev")

semeval_train = load_dataset(dataset_name, name="qa", split="train")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/43.6k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/65 [00:00<?, ?files/s]
# qa.parquet:   0%|          | 0.00/6.71k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.82k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.65k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.90k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.31k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.71k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.57k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.75k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.56k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.67k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.41k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.45k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.80k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.91k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.90k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.42k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.87k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.55k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.38k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.83k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.65k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.28k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.95k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.59k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.28k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.79k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.67k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/8.29k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.44k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.64k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.96k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.04k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.28k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.21k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.93k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.72k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.99k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.98k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.61k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.95k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.53k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.55k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.58k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.42k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.90k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.27k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.91k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.20k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/8.73k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.19k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.92k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.21k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.68k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.89k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.46k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.47k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/8.25k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.73k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.11k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/8.08k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.03k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/7.25k [00:00<?, ?B/s]
# qa.parquet:   0%|          | 0.00/6.40k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1308 [00:00<?, ? examples/s]

# %% [markdown]
# ## Updates 'column_used' function from QA dataset
#
# 1.  Converts value to String format by adding quotes
# 2.  Escapes inner quotes
# 3. If column name has <gx:[^>]+>: regex pattern, strips it

# %%
def safe_parse_list(raw):
    import ast
    import re

    if isinstance(raw, list):
        return raw

    if isinstance(raw, str):
        try:
            parsed = ast.literal_eval(raw)
            if isinstance(parsed, list):
                return parsed
        except:
            pass

        try:
            # Manually fix unquoted or single-quoted elements
            if raw.startswith("[") and raw.endswith("]"):
                inner = raw[1:-1].strip()
                if inner and not inner.startswith(("'", '"')):
                    # Case: [Weight, Height] -> Update to Str format by adding quotes around
                    parts = [p.strip() for p in inner.split(",")]
                    quoted = [f'"{p}"' for p in parts if p]
                    fixed = "[" + ", ".join(quoted) + "]"
                else:
                    # Case: ["What's your name?"] # Escape inner quotes
                    inner = raw[1:-1]
                    fixed_inner = re.sub(r'(["\'])', r'\\\1', inner)
                    fixed = f'["{fixed_inner}"]'
                parsed = ast.literal_eval(fixed)
                if isinstance(parsed, list):
                    return parsed
        except Exception as e:
            print(f"Failed to parse used_cols string: {raw} | Reason: {e}")

    return raw # should never happen

def clean_columns_used(col_list):
    parsed = safe_parse_list(col_list)

    if not isinstance(parsed, list):
        return [str(parsed)] if parsed is not None else []

    cleaned = []
    for col in parsed:
        col = str(col)
        col = re.sub(r"<gx:[^>]+>", "", col).strip()
        cleaned.append(col)
    return cleaned

# %%
# Update column names using Map as HuggingFace dataframes are immutable
def update_columns_used(example):
    example["columns_used"] = clean_columns_used(example.get("columns_used"))
    return example

# Apply the function to update each sample in the datasets
semeval_train = semeval_train.map(update_columns_used)
# Out:
# Map:   0%|          | 0/1308 [00:00<?, ? examples/s]

# %% [markdown]
# ## Unique Datasets

# %%
# unique_train_datasets = list(set(semeval_train.unique("dataset")))
unique_train_datasets = [
    "001_Forbes", "002_Titanic", "004_Taxi", "005_NYC",
    "006_London", "007_Fifa", "008_Tornados", "009_Central", "010_ECommerce",
    "011_SF", "012_Heart", "013_Roller", "015_Food",
    "016_Holiday", "017_Hacker", "018_Staff", "019_Aircraft",
    "021_Telco", "022_Airbnbs", "023_Climate", "024_Salary", "025_Data",
    "026_Predicting", "027_Supermarket", "028_Predict", "029_NYTimes", "030_Professionals",
    "031_Trustpilot", "032_Delicatessen", "033_Employee", "034_World",
    "036_US", "037_Ted", "038_Stroke", "039_Happy", "040_Speed",
    "041_Airline", "042_Predict", "043_Predict", "044_IMDb", "045_Predict",
    "046_120", "047_Bank", "048_Data",  "050_ING",
    "051_Pokemon", "052_Professional", "053_Patents", "055_German",
    "056_Emoji", "057_Spain", "058_US", "059_Second", "060_Bakery",
    "061_Disneyland", "062_Trump", "063_Influencers", "064_Clustering", "065_RFM"
]


print(f"Unique Train Datasets: {unique_train_datasets}")

# unique_dev_datasets = list(set(semeval_dev.unique("dataset")))
# print(f"Unique Dev Datasets: {unique_dev_datasets}")
# Out:
# Unique Train Datasets: ['001_Forbes', '002_Titanic', '004_Taxi', '005_NYC', '006_London', '007_Fifa', '008_Tornados', '009_Central', '010_ECommerce', '011_SF', '012_Heart', '013_Roller', '015_Food', '016_Holiday', '017_Hacker', '018_Staff', '019_Aircraft', '021_Telco', '022_Airbnbs', '023_Climate', '024_Salary', '025_Data', '026_Predicting', '027_Supermarket', '028_Predict', '029_NYTimes', '030_Professionals', '031_Trustpilot', '032_Delicatessen', '033_Employee', '034_World', '036_US', '037_Ted', '038_Stroke', '039_Happy', '040_Speed', '041_Airline', '042_Predict', '043_Predict', '044_IMDb', '045_Predict', '046_120', '047_Bank', '048_Data', '050_ING', '051_Pokemon', '052_Professional', '053_Patents', '055_German', '056_Emoji', '057_Spain', '058_US', '059_Second', '060_Bakery', '061_Disneyland', '062_Trump', '063_Influencers', '064_Clustering', '065_RFM']

# %% [markdown]
# ## Create Dictionary of {Dataset_Name: Dataset}

# %%
train_dataset_map = {}
# unique_train_datasets = list(set(semeval_train.unique("dataset")))

for dataset in unique_train_datasets:
    train_dataset_map[dataset] = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{dataset}/sample.parquet")

# %%
print(len(train_dataset_map))
# Out:
# 59

# %%
print(unique_train_datasets)
print(len(unique_train_datasets))
# Out:
# ['001_Forbes', '002_Titanic', '004_Taxi', '005_NYC', '006_London', '007_Fifa', '008_Tornados', '009_Central', '010_ECommerce', '011_SF', '012_Heart', '013_Roller', '015_Food', '016_Holiday', '017_Hacker', '018_Staff', '019_Aircraft', '021_Telco', '022_Airbnbs', '023_Climate', '024_Salary', '025_Data', '026_Predicting', '027_Supermarket', '028_Predict', '029_NYTimes', '030_Professionals', '031_Trustpilot', '032_Delicatessen', '033_Employee', '034_World', '036_US', '037_Ted', '038_Stroke', '039_Happy', '040_Speed', '041_Airline', '042_Predict', '043_Predict', '044_IMDb', '045_Predict', '046_120', '047_Bank', '048_Data', '050_ING', '051_Pokemon', '052_Professional', '053_Patents', '055_German', '056_Emoji', '057_Spain', '058_US', '059_Second', '060_Bakery', '061_Disneyland', '062_Trump', '063_Influencers', '064_Clustering', '065_RFM']
# 59

# %% [markdown]
# ## Clean column names from dataset dictionary

# %%
# Function to clean column names by removing <gx:...> part
def clean_column_name(col_name):
    # Use regex to remove the <gx:...> part
    cleaned = re.sub(r'<gx:[^>]+>', '', col_name)
    return cleaned

# %%
for ds in train_dataset_map.keys():
    df = train_dataset_map[ds]

    column_mapping = {col: clean_column_name(col) for col in df.columns}
    df = df.rename(columns=column_mapping)

    # Store the updated dataframe back in the hashmap
    train_dataset_map[ds] = df

# %% [markdown]
# ## Ignore -> Don't RUN

# %%
from collections import defaultdict
import ast

import ast
import re

def safe_parse_columns(raw):
    if isinstance(raw, list):
        return raw
    if not isinstance(raw, str):
        return []

    try:
        # Check if elements are unquoted and fix: [Name, Age] → ["Name", "Age"]
        if re.match(r"\[\s*[A-Za-z0-9_]+(,\s*[A-Za-z0-9_]+)*\s*\]", raw):
            raw = re.sub(r'([A-Za-z0-9_]+)', r'"\1"', raw)
        parsed = ast.literal_eval(raw)
        if isinstance(parsed, list):
            return parsed
    except Exception as e:
        print(f" Failed to parse used_cols string: {raw} | Reason: {e}")
    return []


# Step 1: Group questions by dataset
questions_by_dataset = defaultdict(list)

for sample in semeval_train:
    dataset = sample['dataset']
    question = sample['question']
    used_cols = sample['columns_used']
    questions_by_dataset[dataset].append({
        "question": question,
        "used_cols": used_cols
    })

# Step 2: Compare used columns with actual columns in the dataset
for ds, entries in questions_by_dataset.items():
    print(f"Dataset: {ds}")
    if ds not in train_dataset_map:
        print(f"\n⚠️ Dataset '{ds}' not found in train_dataset_map.")
        continue

    actual_cols = set(train_dataset_map[ds].columns.tolist())

    used_cols = set()
    for entry in entries:
        parsed_cols = safe_parse_columns(entry.get("used_cols"))
        used_cols.update(parsed_cols)


    missing = used_cols - actual_cols  # predicted but not present
    if missing:
        print(f"\n📘 Dataset: {ds}")
        print(f"\nActul Columns: {actual_cols}")
        print(f"\nUsed Columns Gold Labels: {used_cols}")

        print(f"⚠️  Columns used in sample but not found in dataset: {missing}")
# Out:
# Dataset: 001_Forbes
# Dataset: 002_Titanic
# Dataset: 003_Love
#
# ⚠️ Dataset '003_Love' not found in train_dataset_map.
# Dataset: 004_Taxi
# Dataset: 005_NYC
# Dataset: 006_London
# Dataset: 007_Fifa
# Dataset: 008_Tornados
# Dataset: 009_Central
# Dataset: 010_ECommerce
# Dataset: 011_SF
# Dataset: 012_Heart
# Dataset: 013_Roller
# Dataset: 014_Airbnb
#
# ⚠️ Dataset '014_Airbnb' not found in train_dataset_map.
# Dataset: 015_Food
# Dataset: 016_Holiday
# Dataset: 017_Hacker
# Dataset: 018_Staff
# Dataset: 019_Aircraft
# Dataset: 020_Real
#
# ⚠️ Dataset '020_Real' not found in train_dataset_map.
# Dataset: 021_Telco
# Dataset: 022_Airbnbs
# Dataset: 023_Climate
# Dataset: 024_Salary
# Dataset: 025_Data
# Dataset: 026_Predicting
# Dataset: 027_Supermarket
# Dataset: 028_Predict
# Dataset: 029_NYTimes
# Dataset: 030_Professionals
# Dataset: 031_Trustpilot
# Dataset: 032_Delicatessen
# Dataset: 033_Employee
#
# 📘 Dataset: 033_Employee
#
# Actul Columns: {'Left', 'Satisfaction Level', 'Average Monthly Hours', 'Years in the Company', 'salary', 'Work Accident', 'Number of Projects', 'Date Hired', 'Marital_Status', 'Department', 'Last Evaluation', 'Promoted in the last 5 years?'}
#
# Used Columns Gold Labels: {'Left', 'Average Monthly Hours', 'salary', 'Satisfaction Level', 'Years in the Company', 'Number of Projects', 'Work Accident', 'Education', 'Marital_Status', 'Department'}
# ⚠️  Columns used in sample but not found in dataset: {'Education'}
# Dataset: 034_World
# Dataset: 035_Billboard
#
# ⚠️ Dataset '035_Billboard' not found in train_dataset_map.
# Dataset: 036_US
# Dataset: 037_Ted
# Dataset: 038_Stroke
# Dataset: 039_Happy
# Dataset: 040_Speed
# Dataset: 041_Airline
#
# 📘 Dataset: 041_Airline
#
# Actul Columns: {'negativereason', 'airline_sentiment_confidence', 'airline', 'retweet_count', 'user_timezone', 'airline_sentiment', 'tweet_id'}
#
# Used Columns Gold Labels: {'negativereason', "'negativereason'", 'airline_sentiment_confidence', 'airline', 'retweet_count', 'user_timezone', 'airline_sentiment', 'tweet_id'}
# ⚠️  Columns used in sample but not found in dataset: {"'negativereason'"}
# Dataset: 042_Predict
# Dataset: 043_Predict
# Dataset: 044_IMDb
# Dataset: 045_Predict
# Dataset: 046_120
# Dataset: 047_Bank
# Dataset: 048_Data
# Dataset: 049_Boris
#
# ⚠️ Dataset '049_Boris' not found in train_dataset_map.
# Dataset: 050_ING
# Dataset: 051_Pokemon
# Dataset: 052_Professional
# Dataset: 053_Patents
#
# 📘 Dataset: 053_Patents
#
# Actul Columns: {'id', 'graphext_cluster', 'kind', 'organization', 'abstract', 'num_claims', 'type', 'date', 'target', 'title', 'lang'}
#
# Used Columns Gold Labels: {'id', 'num_claim', 'graphext_cluster', 'kind', 'organization', 'abstract', 'num_claims', 'type', 'date', 'title', 'lang'}
# ⚠️  Columns used in sample but not found in dataset: {'num_claim'}
# Dataset: 054_Joe
#
# ⚠️ Dataset '054_Joe' not found in train_dataset_map.
# Dataset: 055_German
# Dataset: 056_Emoji
# Dataset: 057_Spain
# Dataset: 058_US
# Dataset: 059_Second
# Dataset: 060_Bakery
# Dataset: 061_Disneyland
# Dataset: 062_Trump
# Dataset: 063_Influencers
# Dataset: 064_Clustering
# Dataset: 065_RFM

# %% [markdown]
# ## Serialize a Row to Key-Value Pair format

# %%
def serialize_to_kv_format(df, dropna=True):
    kv_serialized = []
    for _, row in df.iterrows():
        kv_pairs = []
        for col, val in row.items():
            if pd.isna(val) and dropna:
                continue
            if isinstance(val, str):
                val = f'"{val}"'
            kv_pairs.append(f"{col}: {val}")
        row_str = "{" + ", ".join(kv_pairs) + "}"
        kv_serialized.append(row_str)
    return kv_serialized

# %% [markdown]
# ## Build LLM Prompt

# %%
# def build_prompt(df: pd.DataFrame, question: str, explain: bool = False) -> str:
#     kv_serialized = serialize_to_kv_format(df)
#     response_format = (
#         'You must answer in a single JSON with two fields:\n'
#         '* "answer": your final answer based on the records.\n'
#         '* "columns_used": list of relevant columns.'
#     )
#     prompt_body = f"""You are an assistant tasked with answering the questions asked of a given dataset in JSON format.\n{response_format}\nRequirements:\n* Only respond with the JSON. Your answer must contain only the final value(s), not explanations or full objects.\nIn the following key-value formatted data:\n```kv\n{kv_serialized}\n```\nUSER: {question}\nASSISTANT:"""
#     return f"[INST]\n{prompt_body}\n[/INST]"

def build_prompt(df: pd.DataFrame, question: str) -> str:
    kv_serialized = serialize_to_kv_format(df)

    response_format = (
        'You must answer in a single JSON with two fields:\n'
        '* "answer": your final answer based on the records.\n'
        '* "columns_used": list of relevant columns.'
    )

    prompt_body = (
        "You are an assistant tasked with answering questions asked of a given dataset in JSON format.\n"
        f"{response_format}\n"
        "Requirements:\n"
        "* Only respond with the JSON. Do not include explanations or full objects.\n"
        "* Your answer must use valid Python data types:\n"
        "  - Use `True` or `False` (capitalized) for boolean values.\n"
        "  - Use numbers as Python `int` or `float` (e.g., `3`, `3.14`).\n"
        "  - Use double-quoted Python strings for categorical values (e.g., \"USA\").\n"
        "  - Use Python lists for answers involving multiple values:\n"
        "    - For list[category], return a list of strings.\n"
        "    - For list[number], return a list of ints or floats.\n"
        "    - Ensure all inner values match the correct type.\n\n"
        "In the following key-value formatted data:\n"
        "```kv\n"
        f"{kv_serialized}\n"
        "```\n"
        f"USER: {question}\n"
        "ASSISTANT:"
    )

    return f"[INST]\n{prompt_body}\n[/INST]"

# %% [markdown]
# ## Util functions for processing column info for dataset

# %%
def try_parse_list(val):
    """Try to parse a stringified list, else return original"""
    if isinstance(val, str) and val.startswith("[") and val.endswith("]"):
        try:
            parsed = ast.literal_eval(val)
            if isinstance(parsed, list):
                return parsed
        except:
            pass
    return val

def detect_url(val) -> bool:
    if not isinstance(val, str):
        return False
    val = val.strip()
    return val.startswith("http://") or val.startswith("https://") or val.startswith("www.")

def detect_number(val) -> bool:
    try:
        return isinstance(val, (int, float)) or float(str(val))
    except:
        return False

def detect_boolean(val) -> bool:
    if isinstance(val, bool): return True
    if isinstance(val, str): return val.strip().lower() in ["true", "false"]
    if isinstance(val, (int, float)): return val in [0, 1]
    return False

def detect_date(val) -> bool:
    try:
        # Suppress UserWarning about ambiguous day/month formats
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", UserWarning)
            parsed = pd.to_datetime(val, errors="raise", dayfirst=False)
        return isinstance(parsed, pd.Timestamp)
    except Exception:
        try:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore", UserWarning)
                parsed = pd.to_datetime(val, errors="raise", dayfirst=True)
            return isinstance(parsed, pd.Timestamp)
        except:
            return False

# %% [markdown]
# ## Identify column type
# For each column in the dataset to be inserted as metadata for building FAISS indexing over column data

# %%
def get_column_type(values, col_name="", sample_size=20) -> str:
    # Parse stringified lists
    parsed = [try_parse_list(v) for v in values if pd.notna(v) and v not in ["", "nan", "NaN"]]
    parsed = parsed[:sample_size]

    if not parsed:
        if "category" in col_name.lower() or "id" in col_name.lower():
            return "category"
        return "empty"

    first = parsed[0]

    # List-type
    if isinstance(first, list):
        inner_vals = [item for sublist in parsed if isinstance(sublist, list) for item in sublist]
        if not inner_vals:
            return "list[empty]"
        if all(detect_number(v) for v in inner_vals):
            return "list[number]"
        if all(detect_url(v) for v in inner_vals):
            return "list[url]"
        if all(detect_boolean(v) for v in inner_vals):
            return "list[boolean]"
        return "list[category]"

    # Scalar-type
    if all(detect_boolean(v) for v in parsed): return "boolean"
    if all(detect_number(v) for v in parsed): return "number"
    if all(detect_url(v) for v in parsed): return "url"
    if all(detect_date(v) for v in parsed): return "date"
    if len(set(map(str, parsed))) < sample_size / 2: return "category"
    if any(len(str(v)) > 30 for v in parsed): return "text"
    return "string"

def get_all_column_types(df: pd.DataFrame) -> dict:
    return {
        col: get_column_type(df[col].tolist(), col_name=col)
        for col in df.columns
    }

# %% [markdown]
# ## Initialize Embedder and FAISS indexing store

# %%
# Retrieval Component
from typing import Dict, List, Tuple
embedder = SentenceTransformer("BAAI/bge-small-en-v1.5")

# Store per-dataset FAISS index and metadata
dataset_faiss_store: Dict[str, Dict] = {}
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## Build index over single dataset

# %%
# Format column as descriptive string
def format_column_for_embedding(col_name: str, values: List[str], dtype: str) -> str:
    sample = ', '.join(map(str, values[:5]))
    return f"Column '{col_name}': {dtype} column with values like [{sample}]."

# Index one dataset from DataFrame
def index_single_dataset(dataset_name: str, df: pd.DataFrame):
    column_meta = []
    embed_strings = []

    for col in df.columns:
        sample_values = df[col].dropna().astype(str).tolist()[:2]
        col_type = get_column_type(df[col].tolist(), col_name=col)

        embed_text = format_column_for_embedding(col, sample_values, col_type)

        column_meta.append({
            "col_name": col,
            "type": col_type,
            "sample_values": sample_values,
            "embed_text": embed_text
        })
        embed_strings.append(embed_text)


    print(embed_strings)
    # Embed all columns
    column_embeddings = embedder.encode(embed_strings, convert_to_numpy=True)
    print(column_embeddings)
    faiss.normalize_L2(column_embeddings)

    # Create FAISS index
    dim = column_embeddings.shape[1]
    index = faiss.IndexFlatIP(dim)
    index.add(column_embeddings)

    dataset_faiss_store[dataset_name] = {
        "index": index,
        "columns": [m["col_name"] for m in column_meta],
        "metadata": column_meta
    }

# %% [markdown]
# ## Index all datasets

# %%
# Index all CSV datasets in a folder
def index_all_datasets():
    for ds in unique_train_datasets:
        df = train_dataset_map[ds]
        index_single_dataset(ds, df)

index_all_datasets()
# Out:
# ["Column 'selfMade': boolean column with values like [False, True].", "Column 'finalWorth': number column with values like [7800, 1700].", "Column 'city': string column with values like [Atlanta, Ningbo].", "Column 'title': category column with values like [Chairman , Athlete].", "Column 'gender': category column with values like [M, M].", "Column 'age': number column with values like [74.0, 86.0].", "Column 'rank': number column with values like [296, 1729].", "Column 'philanthropyScore': number column with values like [2.0, 1.0].", "Column 'category': category column with values like [Media & Entertainment, Manufacturing].", "Column 'source': string column with values like [media, automotive, precision machinery].", "Column 'country': string column with values like [United States, China]."]
# [[-0.04345224 -0.01267547  0.01537719 ...  0.07764073  0.0664267
#    0.01858214]
#  [-0.05050795 -0.04840382  0.00186775 ...  0.04405105  0.0453498
#    0.01833499]
#  [-0.03145483 -0.0380358   0.04470056 ...  0.02723679  0.00684388
#    0.03047204]
#  ...
#  [-0.00634264 -0.02361554  0.00393419 ... -0.01481153  0.06594469
#    0.02184697]
#  [-0.02162971 -0.01833648  0.00493854 ...  0.01519345  0.07430694
#    0.02197004]
#  [-0.02785256 -0.02915143  0.03344153 ...  0.017596    0.02389402
#   -0.01494388]]
# ["Column 'Age': number column with values like [69.0, 57.0].", "Column 'Siblings_Spouses Aboard': number column with values like [0, 0].", "Column 'Sex': category column with values like [male, male].", "Column 'Name': text column with values like [Mr. Samuel Beard Risien, Rev. Charles Leonard Kirkland].", "Column 'Pclass': number column with values like [3, 2].", "Column 'Fare': number column with values like [14.5, 12.35].", "Column 'Survived': boolean column with values like [False, False]."]
# [[-0.08063896 -0.04825872 -0.01185817 ...  0.02216374  0.05501248
#   -0.06288913]
#  [-0.02551368 -0.04047725 -0.00895538 ...  0.04803943  0.01603808
#   -0.01098678]
#  [-0.0042315   0.02170746  0.00642091 ...  0.00705776  0.0406572
#   -0.02100543]
#  ...
#  [-0.0557429  -0.05914524 -0.01988173 ...  0.03419642  0.06531659
#    0.02223978]
#  [-0.0321351  -0.07103402  0.00426868 ...  0.01235684  0.02800555
#   -0.0159375 ]
#  [-0.10270077 -0.0072001   0.01405487 ...  0.11048342  0.03269308
#   -0.01641662]]
# ["Column 'store_and_fwd_flag': category column with values like [Y, N].", "Column 'payment_type': number column with values like [1, 1].", "Column 'tpep_pickup_datetime': date column with values like [2023-02-01T16:42:37Z, 2023-02-01T02:59:27Z].", "Column 'fare_amount': number column with values like [12.8, 5.8].", "Column 'VendorID': number column with values like [1, 2].", "Column 'DOLocationID': number column with values like [48, 141].", "Column 'tolls_amount': boolean column with values like [0, 0].", "Column 'tip_amount': number column with values like [3.85, 1.51].", "Column 'PULocationID': number column with values like [100, 263].", "Column 'Airport_fee': boolean column with values like [0.0, 0.0].", "Column 'trip_distance': number column with values like [0.9, 0.79].", "Column 'RatecodeID': boolean column with values like [1, 1].", "Column 'total_amount': number column with values like [23.15, 12.31].", "Column 'passenger_count': number column with values like [1, 1]."]
# [[-0.04495318 -0.00864461  0.02358005 ...  0.04278764 -0.01709004
#    0.00490066]
#  [-0.04550594 -0.08029281 -0.00895057 ...  0.02619721  0.05851681
#   -0.0227339 ]
#  [-0.0953332  -0.03836497  0.09532035 ...  0.04594112 -0.01891594
#    0.00721356]
#  ...
#  [-0.06792305 -0.07724652 -0.00063331 ...  0.06095396  0.04363677
#   -0.04075938]
#  [-0.04718586 -0.10140301  0.00804579 ...  0.00518214  0.03030204
#   -0.04225368]
#  [-0.03092732 -0.08922956  0.06395805 ...  0.05407533  0.01424741
#   -0.00182569]]
# ["Column 'complaint_type': string column with values like [HEAT/HOT WATER, Illegal Parking].", "Column 'borough': category column with values like [MANHATTAN, QUEENS].", "Column 'hour': number column with values like [18, 21].", "Column 'month_name': string column with values like [March, February].", "Column 'weekday_name': category column with values like [Monday, Friday].", "Column 'agency': category column with values like [HPD, NYPD].", "Column 'unique_key': number column with values like [50082845, 49874401].", "Column 'descriptor': text column with values like [APARTMENT ONLY, Commercial Overnight Parking]."]
# [[-0.04289254 -0.00813776  0.04273143 ...  0.05168591  0.03117874
#    0.00363361]
#  [ 0.02195476 -0.05816264  0.06411236 ...  0.03866835 -0.00696039
#    0.00933519]
#  [-0.07970519 -0.0420857  -0.00728163 ...  0.01878891  0.02055966
#   -0.03823645]
#  ...
#  [-0.04366111 -0.01876276  0.03354988 ...  0.02231183  0.01244578
#    0.03033592]
#  [-0.07593618 -0.06839308 -0.01264022 ...  0.02361298  0.02093179
#   -0.01827706]
#  [ 0.00033752 -0.01188127  0.01835157 ...  0.03246199 -0.00350437
#    0.00770916]]
# ["Column 'reviews_per_month': number column with values like [0.01, 2.22].", "Column 'review_scores_communication': number column with values like [4.0, 4.4].", "Column 'host_verifications': category column with values like [[email, phone, work_email], [email, phone]].", "Column 'calculated_host_listings_count_entire_homes': number column with values like [0, 11].", "Column 'host_neighbourhood': string column with values like [Notting Hill, West Kensington].", "Column 'property_type': category column with values like [Private room in rental unit, Entire condo].", "Column 'host_identity_verified': category column with values like [t, t].", "Column 'bedrooms': number column with values like [1.0, 1.0].", "Column 'review_scores_location': number column with values like [4.0, 4.2].", "Column 'neighbourhood_cleansed': string column with values like [Islington, Hammersmith and Fulham].", "Column 'price': empty column with values like [].", "Column 'room_type': category column with values like [Private room, Entire home/apt]."]
# [[-0.05018892 -0.04770435  0.01738986 ...  0.04581613  0.03615282
#   -0.02098278]
#  [-0.05770715 -0.03392917  0.00181856 ...  0.06870722  0.02764828
#   -0.00222272]
#  [-0.02833256 -0.01786931 -0.00851977 ...  0.0781645   0.00914089
#   -0.00253656]
#  ...
#  [ 0.02380197 -0.0577325   0.07616882 ...  0.04401542 -0.00902877
#    0.03086641]
#  [-0.03592824 -0.04288985  0.01239211 ...  0.00253626 -0.01582212
#    0.02296972]
#  [ 0.00636825 -0.02119067  0.01599605 ...  0.06700917  0.00219929
#    0.00972533]]
# ["Column 'Joined': date column with values like [Jul 1, 2018, Sep 1, 2020].", "Column 'Overall': number column with values like [72, 66].", "Column 'Age': number column with values like [26, 20].", "Column 'Position': category column with values like [SUB, RDM].", "Column 'Wage_€': number column with values like [19000, 6000].", "Column 'Preferred Foot': category column with values like [Right, Right].", "Column 'Potential': number column with values like [72, 78].", "Column 'Agility': number column with values like [74.0, 90.0].", "Column 'Nationality': string column with values like [Ghana, Luxembourg].", "Column 'Height_ft': number column with values like [5.11, 5.9].", "Column 'Value_€': number column with values like [3300000, 1100000].", "Column 'Club': string column with values like [Hannover 96, 1. FSV Mainz 05]."]
# [[-0.0771194  -0.04285413  0.04541214 ...  0.00768414  0.01060005
#   -0.02182795]
#  [-0.04774447 -0.05712814 -0.0278624  ...  0.00819657  0.03738144
#    0.02475281]
#  [-0.03933923 -0.04712214  0.01847763 ...  0.04109333  0.03400651
#   -0.05508496]
#  ...
#  [-0.06110066 -0.05490562  0.03361272 ... -0.00756318  0.0057108
#    0.01381225]
#  [-0.074096   -0.05274793 -0.0299354  ...  0.00075205  0.07326669
#   -0.02401432]
#  [-0.01215316 -0.02271124  0.00438287 ...  0.01584859  0.03929488
#   -0.0072923 ]]
# ["Column 'date': date column with values like [1971-05-12, 2004-10-18].", "Column 'yr': number column with values like [1971, 2004].", "Column 'fat': boolean column with values like [0, 0].", "Column 'mag': number column with values like [1, 0].", "Column 'inj': number column with values like [0, 0].", "Column 'mo': number column with values like [5, 10].", "Column 'st': string column with values like [GA, AR].", "Column 'len': number column with values like [0.5, 2.0]."]
# [[-0.0950173  -0.04056566  0.03520853 ...  0.02062842  0.01356478
#   -0.00526545]
#  [-0.05219954 -0.04261237  0.01991781 ...  0.04648646  0.0202864
#   -0.01112278]
#  [-0.08194282 -0.03148427  0.00396977 ...  0.04797654  0.06471533
#    0.01382998]
#  ...
#  [-0.08215009 -0.01224474  0.02034672 ...  0.07519169  0.01082762
#   -0.00116954]
#  [-0.05075905 -0.03399249  0.00411841 ...  0.02804086  0.02069494
#    0.03199235]
#  [-0.08249897 -0.0733233  -0.00664022 ...  0.02577312  0.05470712
#    0.00433076]]
# ["Column 'TMIN': number column with values like [60.0, 18.0].", "Column 'PRCP': number column with values like [0.0, 0.0].", "Column 'DATE': date column with values like [1982-07-02, 1945-02-03].", "Column 'SNWD': number column with values like [0.0, 4.0].", "Column 'TMAX': number column with values like [80.0, 32.0]."]
# [[-0.06455754 -0.0634351   0.01747869 ...  0.03514072  0.00696162
#   -0.02182965]
#  [-0.09861992 -0.0468505  -0.01475724 ...  0.05887453  0.06114816
#   -0.00956643]
#  [-0.09925925 -0.0116752   0.02408968 ...  0.03320169  0.01274677
#   -0.01652922]
#  [-0.04776088 -0.06580306 -0.01835229 ...  0.01353951  0.02591719
#    0.02153024]
#  [-0.06210991 -0.04492775  0.00060834 ...  0.01920846  0.04872211
#    0.00315895]]
# ["Column 'Positive Feedback Count': number column with values like [19, 0].", "Column 'Clothing ID': number column with values like [1095, 903].", "Column 'Age': number column with values like [34, 57].", "Column 'Department Name': category column with values like [Dresses, Tops].", "Column 'Recommended IND': boolean column with values like [1, 1].", "Column 'Class Name': category column with values like [Dresses, Fine gauge].", "Column 'Division Name': category column with values like [General, General Petite].", "Column 'Rating': number column with values like [4, 4]."]
# [[-0.08345215 -0.04572678  0.0183285  ...  0.10449345  0.02646997
#   -0.00423729]
#  [-0.07487018 -0.01384525  0.00567183 ... -0.02137568  0.02815024
#   -0.03938252]
#  [-0.0723872  -0.0599774  -0.0192063  ...  0.02477453  0.06411128
#   -0.05257585]
#  ...
#  [-0.02739833 -0.02111587  0.04087691 ... -0.01147214  0.03478077
#   -0.00359569]
#  [-0.00208498 -0.02328664  0.04183725 ...  0.02929861  0.01941067
#    0.00566057]
#  [-0.04590909 -0.04552142 -0.00562482 ...  0.07346462  0.04955006
#   -0.01076941]]
# ["Column 'Longitude': number column with values like [-122.40647555268292, -122.3945869789376].", "Column 'Incident Category': text column with values like [Other Miscellaneous, Other Miscellaneous].", "Column 'Incident Number': number column with values like [190860198, 230082147].", "Column 'Latitude': number column with values like [37.79514446373132, 37.752426800122734].", "Column 'Incident Day of Week': category column with values like [Wednesday, Friday].", "Column 'Incident Description': text column with values like [Investigative Detention, Investigative Detention].", "Column 'Resolution': category column with values like [Open or Active, Open or Active].", "Column 'Police District': category column with values like [Central, Bayview].", "Column 'Incident Year': number column with values like [2019, 2023].", "Column 'Filed Online': boolean column with values like [True].", "Column 'Supervisor District': number column with values like [3.0, 10.0]."]
# [[-0.03307566 -0.08094406  0.0175706  ...  0.04399509 -0.00725153
#   -0.0132205 ]
#  [-0.02664495  0.00733543  0.0380351  ...  0.02980214  0.0191958
#    0.02920228]
#  [-0.07175528 -0.03169765  0.01670896 ...  0.04943863  0.01500902
#   -0.0178467 ]
#  ...
#  [-0.06140215 -0.02620977  0.04658721 ...  0.01591309 -0.01018094
#   -0.00813265]
#  [-0.07597541 -0.06805433  0.01870465 ...  0.07285855  0.07929499
#    0.02949159]
#  [-0.05184681 -0.07205258  0.02834017 ...  0.04279395  0.0335568
#    0.01095806]]
# ["Column 'Cholesterol': number column with values like [195, 518].", "Column 'Age': number column with values like [63, 53].", "Column 'RestingBP': number column with values like [140, 145].", "Column 'ST_Slope': category column with values like [Up, Flat].", "Column 'Sex': category column with values like [F, M].", "Column 'ChestPainType': category column with values like [ATA, NAP].", "Column 'RestingECG': category column with values like [Normal, Normal].", "Column 'MaxHR': number column with values like [179, 130].", "Column 'ExerciseAngina': category column with values like [N, N].", "Column 'HeartDisease': boolean column with values like [0, 1]."]
# [[-0.04251286 -0.02778578 -0.03573658 ...  0.02324049  0.0637895
#   -0.02694801]
#  [-0.08396083 -0.0497979   0.00048262 ...  0.03015267  0.05172664
#   -0.05323589]
#  [-0.08493827 -0.04444684 -0.04276263 ...  0.02925563  0.02130853
#   -0.01316926]
#  ...
#  [-0.07569482 -0.07524418 -0.02331694 ...  0.02700774  0.01793305
#    0.02294718]
#  [-0.05858394 -0.02525024  0.03362784 ...  0.04106256  0.01773554
#    0.01219114]
#  [-0.07714912 -0.04274049  0.03327427 ...  0.06311526  0.06824655
#    0.03522579]]
# ["Column 'Status': category column with values like [Operating, Operating].", "Column 'coaster_name': text column with values like [Surfrider, Zipper Dipper].", "Column 'Designer': category column with values like [Ing.-Büro Stengel GmbH, Charlie Paige].", "Column 'Manufacturer': string column with values like [Intamin, Intamin].", "Column 'height_ft': number column with values like [98.4, 78.7].", "Column 'Gforce_clean': number column with values like [3.5, 4.3].", "Column 'Type': string column with values like [Steel\xa0– Shuttle\xa0– Launched, Other].", "Column 'year_introduced': number column with values like [2007, 1934].", "Column 'speed_mph': number column with values like [46.6, 60.0].", "Column 'Inversions_clean': number column with values like [0, 0].", "Column 'Location': string column with values like [Wet'n'Wild Gold Coast, Blackpool Pleasure Beach].", "Column 'Opening date': text column with values like [September\xa02007, 1934]."]
# [[-0.02700153 -0.01458257  0.05964625 ...  0.06977982  0.08056642
#    0.00783614]
#  [-0.03848129  0.01317102  0.06721568 ...  0.04600212 -0.00849404
#    0.03635652]
#  [-0.02564678  0.01840094 -0.0044464  ...  0.02791214  0.06582701
#    0.0267583 ]
#  ...
#  [-0.08182848 -0.06443979  0.02253797 ...  0.06621736 -0.00266956
#   -0.00961418]
#  [ 0.02264413 -0.03559038  0.03191458 ...  0.08634111 -0.03161662
#    0.00275267]
#  [-0.05971704 -0.02688558  0.03562954 ...  0.03356683  0.05698855
#    0.00699211]]
# ["Column 'FOOD NAME': text column with values like [Alcoholic beverages, Colorado pinyon].", "Column 'SCIENTIFIC NAME': text column with values like [Pinus edulis, Octopus vulgaris].", "Column 'GROUP': category column with values like [Beverages, Nuts].", "Column 'SUB GROUP': string column with values like [Alcoholic beverages, Nuts]."]
# [[-0.00416257 -0.00628523  0.03698729 ...  0.03513466  0.0371353
#   -0.01527024]
#  [ 0.00496995  0.02288425  0.02073899 ... -0.04294339  0.07067459
#    0.02816511]
#  [ 0.00562315 -0.01210333  0.010872   ...  0.04368905  0.04629852
#    0.00346757]
#  [ 0.01038683 -0.03282833  0.00368615 ...  0.05044944  0.05518492
#   -0.01272089]]
# ["Column 'CustomerID': number column with values like [200144, 200079].", "Column 'ProdTaken': boolean column with values like [0, 0].", "Column 'Age': number column with values like [32.0, 46.0].", "Column 'TypeofContact': category column with values like [Company Invited, Self Enquiry].", "Column 'CityTier': number column with values like [3, 2].", "Column 'DurationOfPitch': number column with values like [11.0, 22.0].", "Column 'Occupation': category column with values like [Small Business, Small Business].", "Column 'Gender': category column with values like [Male, Male].", "Column 'NumberOfPersonVisiting': number column with values like [2, 3].", "Column 'NumberOfFollowups': number column with values like [5.0, 4.0].", "Column 'ProductPitched': category column with values like [Deluxe, Deluxe].", "Column 'PreferredPropertyStar': number column with values like [3.0, 4.0].", "Column 'MaritalStatus': category column with values like [Married, Married].", "Column 'NumberOfTrips': number column with values like [1.0, 1.0].", "Column 'Passport': boolean column with values like [0, 1].", "Column 'PitchSatisfactionScore': number column with values like [2, 5].", "Column 'OwnCar': boolean column with values like [0, 0].", "Column 'NumberOfChildrenVisiting': number column with values like [1.0, 1.0].", "Column 'Designation': category column with values like [Manager, Manager].", "Column 'MonthlyIncome': number column with values like [19668.0, 20021.0]."]
# [[-0.03588261 -0.06135156 -0.01372384 ...  0.06269739  0.01393268
#   -0.02219477]
#  [-0.08347294 -0.00689558 -0.00255152 ...  0.06862836  0.03590529
#    0.00888886]
#  [-0.08839737 -0.05876484 -0.00501851 ...  0.02297128  0.05023643
#   -0.07518529]
#  ...
#  [-0.01264729 -0.0679481  -0.00784694 ...  0.00155598  0.0315894
#    0.01033608]
#  [-0.00537348 -0.00331873  0.04547029 ...  0.0487853   0.04995178
#    0.03583569]
#  [-0.0913728  -0.04704793  0.03995521 ...  0.05675044  0.04467371
#   -0.04700114]]
# ["Column 'title_gx_text_length': number column with values like [20.0, 78.0].", "Column 'title': text column with values like [CRDTs are the future, Data structures and algorithms I actually used while working at tech companies].", "Column 'score': number column with values like [1181, 1025].", "Column 'partofday': category column with values like [afternoon, night].", "Column 'month_name': category column with values like [September, July].", "Column 'title_gx_lang': category column with values like [en, en].", "Column 'weekday_name': category column with values like [Monday, Wednesday].", "Column 'Clusters II': category column with values like [year, work, new, year, work, new].", "Column 'descendants': number column with values like [312.0, 524.0].", "Column 'season': category column with values like [Autumn, Summer].", "Column 'title_gx_cardiff_nlp_sentiment': empty column with values like []."]
# [[-0.00555838  0.00755338  0.04007351 ... -0.00733947  0.01263624
#    0.00966239]
#  [-0.05186279  0.01488313  0.01294645 ...  0.02245201  0.03291493
#    0.05038186]
#  [-0.07385083 -0.06431228  0.00965264 ...  0.04741162  0.06027877
#   -0.05402571]
#  ...
#  [-0.04132482 -0.0265302  -0.01817131 ...  0.02548828  0.04042272
#   -0.00586062]
#  [-0.03307653 -0.01470866  0.03992509 ... -0.01551536  0.04247882
#    0.0332012 ]
#  [-0.00993216  0.03447136  0.03370174 ...  0.03926388 -0.00922255
#    0.00701718]]
# ["Column 'Last Evaluation': number column with values like [0.89, 0.51].", "Column 'Department': category column with values like [support, technical].", "Column 'Left': category column with values like [No, No].", "Column 'Years in the Company': number column with values like [4, 3].", "Column 'Work Accident': category column with values like [No, No].", "Column 'Number of Projects': number column with values like [5, 3].", "Column 'Satisfaction Level': number column with values like [0.24, 0.28].", "Column 'salary': category column with values like [medium, low].", "Column 'Average Monthly Hours': number column with values like [142, 124].", "Column 'Promoted in the last 5 years?': category column with values like [No, No].", "Column 'Date Hired': date column with values like [2016-06-04, 2017-06-06]."]
# [[-0.08737706 -0.03901878  0.01154872 ...  0.06835577  0.04934388
#    0.02161357]
#  [-0.01826253 -0.00654732  0.04829581 ...  0.02133668  0.06258261
#    0.00444322]
#  [-0.03599605 -0.02586576 -0.01256041 ...  0.02959058  0.00417378
#    0.02407114]
#  ...
#  [-0.03781212 -0.05518079  0.00122264 ...  0.01785298  0.03345312
#   -0.01980901]
#  [-0.06099775 -0.00755793  0.02694945 ...  0.05777261  0.03279821
#    0.00959875]
#  [-0.08057823 -0.00839101  0.03582152 ...  0.05078633  0.01692467
#    0.00350017]]
# ["Column 'Incident_Location': string column with values like [near Loukhi, Arnhem].", "Column 'Fatalities': number column with values like [1, 5].", "Column 'Aircaft_Operator': string column with values like [Aeroflot, Northern, RAF].", "Column 'Onboard_Total': string column with values like [Fatalities: 1 / Occupants: 2, Fatalities: 5 / Occupants: 8].", "Column 'Aircaft_Model': text column with values like [Antonov An-2V, Douglas Dakota III (DC-3)].", "Column 'Onboard_Crew': string column with values like [Fatalities: 1 / Occupants: 2, Fatalities: 3 / Occupants: 4].", "Column 'Aircraft_Phase': category column with values like [En route (ENR), En route (ENR)].", "Column 'Incident_Category': category column with values like [Accident | hull-loss, Criminal occurrence (sabotage, shoot down) | hull-loss].", "Column 'Aircaft_Damage_Type': category column with values like [Damaged beyond repair, Damaged beyond repair].", "Column 'Incident_Cause(es)': text column with values like [Info-Unavailable, Security - Shot, Security - Shot - Surface-to-air].", "Column 'Date': string column with values like [Sunday 5 September 1965, Tuesday 19 September 1944].", "Column 'Ground_Casualties': category column with values like [Fatalities: 9, Fatalities: 1].", "Column 'Onboard_Passengers': string column with values like [Fatalities: 0 / Occupants: 0, Fatalities: 2 / Occupants: 4]."]
# [[-0.03584931  0.003884    0.03224045 ...  0.03564841 -0.0581422
#    0.01846997]
#  [-0.08950245 -0.05648534  0.04066626 ...  0.03405178  0.01813184
#   -0.03630308]
#  [-0.02317197  0.0081814   0.03712424 ...  0.00413589  0.03076808
#    0.05941622]
#  ...
#  [-0.08435635 -0.00679747  0.02106121 ...  0.04090124  0.01162852
#    0.00148166]
#  [-0.055792   -0.00102142  0.03394364 ...  0.02390571  0.00918735
#   -0.00767663]
#  [-0.02112876 -0.02258008  0.02912891 ...  0.03670339  0.02387592
#    0.00165047]]
# ["Column 'customerID': string column with values like [1024-GUALD, 0484-JPBRU].", "Column 'gender': category column with values like [Female, Male].", "Column 'SeniorCitizen': boolean column with values like [0, 0].", "Column 'Partner': category column with values like [Yes, No].", "Column 'Dependents': category column with values like [No, No].", "Column 'tenure': number column with values like [1, 41].", "Column 'PhoneService': category column with values like [No, Yes].", "Column 'MultipleLines': category column with values like [No phone service, Yes].", "Column 'InternetService': category column with values like [DSL, No].", "Column 'OnlineSecurity': category column with values like [No, No internet service].", "Column 'OnlineBackup': category column with values like [No, No internet service].", "Column 'DeviceProtection': category column with values like [No, No internet service].", "Column 'TechSupport': category column with values like [No, No internet service].", "Column 'StreamingTV': category column with values like [No, No internet service].", "Column 'StreamingMovies': category column with values like [No, No internet service].", "Column 'Contract': category column with values like [Month-to-month, Month-to-month].", "Column 'PaperlessBilling': category column with values like [Yes, Yes].", "Column 'PaymentMethod': category column with values like [Electronic check, Bank transfer (automatic)].", "Column 'MonthlyCharges': number column with values like [24.8, 25.25].", "Column 'TotalCharges': number column with values like [24.8, 996.45].", "Column 'Churn': category column with values like [Yes, No]."]
# [[-0.01861085 -0.05541482 -0.01473751 ...  0.01785808  0.02994852
#    0.00816739]
#  [-0.00822557 -0.00256233  0.01191869 ... -0.01368893  0.03653101
#   -0.00724205]
#  [-0.10224199 -0.01580006 -0.00364992 ...  0.08913212  0.06108779
#    0.02338951]
#  ...
#  [-0.06758083 -0.03299048 -0.01069    ... -0.01306763  0.00365569
#    0.01305699]
#  [-0.05104636 -0.04885751 -0.00247822 ...  0.01372776  0.01285207
#    0.01228967]
#  [-0.04039456 -0.0360242  -0.02094739 ...  0.05527741  0.03220208
#   -0.01624366]]
# ["Column 'minimum_nights': number column with values like [30, 30].", "Column 'name': text column with values like [Skylit Bedroom In Brooklyn, 1 Bedroom in 2 bdr Bushwick apt].", "Column 'host_location': category column with values like [New York, New York, United States, New York, New York, United States].", "Column 'instant_bookable': category column with values like [t, f].", "Column 'review_scores_rating': number column with values like [93.0, 99.0].", "Column 'host_total_listings_count': number column with values like [0.0, 1.0].", "Column 'property_type': category column with values like [Private room in apartment, Private room in apartment].", "Column 'review_scores_location': number column with values like [9.0, 10.0].", "Column 'bedrooms': number column with values like [1.0, 1.0].", "Column 'listing_id': number column with values like [31898478, 9473492].", "Column 'host_id': number column with values like [3734323, 49099055]."]
# [[-0.04444711 -0.0418794   0.00476996 ...  0.06870544  0.00282544
#   -0.01581887]
#  [ 0.01553654 -0.01676527  0.01912555 ...  0.04047506 -0.02571734
#    0.00690923]
#  [ 0.00957776 -0.0502645   0.06139575 ...  0.04176529 -0.02698041
#    0.00343341]
#  ...
#  [-0.01295524 -0.05414861  0.00606116 ...  0.0428061  -0.01014299
#   -0.04499586]
#  [-0.03654408 -0.06656547 -0.00212002 ...  0.03641175  0.03038616
#   -0.0106186 ]
#  [-0.04217946 -0.07139969  0.01800962 ...  0.05765484  0.03725143
#   -0.04374722]]
# ["Column 'racha': number column with values like [8.3, 4.2].", "Column 'dayofyear': number column with values like [103, 45].", "Column 'tmin': number column with values like [10.0, 3.5].", "Column 'velmedia': number column with values like [1.1, 2.8].", "Column 'month_name': string column with values like [April, February].", "Column 'sol': number column with values like [9.4, 8.4].", "Column 'weekday_name': category column with values like [Sunday, Tuesday].", "Column 'tmed': number column with values like [15.0, 6.6].", "Column 'tmax': number column with values like [20.0, 9.7].", "Column 'prec': number column with values like [2.4, 0.0].", "Column 'season': category column with values like [Spring, Winter].", "Column 'fecha': date column with values like [2020-04-12T00:00:00Z, 1950-02-14T00:00:00Z].", "Column 'presMax': number column with values like [942.0, 953.5]."]
# [[-0.04644259 -0.05832232 -0.03591869 ...  0.0240996   0.03061929
#    0.00603082]
#  [-0.05943848 -0.05618008 -0.00341061 ...  0.02965911  0.00950341
#   -0.02275772]
#  [-0.06558151 -0.07547446  0.02307535 ...  0.04472061  0.01170942
#   -0.01339311]
#  ...
#  [-0.01588402 -0.00478566  0.04079239 ... -0.01483167  0.03864911
#    0.02418469]
#  [-0.07110202 -0.03890695 -0.01222145 ... -0.01596418 -0.00825719
#   -0.03368398]
#  [-0.07116672 -0.04751623  0.01100694 ...  0.04813118  0.0199196
#    0.01903647]]
# ["Column 'CNACE': text column with values like [Información y comunicaciones: edición, actividades cinematog, Industria manufacturera: coquerías y refino de petróleo, ind].", "Column 'RETRINOIN_ac1q': number column with values like [29699.05, 13871.31].", "Column 'RETRINOIN_WwQk': number column with values like [29699.05, 13871.31].", "Column 'CONTROL': category column with values like [PRIVADO, PRIVADO].", "Column 'SEXO': category column with values like [Female, Male].", "Column 'x': number column with values like [612.26984, -1538.5378].", "Column 'MERCADO': category column with values like [LOCAL O REGIONAL, NACIONAL].", "Column 'RETRINOIN_xRZI': number column with values like [29699.05, 13871.31].", "Column 'NUTS1': category column with values like [NORESTE, NORESTE].", "Column 'RETRINOIN': number column with values like [29699.05, 13871.31].", "Column 'y': number column with values like [8831.377, 13925.02].", "Column 'ANOS2': category column with values like [DE 40 A 49, DE 30 A 39].", "Column 'umap_cluster': string column with values like [Cluster 20, Cluster 10]."]
# [[-0.02938986 -0.00087125  0.01003195 ...  0.01844143  0.03261161
#    0.0058671 ]
#  [-0.07930244 -0.04291279 -0.05494821 ...  0.05082266  0.06338967
#   -0.0438452 ]
#  [-0.06092644 -0.05817598 -0.03747425 ...  0.04136646  0.0438719
#   -0.06116959]
#  ...
#  [-0.05586473 -0.09730023 -0.00030522 ...  0.04683431  0.02807958
#   -0.04466832]
#  [-0.04868006 -0.02983357 -0.02120133 ...  0.04538491  0.04093909
#    0.01128273]
#  [-0.04869085 -0.04411706 -0.02323429 ...  0.00839003 -0.00169546
#    0.03624407]]
# ["Column 'Ranking': number column with values like [1, 3].", "Column 'Competition': category column with values like [Medium, Unknown].", "Column 'Avg. monthly searches': number column with values like [50, 50].", "Column 'URLs': url column with values like [https://www.obviously.ai/, https://hbr.org/2021/11/how-no-code-platforms-can-bring-ai-to-small-and-midsize-businesses].", "Column 'Keyword': category column with values like [no code data science, no code data analytics]."]
# [[-0.04548465 -0.07317279 -0.00646981 ...  0.02649356  0.01964026
#    0.01206286]
#  [-0.0251223  -0.02852053 -0.02388717 ...  0.0053467   0.04166155
#    0.0167039 ]
#  [-0.08956732 -0.07633173 -0.01404629 ...  0.01716102  0.04036049
#   -0.00214267]
#  [-0.06513482 -0.09165745 -0.00043137 ...  0.03314449  0.02470861
#    0.00570428]
#  [-0.00521272 -0.02017709 -0.02672738 ... -0.00086871  0.00482579
#   -0.01167393]]
# ["Column 'quality': number column with values like [6, 5].", "Column 'alcohol': number column with values like [9.6, 9.5].", "Column 'density': number column with values like [0.9971, 0.996].", "Column 'pH': number column with values like [3.24, 3.39].", "Column 'volatile acidity': number column with values like [0.56, 0.5].", "Column 'free sulfur dioxide': number column with values like [14, 21].", "Column 'fixed acidity': number column with values like [7.7, 7.8].", "Column 'residual sugar': number column with values like [2.5, 1.6]."]
# [[-0.05020225 -0.07249328  0.0294258  ...  0.04719629  0.05241047
#   -0.02377226]
#  [-0.024573   -0.03360385 -0.00533058 ...  0.042664    0.07211301
#   -0.02874736]
#  [-0.0339286  -0.05566975 -0.01316128 ...  0.01976533  0.05760844
#    0.02291085]
#  ...
#  [-0.08425257 -0.02190659 -0.01356049 ...  0.02955676  0.03869352
#    0.01543258]
#  [-0.06148934 -0.03356748  0.00072582 ...  0.05195612  0.0194741
#   -0.02931953]
#  [-0.03684264 -0.03524641  0.00062807 ...  0.02773309  0.01062368
#   -0.04226881]]
# ["Column 'gross income': number column with values like [6.4455, 29.38].", "Column 'Unit price': number column with values like [42.97, 58.76].", "Column 'Total': number column with values like [135.3555, 616.98].", "Column 'Customer type': category column with values like [Normal, Normal].", "Column 'Product line': category column with values like [Sports and travel, Electronic accessories].", "Column 'Quantity': number column with values like [3, 10].", "Column 'Gender': category column with values like [Female, Male].", "Column 'Branch': category column with values like [B, C].", "Column 'City': category column with values like [Mandalay, Naypyitaw].", "Column 'Payment': category column with values like [Cash, Ewallet].", "Column 'Rating': number column with values like [9.3, 9.0]."]
# [[-0.01858162 -0.05713483 -0.01677434 ... -0.01660181  0.0281481
#   -0.04648548]
#  [-0.04890901 -0.07259695 -0.00215412 ... -0.01411541  0.01910224
#   -0.01618987]
#  [-0.02502248 -0.09492021  0.00358549 ...  0.00577886  0.05482728
#   -0.05080046]
#  ...
#  [-0.00923922 -0.04362102  0.02118894 ...  0.05596963  0.0037294
#    0.02076575]
#  [-0.01938888 -0.05419888  0.00856507 ...  0.00485413  0.05257415
#   -0.01120344]
#  [-0.05526325 -0.04950804 -0.00249308 ...  0.049431    0.04451121
#   -0.01890354]]
# ["Column 'BMI': number column with values like [34.0, 35.7].", "Column 'Age': number column with values like [43, 21].", "Column 'Glucose': number column with values like [98, 112].", "Column 'Outcome': boolean column with values like [0, 0].", "Column 'Pregnancies': number column with values like [6, 2].", "Column 'BloodPressure': number column with values like [58, 75].", "Column 'DiabetesPedigreeFunction': number column with values like [0.43, 0.148].", "Column 'Insulin': number column with values like [190, 0]."]
# [[-0.03870752 -0.03553146 -0.032114   ... -0.02050428  0.0355493
#   -0.03554998]
#  [-0.08563916 -0.05442756 -0.00237277 ...  0.02397105  0.05182822
#   -0.05969707]
#  [-0.06178562 -0.00319016 -0.0162768  ...  0.01036879  0.03414194
#   -0.06838643]
#  ...
#  [-0.09829371  0.01731613 -0.0298229  ... -0.01121738  0.06622474
#   -0.05848685]
#  [-0.05661164 -0.01229027  0.01097908 ...  0.00035526  0.00770442
#   -0.01273209]
#  [-0.05382832 -0.028674   -0.01065254 ... -0.01586229  0.01888238
#   -0.04906177]]
# ["Column 'date': date column with values like [2021-07-01, 2021-06-03].", "Column 'keywords': list[category] column with values like [['Surfside, Fla, Building Collapse (2021)', 'Condominiums', 'Accidents and Safety'], ['United States Politics and Government', 'Newspapers', 'News Sources, Confidential Status of', 'Classified Information and State Secrets', 'Freedom of the Press', 'News and News Media']].", "Column 'material_type': category column with values like [Video, News].", "Column 'headline': text column with values like [Rescue Teams Paused Search Over Building Structure Concern, Trump Administration Secretly Seized Phone Records of Times Reporters]."]
# [[-0.0984115  -0.0485925   0.03712138 ...  0.02579544  0.00489147
#   -0.01394933]
#  [-0.03032832 -0.025152   -0.00309124 ...  0.00991591 -0.01125542
#    0.01960267]
#  [ 0.00964544  0.01906488  0.01239609 ... -0.02341732  0.08521599
#    0.03537619]
#  [-0.01875239  0.04864909 -0.00486808 ... -0.01626052  0.00371117
#   -0.00087997]]
# ["Column 'Which of the following cloud computing platforms do you hope to become more familiar with in the next 2 years?': list[empty] column with values like [[], [Amazon Web Services (AWS), Microsoft Azure, Google Cloud Platform (GCP), Salesforce Cloud]].", "Column 'What type of computing platform do you use most often for your data science projects?': category column with values like [A laptop, A laptop].", "Column 'What is your age (years)?': category column with values like [22-24, 22-24].", "Column 'In which country do you currently reside?': text column with values like [Brazil, Indonesia].", "Column 'Select the title most similar to your current role (or most recent title if retired)': category column with values like [Data Scientist, Currently not employed].", "Column 'Labeled Clusters': text column with values like [Data Scientists w Masters Degree, Unemployed - Bachelors].", "Column 'General Segments': category column with values like [[Data Scientists], []].", "Column 'What programming languages do you use on a regular basis?': text column with values like [[Python, R], [Python, SQL]].", "Column 'Geographies': category column with values like [[South America], [Developing Asia]].", "Column 'What programming language would you recommend an aspiring data scientist to learn first?': category column with values like [Python, SQL].", "Column 'What is the size of the company where you are employed?': category column with values like [0-49 employees, 0-49 employees].", "Column '(Average) For how many years have you used machine learning methods?': number column with values like [1.5, 0.5].", "Column '(Average) What is your current yearly compensation (approximate $USD)?': number column with values like [4499.5, 34999.5]."]
# [[-0.07256576 -0.0873384  -0.00205653 ...  0.07093928  0.0026169
#    0.05384341]
#  [-0.00494407 -0.02187749 -0.01500545 ...  0.06327617  0.03992178
#    0.04358739]
#  [-0.05400069 -0.01755853  0.02290343 ...  0.0696841   0.03653248
#   -0.05066361]
#  ...
#  [-0.02018235 -0.05141575 -0.0071791  ...  0.01840344  0.03044223
#    0.05929283]
#  [-0.04676452 -0.05847794  0.03306505 ...  0.0470288   0.01295101
#   -0.02330896]
#  [-0.07389981 -0.05630229 -0.00365942 ...  0.02027213  0.00407965
#   -0.01268227]]
# ["Column 'rating': number column with values like [2, 5].", "Column 'country_code': string column with values like [US, PT].", "Column 'Company': category column with values like [Wise, N26]."]
# [[-0.05969224 -0.06274857  0.01499833 ...  0.06877647  0.03271713
#   -0.01871832]
#  [-0.03451184 -0.02360995  0.02003814 ...  0.02486306  0.0306392
#   -0.00790786]
#  [-0.00862576 -0.03805022 -0.01515673 ... -0.01450006  0.05190544
#    0.04544928]]
# ["Column 'ID': number column with values like [2607, 7247].", "Column 'Recency': number column with values like [78, 72].", "Column 'NumWebPurchases': number column with values like [8, 7].", "Column 'Education': category column with values like [Graduation, Graduation].", "Column 'Marital_Status': category column with values like [Single, Widow].", "Column 'Income': number column with values like [40464, 47916]."]
# [[-0.0546402  -0.03512406 -0.03369873 ...  0.02786053  0.05961385
#   -0.04410227]
#  [-0.08228006 -0.0376456  -0.01149527 ...  0.0640218   0.02806693
#   -0.04245093]
#  [-0.05247369 -0.06527814 -0.03504888 ...  0.02184181  0.00662408
#   -0.00310011]
#  [-0.01560032  0.02889951  0.03960193 ...  0.02474506  0.05133681
#    0.02135983]
#  [-0.03842043  0.01748068 -0.00925553 ...  0.02690899  0.06984897
#   -0.00536213]
#  [-0.03477492 -0.06909719 -0.0246447  ...  0.00169683  0.03007842
#   -0.02356494]]
# ["Column 'Left': category column with values like [No, No].", "Column 'Satisfaction Level': number column with values like [0.73, 0.93].", "Column 'Work Accident': category column with values like [No, No].", "Column 'Average Monthly Hours': number column with values like [174, 276].", "Column 'Last Evaluation': number column with values like [0.63, 0.48].", "Column 'Years in the Company': number column with values like [3, 3].", "Column 'salary': category column with values like [low, low].", "Column 'Department': category column with values like [accounting, IT].", "Column 'Number of Projects': number column with values like [4, 3].", "Column 'Promoted in the last 5 years?': category column with values like [No, No].", "Column 'Date Hired': date column with values like [2017-05-09, 2017-05-08].", "Column 'Marital_Status': category column with values like [ Married,  Married]."]
# [[-0.03599605 -0.02586576 -0.01256041 ...  0.02959058  0.00417378
#    0.02407114]
#  [-0.0652514  -0.03661469 -0.01409559 ...  0.10257848  0.03264461
#   -0.03381851]
#  [-0.06146359 -0.01813119  0.01114244 ...  0.05987395  0.0186507
#    0.02335187]
#  ...
#  [-0.06099775 -0.00755793  0.02694945 ...  0.05777261  0.03279821
#    0.00959875]
#  [-0.08955371 -0.02252735  0.02914415 ...  0.04275568  0.02653909
#    0.00563518]
#  [-0.02694032  0.0320375  -0.02866099 ...  0.03682186  0.06815398
#   -0.03035283]]
# ["Column 'Ladder score': number column with values like [5.233300209, 5.197599888].", "Column 'Social support': number column with values like [0.658048689, 0.91316092].", "Column 'Perceptions of corruption': number column with values like [0.790771961, 0.824211061].", "Column 'Regional indicator': category column with values like [Sub-Saharan Africa, South Asia].", "Column 'Generosity': number column with values like [-0.043991156, 0.038085498]."]
# [[-0.08271015 -0.04835448 -0.00376582 ...  0.01997897  0.0258845
#   -0.00358006]
#  [-0.03997205 -0.03763939 -0.02161717 ...  0.04571047  0.01619371
#    0.00746134]
#  [-0.04974071 -0.02693904  0.00555485 ...  0.06946208  0.03011125
#   -0.04998212]
#  [-0.0001386  -0.01569305  0.02139571 ...  0.00420887 -0.01476571
#    0.00124298]
#  [-0.08011172 -0.05071825 -0.01745029 ...  0.0469093  -0.00774567
#   -0.06613346]]
# ["Column 'lon_origin': number column with values like [-106.6847185, -89.50553297].", "Column 'lat_dest': number column with values like [39.01016896, 46.27467409].", "Column 'name_origin': string column with values like [Bernalillo, Portage].", "Column 'lon_dest': number column with values like [-96.74226038, -90.65691261].", "Column 'name_dest': string column with values like [Geary, Ashland].", "Column 'count': number column with values like [17, 20].", "Column 'dest': number column with values like [20061, 55003].", "Column 'lat_origin': number column with values like [35.07217059, 44.4720557]."]
# [[-0.05765389 -0.05461513 -0.02269718 ...  0.05773104 -0.00415774
#   -0.02740807]
#  [-0.03013018 -0.08530345  0.04531201 ... -0.0034795  -0.00239703
#    0.02010871]
#  [-0.02772329 -0.00685396  0.02214798 ...  0.04279223  0.03028769
#   -0.00786391]
#  ...
#  [-0.04878374 -0.06313732  0.02392571 ...  0.02875613  0.00542492
#   -0.00040886]
#  [-0.05320086 -0.04293395 -0.00023113 ...  0.01425278  0.04928297
#    0.03396999]
#  [-0.02674186 -0.06416962  0.02950504 ...  0.03341961  0.00062234
#    0.00931708]]
# ["Column 'views': number column with values like [946000, 310677].", "Column 'title': text column with values like [Glorious visions in animation and performance, Medicine for the 99 percent].", "Column 'available_lang': list[category] column with values like [['af', 'ar', 'bg', 'cs', 'de', 'el', 'en', 'es', 'fa', 'fr', 'he', 'hi', 'hu', 'id', 'it', 'ja', 'ko', 'lt', 'lv', 'my', 'nl', 'pa', 'pl', 'pt', 'pt-br', 'ro', 'ru', 'sr', 'th', 'tr', 'uk', 'vi', 'zh-cn', 'zh-tw'], ['ar', 'en', 'es', 'fa', 'fr', 'he', 'it', 'ko', 'nl', 'pt-br', 'tr', 'zh-cn', 'zh-tw']].", "Column 'speaker_1': string column with values like [Miwa Matreyek, Thomas Pogge].", "Column 'duration': number column with values like [671, 1085].", "Column 'comments': number column with values like [148.0, 121.0].", "Column 'event': string column with values like [TEDGlobal 2010, TEDxCanberra]."]
# [[-0.04415675 -0.06003618 -0.01909105 ...  0.05610526  0.03617967
#   -0.03052569]
#  [-0.03510279  0.02916382  0.01466028 ...  0.02918196  0.0634103
#   -0.00390671]
#  [-0.07494877 -0.02431294 -0.00496163 ...  0.05044108  0.01453488
#    0.01062381]
#  ...
#  [-0.06766293 -0.02513518  0.03064953 ...  0.04101153  0.02535826
#   -0.02150944]
#  [-0.06313756 -0.01785813  0.00545246 ...  0.04703464  0.04473986
#   -0.04621843]
#  [-0.03570298  0.01889986  0.01386799 ... -0.00459931 -0.00649727
#    0.02234004]]
# ["Column 'smoking_status': category column with values like [Unknown, never smoked].", "Column 'heart_disease': boolean column with values like [0.0, 0.0].", "Column 'gender': category column with values like [Male, Male].", "Column 'age': number column with values like [31.0, 40.0].", "Column 'work_type': category column with values like [Self-employed, Self-employed].", "Column 'stroke': boolean column with values like [0.0, 0.0].", "Column 'bmi': number column with values like [23.0, 28.3].", "Column 'Residence_type': category column with values like [Rural, Rural].", "Column 'ever_married': category column with values like [No, Yes].", "Column 'avg_glucose_level': number column with values like [64.85, 65.29].", "Column 'hypertension': boolean column with values like [0.0, 0.0]."]
# [[-0.02375964  0.00416742  0.00285563 ...  0.07588834  0.05426424
#    0.02600561]
#  [-0.07079655 -0.0377454   0.0295519  ...  0.02658274  0.08109462
#    0.01209847]
#  [-0.00207686  0.00571985  0.00804908 ... -0.0107997   0.03100367
#   -0.01327677]
#  ...
#  [-0.04721483  0.02435297 -0.0219584  ...  0.06981517  0.06884313
#   -0.02722009]
#  [-0.05813105 -0.03436653 -0.01103127 ... -0.01313546  0.0409596
#   -0.04720259]
#  [-0.07574154 -0.02542914  0.00188532 ...  0.06459254  0.05061262
#   -0.00308284]]
# ["Column 'wid': number column with values like [8129, 2634].", "Column 'gender': category column with values like [f, f].", "Column 'age': number column with values like [54.0, 46.0].", "Column 'marital': category column with values like [single, single].", "Column 'predicted_category': category column with values like [affection, achievement].", "Column 'reflection_period': category column with values like [24h, 3m].", "Column 'num_sentence': number column with values like [1, 1].", "Column 'country': category column with values like [USA, USA]."]
# [[-0.07732544 -0.06957533  0.03398915 ... -0.00222884  0.02333821
#   -0.00147338]
#  [-0.00025943 -0.01818709  0.00101363 ... -0.01341373  0.04200368
#    0.00209225]
#  [-0.07159726 -0.05683552  0.0028783  ...  0.02369559  0.03475319
#   -0.06462197]
#  ...
#  [-0.04314165 -0.00920055  0.00775235 ...  0.02035538 -0.02039225
#    0.00963122]
#  [-0.03916636 -0.05559834  0.0157763  ...  0.03988947  0.03908219
#   -0.02800591]
#  [-0.00626278 -0.03378982  0.03581055 ...  0.0255749   0.01993393
#   -0.01812353]]
# ["Column 'expected_num_matches': number column with values like [2.0, 1.0].", "Column 'gender': category column with values like [male, male].", "Column 'age': number column with values like [27.0, 24.0].", "Column 'race': category column with values like [european/caucasian-american, asian/pacific islander/asian-american].", "Column 'wave': number column with values like [12, 21].", "Column 'samerace': boolean column with values like [0, 0].", "Column 'match': boolean column with values like [0, 0]."]
# [[-0.08600961 -0.05795085  0.00404969 ...  0.01401763  0.0213414
#   -0.01966688]
#  [-0.00207686  0.00571985  0.00804908 ... -0.0107997   0.03100367
#   -0.01327677]
#  [-0.07443864 -0.0325576  -0.00016245 ...  0.0106782   0.0431804
#   -0.05444733]
#  ...
#  [-0.07129034 -0.06252223 -0.00513849 ...  0.03990708  0.01421113
#    0.01797419]
#  [-0.0932422  -0.03227761 -0.02429935 ...  0.04387713  0.05348669
#   -0.01711389]
#  [-0.11932827 -0.04778529 -0.02501596 ...  0.05835077  0.05766037
#   -0.00807317]]
# ["Column 'retweet_count': boolean column with values like [1, 0].", "Column 'negativereason': category column with values like [Cancelled Flight, Late Flight].", "Column 'user_timezone': category column with values like [Eastern Time (US & Canada), Atlantic Time (Canada)].", "Column 'airline_sentiment_confidence': number column with values like [1.0, 1.0].", "Column 'tweet_id': number column with values like [569731104070115329, 569263373092823040].", "Column 'airline': category column with values like [Southwest, US Airways].", "Column 'airline_sentiment': category column with values like [positive, negative]."]
# [[-0.06006533 -0.05740637  0.02028506 ...  0.046752    0.04949691
#    0.03880293]
#  [-0.02577517 -0.00593718  0.00329936 ...  0.02584321 -0.01532848
#    0.01997305]
#  [-0.0417609   0.00033446  0.03736398 ...  0.01966072 -0.05201588
#   -0.00546083]
#  ...
#  [-0.0489122  -0.04846698 -0.00272935 ...  0.03521085  0.02814375
#    0.0176105 ]
#  [ 0.02076294 -0.04137432 -0.00725345 ...  0.00530014  0.01815266
#    0.05041019]
#  [-0.01388597 -0.00195244  0.00424286 ...  0.03675871  0.01181169
#    0.02657485]]
# ["Column 'famrel': number column with values like [4, 4].", "Column 'sex': category column with values like [M, M].", "Column 'romantic': category column with values like [no, yes].", "Column 'Mjob': category column with values like [other, at_home].", "Column 'famsize': category column with values like [GT3, LE3].", "Column 'age': number column with values like [17, 18].", "Column 'school': category column with values like [GP, MS].", "Column 'Pstatus': category column with values like [T, T].", "Column 'absences': number column with values like [2, 3].", "Column 'address': category column with values like [U, R].", "Column 'Dalc': number column with values like [1, 2].", "Column 'freetime': number column with values like [5, 3].", "Column 'Medu': number column with values like [2, 1].", "Column 'G3': number column with values like [10, 12].", "Column 'reason': category column with values like [home, other].", "Column 'higher': category column with values like [no, no]."]
# [[-0.05543149 -0.04990214 -0.0346357  ...  0.04583928  0.0440262
#    0.0132707 ]
#  [-0.01237098  0.02094142  0.01053169 ...  0.01436271  0.02996776
#   -0.01878059]
#  [-0.03318653  0.01280324  0.02596994 ...  0.07586564  0.04555301
#   -0.01268048]
#  ...
#  [-0.01607293 -0.05780477 -0.02210427 ...  0.02586418  0.02076125
#    0.00578532]
#  [-0.01160031 -0.03538586  0.03479447 ...  0.06964776 -0.01833955
#    0.04734459]
#  [-0.05930962 -0.0324378  -0.02631319 ...  0.03173256  0.03551208
#    0.03110554]]
# ...
# [[-0.0086794  -0.05711896 -0.0181644  ...  0.04885536  0.06911998
#    0.0387651 ]
#  [-0.06832575 -0.07379656  0.00455798 ...  0.03377509  0.0337792
#   -0.00110663]
#  [-0.03398695  0.01826563  0.05746932 ...  0.02080542  0.05485335
#    0.01372166]
#  ...
#  [-0.09160211 -0.05303311 -0.00518672 ...  0.03506973  0.03440087
#    0.01102928]
#  [ 0.01525494 -0.01786305  0.01294494 ...  0.03001403  0.0540687
#    0.02269254]
#  [ 0.00800741  0.00447032  0.02360857 ... -0.00051053  0.09110796
#    0.0060058 ]]
# ["Column 'Loan Amount': number column with values like [8613, 7297].", "Column 'Credit History': category column with values like [Delay in Paying Off in the Past, Existing Credits Paid Back Duly Till Now].", "Column 'Loan Duration - Months': number column with values like [27, 60].", "Column 'Age': number column with values like [27, 36].", "Column 'Savings Account': category column with values like [More than 1000 DM, Less than 100 DM].", "Column 'Job': category column with values like [Skilled, Skilled].", "Column 'Number of Existing Loans': number column with values like [3, 1].", "Column 'Purpose of Loan': category column with values like [Used Car, Business]."]
# [[-0.04428699 -0.07222526 -0.02340074 ...  0.01514467  0.02624148
#   -0.04724038]
#  [-0.06454913 -0.02866749  0.02507882 ...  0.05154371 -0.01956163
#   -0.01600147]
#  [-0.03458071 -0.02716721  0.01586079 ...  0.00714242  0.01491017
#   -0.0345499 ]
#  ...
#  [-0.035698   -0.01112369 -0.01738499 ...  0.03078439  0.06580691
#    0.00137985]
#  [-0.04887147 -0.10233907 -0.00042238 ...  0.02706977  0.00833234
#   -0.00930474]
#  [ 0.00544424 -0.03136612  0.02836255 ...  0.00942112  0.00200359
#    0.02262538]]
# ["Column 'Calories (kcal)': number column with values like [0.69, 0.89].", "Column 'Total Fat (g)': number column with values like [0.0016, 0.0033].", "Column 'name': string column with values like [grapes, banana].", "Column 'Sodium (g)': number column with values like [0.02, 0.01].", "Column 'Protein (g)': number column with values like [0.0072, 0.0109].", "Column 'Total Sugar (g)': number column with values like [0.1548, 0.1223]."]
# [[-0.06345326 -0.01658323  0.01673486 ...  0.013098    0.04569588
#   -0.00955963]
#  [-0.00779835 -0.03060152  0.03674839 ... -0.01471226  0.0459501
#   -0.02945836]
#  [-0.01475609 -0.02353881  0.02106012 ...  0.04271837  0.05335581
#    0.00591242]
#  [-0.06321359 -0.03225162 -0.02720525 ...  0.02203669  0.00312912
#    0.01336703]
#  [-0.05548853 -0.06208776 -0.01479648 ... -0.04752915  0.0484769
#   -0.04775507]
#  [ 0.00374471 -0.05524142  0.00302448 ... -0.00950886  0.00661375
#   -0.05780941]]
# ["Column 'partyId': category column with values like [I prefer not to say, PP].", "Column 'Vote Intention': category column with values like [[I prefer not to say], []].", "Column 'User self- placement on Progressive-Conservative economic values axis': number column with values like [5.0, 7.0].", "Column 'polInterest': category column with values like [A little interested, Somewhat interested].", "Column 'Age': number column with values like [33.0, 55.0].", "Column 'gender': category column with values like [Female, Male].", "Column 'lang': category column with values like [Castellano, Castellano].", "Column 'edu': category column with values like [University degree, I prefer not to say].", "Column 'voteReason': category column with values like [I prefer not to say, So that another party does not win].", "Column 'Constitutional organisation of the country (More Descentralization)': number column with values like [2.0, 2.0].", "Column 'It should be more difficult for companies to lay off workers': number column with values like [2.0, 3.0].", "Column 'User self-placement on Left-Right economic values axis': number column with values like [7.0, 2.0]."]
# [[-0.02482638 -0.02990302 -0.00348637 ...  0.04806154  0.01779726
#   -0.02252609]
#  [-0.03830048 -0.0116218   0.00941844 ...  0.06526124  0.00466563
#    0.01691832]
#  [-0.04281242 -0.02261666 -0.01895111 ...  0.04265455 -0.0497761
#   -0.01674766]
#  ...
#  [-0.03087418 -0.01296033  0.00337131 ...  0.04195138 -0.00431109
#    0.01455833]
#  [-0.04859639 -0.01803264 -0.02003491 ...  0.01813221  0.01484544
#    0.01161467]
#  [-0.04424912 -0.03370043 -0.01076294 ...  0.03989974 -0.04347314
#   -0.02664384]]
# ["Column 'Are you registered to vote?': category column with values like [Yes, No - I will not register].", "Column 'Which of the following best describes your ethnic heritage?': category column with values like [Asian, White (not Hispanic, Latino or Spanish origin)].", "Column 'Who are you most likely to vote for on election day?': category column with values like [Joe Biden (Democrat), Undecided].", "Column 'Division': category column with values like [South Atlantic, West North Central].", "Column 'Did you vote in the 2016 Presidential election? (Four years ago)': category column with values like [No - I was eligible but did not vote, Yes].", "Column 'Weight': number column with values like [4.871233760276248, 0.8475708375044543].", "Column 'How likely are you to vote in the forthcoming US Presidential election? Early Voting Open': category column with values like [10 (Will definitely vote), 10 (Will definitely vote)].", "Column 'State': string column with values like [GA, MO].", "Column 'County FIPS': number column with values like [13135, 29189].", "Column 'Who did you vote for in the 2016 Presidential election? (Four years ago)': category column with values like [Hillary Clinton (Democrat), Donald Trump (Republican)].", "Column 'What is the highest degree or level of school you have *completed* ?': category column with values like [High school graduate (includes equivalency), Associate's degree].", "Column 'NCHS Urban/rural': number column with values like [2, 2].", "Column 'likelihood': number column with values like [10.0, 10.0].", "Column 'Which of these best describes the kind of work you do?': category column with values like [Office worker or other professional, Education and training].", "Column 'How old are you?': category column with values like [25-34, 25-34]."]
# [[-0.05218404 -0.01997819 -0.00422589 ...  0.10471784  0.01765075
#   -0.0170891 ]
#  [-0.00838399  0.00813102  0.02518276 ...  0.05748989  0.02219429
#   -0.01639517]
#  [-0.07884833  0.02684425 -0.03670799 ...  0.08729277 -0.01211913
#    0.02866938]
#  ...
#  [-0.06519084 -0.05662672 -0.00691539 ...  0.04697512  0.03664823
#   -0.04266959]
#  [ 0.00681874  0.00567145  0.02149453 ...  0.06760368  0.0770288
#    0.03653499]
#  [-0.05718955 -0.01380393 -0.00202693 ...  0.06451628  0.06495333
#   -0.02603497]]
# ["Column 'fuel': category column with values like [Diésel, Eléctrico].", "Column 'color': category column with values like [Gris / Plata (gris), Blanco].", "Column 'shift': category column with values like [Manual, Automático].", "Column 'make': string column with values like [MERCEDES-BENZ, BMW].", "Column 'model': string column with values like [Clase GLS, i3].", "Column 'price': number column with values like [61990, 23975].", "Column 'year': number column with values like [2017.0, 2018.0].", "Column 'kms': number column with values like [115242, 9886].", "Column 'power': number column with values like [258.0, 170.0].", "Column 'province': string column with values like [Madrid, Madrid].", "Column 'dealer': text column with values like [automotorDURSAN.com A, Canalcar].", "Column 'photos': number column with values like [54, 44].", "Column 'version': text column with values like [MERCEDES-BENZ Clase GLS GLS 350 d 4MATIC 5p., BMW i3 94ah 5p.]."]
# [[-0.00212425  0.02234312  0.02604108 ...  0.03563295  0.04397805
#    0.02358717]
#  [ 0.00138049 -0.02428868  0.02668787 ...  0.00253961  0.01512222
#    0.00308638]
#  [-0.0340916  -0.01487184  0.07422546 ...  0.01559036  0.01273585
#    0.01131636]
#  ...
#  [-0.03499058  0.00249879  0.03217405 ...  0.0484764   0.04029606
#    0.01831586]
#  [-0.04903867 -0.05962515 -0.01113885 ...  0.02505118  0.03525243
#   -0.03909097]
#  [-0.05400893  0.00824134  0.00130128 ... -0.00098785  0.031933
#    0.02863831]]
# ["Column 'date_time': date column with values like [06-02-2017 10:56, 13-11-2016 14:14].", "Column 'Item': string column with values like [Farm House, Hearty & Seasonal].", "Column 'period_day': category column with values like [morning, afternoon].", "Column 'Transaction': number column with values like [6103, 1259].", "Column 'weekday_weekend': category column with values like [weekday, weekend]."]
# [[-0.08219068 -0.0486263   0.04766127 ...  0.04557901 -0.00161175
#   -0.01149008]
#  [-0.0122666  -0.01376246  0.04516657 ...  0.02656305  0.05311577
#    0.00715522]
#  [-0.03293575 -0.05503218  0.00547417 ...  0.0143768   0.01695344
#   -0.03054428]
#  [-0.05087807 -0.08949442 -0.02292837 ...  0.02899839  0.01589013
#   -0.02733334]
#  [-0.03776284 -0.07195992  0.00255401 ...  0.00593903  0.01583193
#    0.02563415]]
# ["Column 'Rating': number column with values like [5, 1].", "Column 'Reviewer_Location': category column with values like [Malta, Canada].", "Column 'Year_Month': string column with values like [2017-9, 2011-10].", "Column 'Branch': category column with values like [Disneyland_Paris, Disneyland_California].", "Column 'Review_ID': number column with values like [540713188, 119781124]."]
# [[-0.05421139 -0.06967402  0.03435823 ...  0.06471504  0.0271218
#   -0.0182179 ]
#  [-0.00513678  0.00782894  0.02551243 ...  0.06512532 -0.00706039
#    0.02368396]
#  [-0.04851726 -0.02150157  0.03240228 ...  0.02469756  0.03422655
#    0.00140637]
#  [-0.02038872 -0.06454919  0.04357825 ...  0.02554892  0.00705763
#    0.02135933]
#  [-0.06902914 -0.04605324  0.00718046 ...  0.06645267  0.04239582
#   -0.01526178]]
# ["Column 'favorites': number column with values like [24, 460].", 'Column \'text\': text column with values like ["@IvankaTrump: Ivanka talks @trumpferrypoint with @foxbusiness! Watch the video: http://buff.ly/1HuXYuu\xa0 DonaldTrump @TrumpGolf #trumpgolf, Via @trscoop: “Mark Levin DEFENDS Trump: Hillary Clinton is a CROOK and a FRAUD and she’s not treated this way!”http://therightscoop.com/mark-levin-defends-trump-hillary-clinton-is-a-crook-and-a-fraud-and-shes-not-treated-this-way/\xa0…].', "Column 'author_name': category column with values like [Donald J. Trump, Donald J. Trump].", "Column 'date': date column with values like [2015-05-27T00:46:10.000Z, 2015-07-02T18:20:10.000Z].", "Column 'lang': category column with values like [en, en].", "Column 'id': number column with values like [603361519192174592, 616672730319069185].", "Column 'retweets': number column with values like [14, 376].", "Column 'author_handler': category column with values like [realDonaldTrump, realDonaldTrump].", 'Column \'mention_names\': list[category] column with values like [["IvankaTrump","trumpferrypoint","foxbusiness","TrumpGolf"], ["trscoop"]].', "Column 'rp_user_id': number column with values like [25073877.0]."]
# [[-0.07173052 -0.06108255 -0.00658195 ...  0.06811999  0.03781244
#   -0.01439444]
#  [-0.04807341  0.00870811 -0.04082464 ... -0.04524371  0.05428067
#    0.05859926]
#  [-0.0158102   0.0139072   0.01258244 ... -0.00247688  0.03219127
#    0.01017823]
#  ...
#  [-0.01452796  0.00127337 -0.00095863 ...  0.0174929   0.05595699
#    0.0095932 ]
#  [-0.02891671 -0.00572598  0.0149563  ...  0.01099948 -0.00263836
#    0.01765209]
#  [-0.04499375 -0.05296147 -0.01355022 ...  0.07109784  0.00330712
#   -0.03591548]]
# ["Column 'name': string column with values like [Christopher, Chris J. Headleand].", "Column 'weight': number column with values like [63.0, 7.0].", "Column 'x': number column with values like [1046.85985057688, -504.8607865514298].", "Column 'is_organization': boolean column with values like [False, False].", "Column 'community': number column with values like [16744206, 16744206].", "Column 'id': number column with values like [35070, 35046].", "Column 'page_rank_norm': number column with values like [0.0011644932467731, 0.0016400009027285].", "Column 'y': number column with values like [1511.9625723548768, 1708.065073048048].", "Column 'pic': url column with values like [https://storage.googleapis.com/pics.contexto.io/photos/paperclips/000/042/951/thumb/96c0590f41f0f9af2e4176b0f6890467_normal.jpeg?1517565061, https://storage.googleapis.com/pics.contexto.io/photos/paperclips/000/042/927/thumb/twitter_normal.jpg?1517565042]."]
# [[-0.05381766  0.00601203  0.03427682 ...  0.02799584  0.03714708
#    0.02034975]
#  [-0.07245797 -0.06208243 -0.01299041 ...  0.00012238  0.0251941
#   -0.00258951]
#  [-0.075838   -0.05067111  0.02906708 ...  0.05007713  0.04931311
#   -0.0084446 ]
#  ...
#  [-0.04949298 -0.06228021 -0.0079716  ...  0.02365752  0.02002349
#   -0.02002051]
#  [-0.05683996 -0.10201921  0.01903277 ...  0.04713014  0.01347684
#   -0.04200658]
#  [-0.05943973 -0.04762917  0.01535487 ...  0.04305549  0.01420263
#    0.02424446]]
# ["Column 'legs': number column with values like [2, 4].", "Column 'domestic': boolean column with values like [0, 0].", "Column 'breathes': boolean column with values like [1, 1].", "Column 'class_type': number column with values like [1, 1].", "Column 'venomous': boolean column with values like [0, 0].", "Column 'feathers': boolean column with values like [0, 0].", "Column 'animal_name': string column with values like [squirrel, oryx]."]
# [[-0.06434184 -0.06920657  0.02364346 ...  0.03918217  0.00713585
#   -0.0328634 ]
#  [-0.04302808 -0.06306642  0.00748873 ...  0.06837751  0.05889498
#    0.01715543]
#  [-0.0924302  -0.04599848  0.0237099  ...  0.08015587  0.03810641
#    0.03600339]
#  ...
#  [-0.07419033 -0.06621961 -0.03451381 ...  0.05411312  0.0698739
#    0.0009172 ]
#  [-0.08093512 -0.04944581 -0.01977327 ...  0.07891358  0.05313711
#    0.03781781]
#  [-0.02516475 -0.04895019  0.01655873 ...  0.04859645  0.02955339
#    0.0284801 ]]
# ["Column 'InvoiceNo': string column with values like [555200, 554974].", "Column 'Country': category column with values like [United Kingdom, United Kingdom].", "Column 'StockCode': string column with values like [71459, 21128].", "Column 'Description': text column with values like [HANGING JAM JAR T-LIGHT HOLDER, GOLD FISHING GNOME].", "Column 'Quantity': number column with values like [24, 4].", "Column 'CustomerID': number column with values like [17315.0, 14031.0].", "Column 'UnitPrice': number column with values like [0.85, 6.95]."]
# [[-0.06962353 -0.05837858 -0.04164274 ...  0.07052189  0.03160601
#   -0.00415309]
#  [ 0.00255745 -0.0442646   0.04698784 ...  0.04473112  0.02030739
#   -0.00814056]
#  [-0.0647974  -0.06085122 -0.04380796 ... -0.01133267  0.03008297
#   -0.01791731]
#  ...
#  [-0.03247913 -0.07747146 -0.01055683 ...  0.02968535  0.03467344
#   -0.00027045]
#  [-0.03732521 -0.07783736  0.00736006 ...  0.0389936   0.02686042
#   -0.02091765]
#  [-0.04131688 -0.06377126 -0.00512898 ... -0.01110427  0.02127781
#   -0.006052  ]]

# %% [markdown]
# ## Print Indexed Datasets

# %%
print("Indexed datasets:", list(dataset_faiss_store.keys()))
# Out:
# Indexed datasets: ['001_Forbes', '002_Titanic', '004_Taxi', '005_NYC', '006_London', '007_Fifa', '008_Tornados', '009_Central', '010_ECommerce', '011_SF', '012_Heart', '013_Roller', '015_Food', '016_Holiday', '017_Hacker', '018_Staff', '019_Aircraft', '021_Telco', '022_Airbnbs', '023_Climate', '024_Salary', '025_Data', '026_Predicting', '027_Supermarket', '028_Predict', '029_NYTimes', '030_Professionals', '031_Trustpilot', '032_Delicatessen', '033_Employee', '034_World', '036_US', '037_Ted', '038_Stroke', '039_Happy', '040_Speed', '041_Airline', '042_Predict', '043_Predict', '044_IMDb', '045_Predict', '046_120', '047_Bank', '048_Data', '050_ING', '051_Pokemon', '052_Professional', '053_Patents', '055_German', '056_Emoji', '057_Spain', '058_US', '059_Second', '060_Bakery', '061_Disneyland', '062_Trump', '063_Influencers', '064_Clustering', '065_RFM']

# %% [markdown]
# ## Util Function to Retrieve Top-K columns for a question

# %%
# Retrieve top-k most relevant columns for a question
def retrieve_columns_for_question(dataset_name: str, question: str, k: int = 3) -> List[str]:
    dataset = dataset_faiss_store[dataset_name]
    index = dataset["index"]
    columns = dataset["columns"]

    q_emb = embedder.encode([question], convert_to_numpy=True)
    faiss.normalize_L2(q_emb)

    scores, indices = index.search(q_emb, k)
    return [columns[i] for i in indices[0]]

# %% [markdown]
# ## Ignore for now [Exploration]

# %%
missing_expected_cols = []
for sample in semeval_train:
    dataset = sample['dataset']
    question = sample['question']
    expected_columns = sample['columns_used']

    if dataset in unique_train_datasets:

      df_cols = train_dataset_map[dataset].columns.tolist()

      cols = retrieve_columns_for_question(dataset, question, 4)



      # Validate that all retrieved columns exist in the dataset
      missing_cols = [col for col in cols if col not in df_cols]
      expected_col = []
      expected_col = [col for col in expected_col if col not in cols]

      if expected_col:
          missing_expected_cols.append(expected_col)
      else:
          missing_expected_cols.append([])

      if missing_cols:
          raise ValueError(
              f"Retrieved columns not found in dataset '{dataset}': {missing_cols}\n"
              f"Available columns: {df_cols}"
          )
      #print(f"Dataset: {dataset}, question: {question}, Columns returned: {cols}")

print(missing_expected_cols)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-c655221da8a7> in <cell line: 0>()
#       9       df_cols = train_dataset_map[dataset].columns.tolist()
#      10
# ---> 11       cols = retrieve_columns_for_question(dataset, question, 4)
#      12
#      13
#
# <ipython-input-131-a041b4976645> in retrieve_columns_for_question(dataset_name, question, k)
#       5     columns = dataset["columns"]
#       6
# ----> 7     q_emb = embedder.encode([question], convert_to_numpy=True)
#       8     faiss.normalize_L2(q_emb)
#       9
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     621
#     622             with torch.no_grad():
# --> 623                 out_features = self.forward(features, **kwargs)
#     624                 if self.device.type == "hpu":
#     625                     out_features = copy.deepcopy(out_features)
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/SentenceTransformer.py in forward(self, input, **kwargs)
#     688             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     689             module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 690             input = module(input, **module_kwargs)
#     691         return input
#     692
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features, **kwargs)
#     440         }
#     441
# --> 442         output_states = self.auto_model(**trans_features, **kwargs, return_dict=False)
#     443         output_tokens = output_states[0]
#     444
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1142         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1143
# -> 1144         encoder_outputs = self.encoder(
#    1145             embedding_output,
#    1146             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     693                 )
#     694             else:
# --> 695                 layer_outputs = layer_module(
#     696                     hidden_states,
#     697                     attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     625             present_key_value = present_key_value + cross_attn_present_key_value
#     626
# --> 627         layer_output = apply_chunking_to_forward(
#     628             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     629         )
#
# /usr/local/lib/python3.11/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     251         return torch.cat(output_chunks, dim=chunk_dim)
#     252
# --> 253     return forward_fn(*input_tensors)
#     254
#     255
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/bert/modeling_bert.py in feed_forward_chunk(self, attention_output)
#     638     def feed_forward_chunk(self, attention_output):
#     639         intermediate_output = self.intermediate(attention_output)
# --> 640         layer_output = self.output(intermediate_output, attention_output)
#     641         return layer_output
#     642
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1733         return result
#    1734
# -> 1735     def _wrapped_call_impl(self, *args, **kwargs):
#    1736         if self._compiled_call_impl is not None:
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:

# %% [markdown]
# ## SET LLM MODEL

# %%
# GROQ_MODEL = "llama3-70b-8192"

# %%
def generate_model_response(prompt):
    """
    Generates a response using Groq (LLaMA-3) or OpenAI (GPT-3.5).
    Falls back across multiple Groq keys if needed.
    """
    if USE_GROQ:
        for attempt in range(len(groq_clients)):
            groq_client = next(groq_client_cycle)

            try:
                response = groq_client.chat.completions.create(
                    model=GROQ_MODEL,
                    messages=[{"role": "user", "content": prompt}],
                    temperature=0.7,
                    max_tokens=512,
                    top_p=1.0
                )
                return response.choices[0].message.content

            except Exception as e:
                print(f"[Groq Attempt {attempt + 1}] Error: {e}")
                continue

        return "All Groq API keys exhausted or rate limited."

    else:
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.7,
                max_tokens=512,
                top_p=1.0
            )
            return response.choices[0].message["content"]

        except Exception as e:
            return f"OpenAI request failed: {e}"

# %% [markdown]
# ## Util functions to Process Retrieved Model Response

# %%
def normalize_number(value):
    if isinstance(value, (int, float)):
        return float(value)
    if isinstance(value, str):
        return float(value.strip())
    raise ValueError(f"Expected numeric type for number, got: {type(value)}")

def normalize_category(value):
    if isinstance(value, str):
        return value.strip()
    raise ValueError(f"Expected string for category, got: {type(value)}")

def normalize_boolean(value):
    if isinstance(value, bool):
        return value
    if isinstance(value, str):
        val = value.strip().lower()
        if val in {"true", "1", "yes"}:
            return True
        elif val in {"false", "0", "no"}:
            return False
        else:
            raise ValueError(f"Unrecognized string for boolean: {value!r}")
    if isinstance(value, (int, float)):
        if value == 1:
            return True
        elif value == 0:
            return False
        else:
            raise ValueError(f"Numeric value not valid for boolean: {value}")
    raise ValueError(f"Expected bool, int, float, or string for boolean, got: {type(value)}")

# %%
def normalize_list_category(answer):
    """
    Normalize an answer of type list[category] into a set of cleaned strings.
    Handles both true lists and stringified list representations,
    and removes stray square brackets from individual elements.
    """
    def clean_item(x):
        x = str(x).strip()
        if x.startswith("["):
            x = x[1:]
        if x.endswith("]"):
            x = x[:-1]
        return x.strip()
    if isinstance(answer, str):
        try:
            parsed = ast.literal_eval(answer)
            if isinstance(parsed, list):
                answer = parsed
            else:
                answer = [item.strip() for item in answer.split(",") if item.strip()]
        except:
            answer = [item.strip() for item in answer.split(",") if item.strip()]
    if isinstance(answer, list):
        return set(clean_item(x) for x in answer)
    return set()  # fallback

# %%
def normalize_list_number(value):
    """
    Normalizes a predicted or gold value for list[number] questions.

    Expected input:
    - a string representing a list of numbers, e.g., "[2, 2, 2]"
    - OR a Python list of numbers
    - OR a stringified CSV like "2, 2, 2"

    Returns:
    - A set of floats
    """
    try:
        if isinstance(value, str):
            try:
                # Try parsing as JSON list
                value = json.loads(value)
            except json.JSONDecodeError:
                try:
                    value = ast.literal_eval(value)
                except:
                    # fallback: comma-separated
                    value = [item.strip() for item in value.split(",") if item.strip()]
        return set(float(v) for v in value)
    except Exception as e:
        print(f"normalize_list_number error: {e}")
        return None

# %%
def normalize_answer(value, expected_type):
    """
    Dispatches to the appropriate normalization function based on expected_type.
    """
    try:
        if expected_type == "number":
            return normalize_number(value)
        elif expected_type == "category":
            return normalize_category(value)
        elif expected_type == "boolean":
            return normalize_boolean(value)
        elif expected_type == "list[category]":
            return normalize_list_category(value)
        elif expected_type == "list[number]":
            return normalize_list_number(value)
        else:
            raise ValueError(f"Unsupported expected type: {expected_type}")
    except Exception as e:
        print(f"normalize_answer error for type '{expected_type}': {e}")
        return None

# %%
def normalize_columns(value):
    """
    Normalize a gold or predicted column list into a set of strings,
    preserving casing and special characters.
    """
    try:
        if isinstance(value, str):
            # Try parsing as a list
            try:
                parsed = ast.literal_eval(value)
                if isinstance(parsed, list):
                    value = parsed
                else:
                    # fallback: comma-split string
                    value = [item.strip() for item in value.split(",") if item.strip()]
            except:
                value = [item.strip() for item in value.split(",") if item.strip()]

        if isinstance(value, list):
            return set(str(x).strip() for x in value)

    except Exception as e:
        print(f"normalize_columns error: {e}")

    return set()  # fallback

# %% [markdown]
# ## Process the Raw LLM Response

# %%
import json
import ast

def process_response(generated_text, question, expected_type, error_set):
    """
    Processes the raw LLM response to extract and normalize the answer and columns.

    Args:
        generated_text (str): Raw text output from the LLM.
        question (str): The question (used for debugging).
        expected_type (str): The expected type of the answer (e.g., boolean, number).
        error_set (set): A set to store questions that had format errors.

    Returns:
        Tuple[bool, Any, List[str]]:
            - is_error (bool): True if formatting/parsing failed.
            - norm_answer: normalized answer or None on failure.
            - norm_columns: normalized list of columns or [] on failure.
    """
    is_error = False
    norm_answer = None
    norm_columns = []

    try:
        # Step 1: Trim response
        generated_text = generated_text.strip()

        # Step 2: Try to isolate a dictionary from the output
        start = generated_text.find('{')
        end = generated_text.rfind('}') + 1
        if start == -1 or end == -1:
            raise ValueError("Could not find a JSON-like object")

        json_str = generated_text[start:end]

        # Fix lowercase true/false if needed
        json_str_fixed = json_str.replace("true", "True").replace("false", "False")

        # Step 3: Try parsing as JSON first, fallback to ast.literal_eval
        try:
            response_json = json.loads(json_str)
        except json.JSONDecodeError:
            response_json = ast.literal_eval(json_str_fixed)

        # Step 4: Ensure expected keys exist
        if "answer" not in response_json or "columns_used" not in response_json:
            raise KeyError("Missing 'answer' or 'columns_used' in response")

        raw_answer = response_json["answer"]
        raw_columns = response_json["columns_used"]

        # Step 5: Normalize both fields
        norm_answer = normalize_answer(raw_answer, expected_type)
        norm_columns = normalize_columns(raw_columns)

    except Exception as e:
        # On any failure, flag error and return safe defaults
        print(f"[process_response] Failed to parse response for question: {question}")
        print(f"Error: {e}")
        is_error = True
        error_set.add(question)
        norm_answer = None
        norm_columns = []

    # Return tuple: (was error?, normalized answer, normalized columns)
    return is_error, norm_answer, norm_columns

# %%
def safe_generate_response(prompt, retries=1, delay=3):
    attempts = 0
    while attempts <= retries:
        try:
            return generate_model_response(prompt)
        except Exception as e:
            print(f"[Attempt {attempts+1}] Error: {repr(e)}")
            time.sleep(delay)
            attempts += 1
    print("Failed all attempts. Returning empty response.")
    return ""

# %% [markdown]
# ## Evaluate Generated Response Over Dataset

# %%
def evaluate_dataset(dataset_rows, dataset_name, dev_dataset_map, request_delay=1.5):
    pred_answers = []
    gold_answers = []
    pred_columns = []
    gold_columns = []
    question_types = []

    type_wise_correct = defaultdict(int)
    type_wise_total = defaultdict(int)
    column_match_count = 0
    error_set = set()
    formatting_errors_by_type = defaultdict(int)

    print(f"# Questions in {dataset_name}: {len(dataset_rows)}")

    for i, row in enumerate(dataset_rows):
        print(f"\n--- Query {i+1}/{len(dataset_rows)} ---")

        question = row["question"]
        dataset = row["dataset"]
        expected_type = row["type"]

        gold_answer = normalize_answer(row["sample_answer"], expected_type)
        gold_cols = normalize_columns(row["columns_used"])

        df = dev_dataset_map[dataset]
        # Retrieve top-k relevant columns for this question
        retrieved_cols = retrieve_columns_for_question(dataset, question, k=4)

        reduced_df = df[retrieved_cols]

        prompt = build_prompt(reduced_df, question)


        response = safe_generate_response(prompt)
        time.sleep(request_delay)
        print("\n--- Raw LLM Response ---")
        print(response)

        is_error, pred_answer, pred_cols = process_response(response, question, expected_type, error_set)
        if is_error:
            formatting_errors_by_type[expected_type] += 1

        print(f"\nQuestion: {question}")
        print(f"Pred Answer: {pred_answer}, Gold Answer: {gold_answer}")
        print(f"Pred Columns: {pred_cols}, Gold Columns: {gold_cols}")

        pred_answers.append(pred_answer)
        gold_answers.append(gold_answer)
        pred_columns.append(pred_cols)
        gold_columns.append(gold_cols)
        question_types.append(expected_type)
        type_wise_total[expected_type] += 1

        correct = False
        try:
            if expected_type == "number":
                correct = abs(pred_answer - gold_answer) < 1e-3
            else:
                correct = pred_answer == gold_answer
        except:
            correct = False

        if correct:
            type_wise_correct[expected_type] += 1

        if isinstance(pred_cols, (list, set)) and set(pred_cols) == set(gold_cols):
            column_match_count += 1

    print("\n=== Answer Accuracy by Type ===")
    for qtype in type_wise_total:
        total = type_wise_total[qtype]
        correct = type_wise_correct[qtype]
        acc = correct / total if total else 0
        print(f"{qtype:15}: {acc:.2%} ({correct}/{total})")

    total = len(dataset_rows)
    col_acc = column_match_count / total if total else 0
    print(f"\n=== Column Selection Accuracy ===\n{col_acc:.2%} ({column_match_count}/{total})")

    eval_records = []
    for i in range(len(dataset_rows)):
        eval_records.append({
            "type": question_types[i],
            "gold_answer": gold_answers[i],
            "pred_answer": pred_answers[i],
            "gold_columns": gold_columns[i],
            "pred_columns": pred_columns[i],
        })

    # Final column stats
    wrong_cols = 0
    right_cols = 0
    format_errors = 0
    for i, (pred, gold) in enumerate(zip(pred_columns, gold_columns)):
        question = dataset_rows[i]["question"]

        if question in error_set:
            format_errors += 1
            continue

        if isinstance(pred, (list, set)):
            if set(pred) == set(gold):
                right_cols += 1
            else:
                wrong_cols += 1
        else:
            format_errors += 1  # fallback, shouldn't happen


    column_stats = {
        "wrong_cols": wrong_cols,
        "right_cols": right_cols,
        "format_error": format_errors,
        "total": len(dataset_rows)
    }

    return eval_records, column_stats, formatting_errors_by_type

# %% [markdown]
# ## Metrics Computation

# %%
def compute_metrics(eval_records, model_name, model_results):
    results = defaultdict(float)
    total = len(eval_records)
    correct_all = 0
    typewise = defaultdict(lambda: [0, 0])
    colwise = {'single': [0, 0], 'multi': [0, 0]}

    for record in eval_records:
        t = record['type'].strip().lower()
        gold_answer = record['gold_answer']
        pred_answer = record['pred_answer']
        gold_cols = set(record['gold_columns'])
        pred_cols = set(record['pred_columns'])

        try:
            if t == "number":
                answer_match = abs(pred_answer - gold_answer) < 1e-3
            else:
                answer_match = pred_answer == gold_answer
        except:
            answer_match = False

        col_match = gold_cols == pred_cols
        joint_match = answer_match and col_match
        if joint_match:
            correct_all += 1

        typewise[t][1] += 1
        if joint_match:
            typewise[t][0] += 1

        col_count = len(gold_cols)
        if col_count == 1:
            colwise['single'][1] += 1
            if joint_match:
                colwise['single'][0] += 1
        else:
            colwise['multi'][1] += 1
            if joint_match:
                colwise['multi'][0] += 1

    def get_acc(dic, key):
        correct, total = dic[key]
        return correct / total if total else 0

    results['avg'] = correct_all / total if total else 0
    results['boolean'] = get_acc(typewise, 'boolean')
    results['number'] = get_acc(typewise, 'number')
    results['category'] = get_acc(typewise, 'category')
    results['list[category]'] = get_acc(typewise, 'list[category]')
    results['list[number]'] = get_acc(typewise, 'list[number]')
    results['single col'] = get_acc(colwise, 'single')
    results['multiple cols'] = get_acc(colwise, 'multi')

    model_results[model_name] = dict(results)

# %%
def format_percent_and_count(val, total):
    percent = 100 * val / total if total else 0
    return f"{percent:.1f} ({val})"

# %% [markdown]
# ## Trigger Pipeline (Iterates over each dataset one after another)

# %%
print(len(unique_train_datasets))
# Out:
# 59

# %%
model_results = {}
column_quality_table = []
formatting_errors_summary = defaultdict(int)

for dataset_id in unique_train_datasets:

    dataset_rows = semeval_train.filter(lambda sample: sample["dataset"] == dataset_id)
    print(f"\n\n### Evaluating {dataset_id} ###")

    records, col_stats, formatting_errors_by_type = evaluate_dataset(
        dataset_rows, dataset_name=dataset_id, dev_dataset_map=train_dataset_map
    )

    compute_metrics(records, dataset_id, model_results)

    column_quality_table.append({
        "model": dataset_id,
        "wrong cols": format_percent_and_count(col_stats["wrong_cols"], col_stats["total"]),
        "right cols": format_percent_and_count(col_stats["right_cols"], col_stats["total"]),
        "format error": format_percent_and_count(col_stats["format_error"], col_stats["total"]),
    })

    for qtype, count in formatting_errors_by_type.items():
        formatting_errors_summary[qtype] += count
# Out:
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 001_Forbes ###
# # Questions in 001_Forbes: 25
#
# --- Query 1/25 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["selfMade", "finalWorth"]}
#
# Question: Is the person with the highest net worth self-made?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'finalWorth', 'selfMade'}, Gold Columns: {'selfMade', 'finalWorth'}
#
# --- Query 2/25 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["gender", "philanthropyScore"]}
#
# Question: Does the youngest billionaire identify as male?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'gender', 'philanthropyScore'}, Gold Columns: {'age', 'gender'}
#
# --- Query 3/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": "Atlanta",
# "columns_used": ["city", "country"]
# }
# normalize_answer error for type 'boolean': Unrecognized string for boolean: 'Atlanta'
#
# Question: Is the city with the most billionaires in the United States?
# Pred Answer: None, Gold Answer: True
# Pred Columns: {'country', 'city'}, Gold Columns: {'country', 'city'}
#
# --- Query 4/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["selfMade", "rank"]
# }
#
# Question: Is there a non-self-made billionaire in the top 5 ranks?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'rank', 'selfMade'}, Gold Columns: {'rank', 'selfMade'}
#
# --- Query 5/25 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["philanthropyScore"]}
#
# Question: Does the oldest billionaire have a philanthropy score of 5?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'philanthropyScore'}, Gold Columns: {'age', 'philanthropyScore'}
#
# --- Query 6/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": 32.0,
# "columns_used": ["age"]
# }
#
# Question: What is the age of the youngest billionaire?
# Pred Answer: 32.0, Gold Answer: 32.0
# Pred Columns: {'age'}, Gold Columns: {'age'}
#
# --- Query 7/25 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["category"]}
#
# Question: How many billionaires are there from the 'Technology' category?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: {'category'}, Gold Columns: {'category'}
#
# --- Query 8/25 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["category", "philanthropyScore"]}
#
# Question: What's the total worth of billionaires in the 'Automotive' category?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: {'philanthropyScore', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# --- Query 9/25 ---
#
# --- Raw LLM Response ---
# {"answer": 1, "columns_used": ["philanthropyScore"]}
#
# Question: How many billionaires have a philanthropy score above 3?
# Pred Answer: 1.0, Gold Answer: 0.0
# Pred Columns: {'philanthropyScore'}, Gold Columns: {'philanthropyScore'}
#
# --- Query 10/25 ---
#
# --- Raw LLM Response ---
# {"answer": 288, "columns_used": ["rank", "finalWorth"]}
#
# Question: What's the rank of the wealthiest non-self-made billionaire?
# Pred Answer: 288.0, Gold Answer: 288.0
# Pred Columns: {'rank', 'finalWorth'}, Gold Columns: {'rank', 'selfMade'}
#
# --- Query 11/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": "Media & Entertainment",
# "columns_used": ["category", "philanthropyScore"]
# }
#
# Question: Which category does the richest billionaire belong to?
# Pred Answer: Media & Entertainment, Gold Answer: Food & Beverage
# Pred Columns: {'philanthropyScore', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# --- Query 12/25 ---
#
# --- Raw LLM Response ---
# {"answer": "United States", "columns_used": ["country"]}
#
# Question: What's the country of origin of the oldest billionaire?
# Pred Answer: United States, Gold Answer: United Kingdom
# Pred Columns: {'country'}, Gold Columns: {'age', 'country'}
#
# --- Query 13/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": {"gender": "M"},
# "columns_used": ["philanthropyScore", "gender"]
# }
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: What's the gender of the billionaire with the highest philanthropy score?
# Pred Answer: None, Gold Answer: M
# Pred Columns: {'gender', 'philanthropyScore'}, Gold Columns: {'gender', 'philanthropyScore'}
#
# --- Query 14/25 ---
#
# --- Raw LLM Response ---
# {"answer": {"source": "diversified", "age": 32.0}, "columns_used": ["source", "age"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: What's the source of wealth for the youngest billionaire?
# Pred Answer: None, Gold Answer: fintech
# Pred Columns: {'age', 'source'}, Gold Columns: {'age', 'source'}
#
# --- Query 15/25 ---
# normalize_answer error for type 'category': Expected string for category, got: <class 'NoneType'>
#
# --- Raw LLM Response ---
# {
# "answer": null,
# "columns_used": ["title", "rank"]
# }
# normalize_answer error for type 'category': Expected string for category, got: <class 'NoneType'>
#
# Question: What is the title of the billionaire with the lowest rank?
# Pred Answer: None, Gold Answer: None
# Pred Columns: {'rank', 'title'}, Gold Columns: {'rank', 'title'}
#
# --- Query 16/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": {
# "rank": [1196, 2076, 288]
# },
# "columns_used": ["country", "rank"]
# }
#
# Question: List the top 3 countries with the most billionaires.
# Pred Answer: set(), Gold Answer: {'China', 'United States', 'Brazil'}
# Pred Columns: {'rank', 'country'}, Gold Columns: {'country'}
#
# --- Query 17/25 ---
#
# --- Raw LLM Response ---
# {"answer": {"Food & Beverage": 3, "Finance & Investments": 2}, "columns_used": ["source"]}
#
# Question: List the top 2 most common sources of wealth for billionaires.
# Pred Answer: set(), Gold Answer: {'media, automotive', 'diversified'}
# Pred Columns: {'source'}, Gold Columns: {'source'}
#
# --- Query 18/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": ["Atlanta", "Ningbo", "Wuhan", "São Paulo"],
# "columns_used": ["city"]
# }
#
# Question: List the 4 cities where the four youngest billionaires live.
# Pred Answer: {'Atlanta', 'São Paulo', 'Wuhan', 'Ningbo'}, Gold Answer: {'Bangalore', 'San Francisco', 'New York', 'Wuhan'}
# Pred Columns: {'city'}, Gold Columns: {'age', 'city'}
#
# --- Query 19/25 ---
#
# --- Raw LLM Response ---
# {"answer": ["Manufacturing", "Food & Beverage", "Finance & Investments", "Service"], "columns_used": ["category"]}
#
# Question: List the 4 categories with the fewest billionaires.
# Pred Answer: {'Manufacturing', 'Finance & Investments', 'Food & Beverage', 'Service'}, Gold Answer: {'Manufacturing', 'Service', 'Real Estate', 'Fashion & Retail'}
# Pred Columns: {'category'}, Gold Columns: {'category'}
#
# --- Query 20/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": [
# "China",
# "Brazil"
# ],
# "columns_used": ["country"]
# [process_response] Failed to parse response for question: List the 2 countries with the least number of billionaires. If there are more than two with the same number take the first two alphabetically.
# Error: invalid syntax (<unknown>, line 0)
#
# Question: List the 2 countries with the least number of billionaires. If there are more than two with the same number take the first two alphabetically.
# Pred Answer: None, Gold Answer: {'Egypt', 'Canada'}
# Pred Columns: [], Gold Columns: {'country'}
#
# --- Query 21/25 ---
#
# --- Raw LLM Response ---
# {"answer": 2076, "columns_used": ["rank"]}
# normalize_list_number error: 'int' object is not iterable
#
# Question: List the top 5 ranks of billionaires who are not self-made.
# Pred Answer: None, Gold Answer: {288.0, 296.0, 523.0, 601.0, 509.0}
# Pred Columns: {'rank'}, Gold Columns: {'rank', 'selfMade'}
#
# --- Query 22/25 ---
#
# --- Raw LLM Response ---
# {"answer": [], "columns_used": ["age", "philanthropyScore"]}
#
# Question: List the youngest 3 ages of billionaires who have a philanthropy score of 5.
# Pred Answer: set(), Gold Answer: set()
# Pred Columns: {'age', 'philanthropyScore'}, Gold Columns: {'age', 'philanthropyScore'}
#
# --- Query 23/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": [],
# "columns_used": ["finalWorth", "category"]
# }
#
# Question: List the highest 6 final worth values of billionaires in the 'Technology' category.
# Pred Answer: set(), Gold Answer: set()
# Pred Columns: {'finalWorth', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# --- Query 24/25 ---
#
# --- Raw LLM Response ---
# {"answer": [{"rank": 288}, {"rank": 523}], "columns_used": ["rank", "gender"]}
# normalize_list_number error: float() argument must be a string or a real number, not 'dict'
#
# Question: List the top 4 ranks of female billionaires.
# Pred Answer: None, Gold Answer: set()
# Pred Columns: {'rank', 'gender'}, Gold Columns: {'rank', 'gender'}
#
# --- Query 25/25 ---
#
# --- Raw LLM Response ---
# {
# "answer": null,
# "columns_used": ["finalWorth", "category"]
# }
# normalize_list_number error: 'NoneType' object is not iterable
#
# Question: List the top 2 final worth values of billionaires in the 'Automotive' category.
# Pred Answer: None, Gold Answer: set()
# Pred Columns: {'finalWorth', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# === Answer Accuracy by Type ===
# boolean        : 60.00% (3/5)
# number         : 80.00% (4/5)
# category       : 20.00% (1/5)
# list[category] : 0.00% (0/5)
# list[number]   : 40.00% (2/5)
#
# === Column Selection Accuracy ===
# 60.00% (15/25)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 002_Titanic ###
# # Questions in 002_Titanic: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Age", "Survived"]}
#
# Question: Did any children below the age of 18 survive?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Age', 'Survived'}, Gold Columns: {'Age', 'Survived'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["Fare"]
# }
#
# Question: Were there any passengers who paid a fare of more than $500?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Fare'}, Gold Columns: {'Fare'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["Name"]}
#
# Question: Is every passenger's name unique?
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'Name'}, Gold Columns: {'Name'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["Pclass", "Survived"]}
#
# Question: Were there any female passengers in the 3rd class who survived?
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'Pclass', 'Survived'}, Gold Columns: {'Pclass', 'Sex', 'Survived'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3, "columns_used": ["Pclass"]}
#
# Question: How many unique passenger classes are present in the dataset?
# Pred Answer: 3.0, Gold Answer: 3.0
# Pred Columns: {'Pclass'}, Gold Columns: {'Pclass'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 69.0, "columns_used": ["Age"]}
#
# Question: What's the maximum age of the passengers?
# Pred Answer: 69.0, Gold Answer: 69.0
# Pred Columns: {'Age'}, Gold Columns: {'Age'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {
#   "answer": 14,
#   "columns_used": ["Siblings_Spouses Aboard", "Sex"]
# }
#
# Question: How many passengers boarded without any siblings or spouses?
# Pred Answer: 14.0, Gold Answer: 12.0
# Pred Columns: {'Sex', 'Siblings_Spouses Aboard'}, Gold Columns: {'Siblings_Spouses Aboard'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 23.1347, "columns_used": ["Fare"]}
#
# Question: On average, how much fare did the passengers pay?
# Pred Answer: 23.1347, Gold Answer: 23.096459999999997
# Pred Columns: {'Fare'}, Gold Columns: {'Fare'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 1,
# "columns_used": ["Pclass", "Survived"]
# }
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: Which passenger class has the highest number of survivors?
# Pred Answer: None, Gold Answer: 3
# Pred Columns: {'Pclass', 'Survived'}, Gold Columns: {'Pclass', 'Survived'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": "female", "columns_used": ["Sex", "Survived"]}
#
# Question: What's the most common gender among the survivors?
# Pred Answer: female, Gold Answer: female
# Pred Columns: {'Sex', 'Survived'}, Gold Columns: {'Sex', 'Survived'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": {"0-50": 6, "50-100": 2, "100-150": 0, "150+": 2},
# "columns_used": ["Fare", "Survived"]
# }
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: Among those who survived, which fare range was the most common: (0-50, 50-100, 100-150, 150+)?
# Pred Answer: None, Gold Answer: 0-50
# Pred Columns: {'Survived', 'Fare'}, Gold Columns: {'Survived', 'Fare'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": {
# "0-18": 3,
# "18-30": 5,
# "30-50": 4,
# "50+": 8
# },
# "columns_used": ["Age"]
# }
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: What's the most common age range among passengers: (0-18, 18-30, 30-50, 50+)?
# Pred Answer: None, Gold Answer: 18-30
# Pred Columns: {'Age'}, Gold Columns: {'Age'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"Pclass": 1, "survival_rate": 0.75}, {"Pclass": 2, "survival_rate": 0.33}, {"Pclass": 3, "survival_rate": 0.33}], "columns_used": ["Pclass", "Survived"]}
#
# Question: Name the top 3 passenger classes by survival rate.
# Pred Answer: {"{'Pclass': 3, 'survival_rate': 0.33}", "{'Pclass': 2, 'survival_rate': 0.33}", "{'Pclass': 1, 'survival_rate': 0.75}"}, Gold Answer: {'1', '3', '2'}
# Pred Columns: {'Pclass', 'Survived'}, Gold Columns: {'Pclass', 'Survived'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"0-50": 4}, {"50-100": 3}, {"100-150": 0, "150+": 0}], "columns_used": ["Fare"]}
#
# Question: Could you list the 3 fare ranges present in the dataset with the least survivors: (0-50, 50-100, 100-150, 150+)?
# Pred Answer: {"{'50-100': 3}", "{'100-150': 0, '150+': 0}", "{'0-50': 4}"}, Gold Answer: {'100-150', '0-50'}
# Pred Columns: {'Fare'}, Gold Columns: {'Survived', 'Fare'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [
# {"30-50": 3, "50+": 2},
# {"answer": 5, "columns_used": ["Age", "Survived"]}
# [process_response] Failed to parse response for question: What are the top 4 age ranges ('30-50', '18-30', '0-18', '50+') with the highest number of survivors?
# Error: '[' was never closed (<unknown>, line 2)
#
# Question: What are the top 4 age ranges ('30-50', '18-30', '0-18', '50+') with the highest number of survivors?
# Pred Answer: None, Gold Answer: {'30-50', '18-30', '50+', '0-18'}
# Pred Columns: [], Gold Columns: {'Age', 'Survived'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"male": 24.535, "female": 29.175}, "columns_used": ["Fare", "Sex"]}
#
# Question: What are the top 2 genders by average fare paid?
# Pred Answer: set(), Gold Answer: {'female', 'male'}
# Pred Columns: {'Sex', 'Fare'}, Gold Columns: {'Sex', 'Fare'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [56.0, 47.0, 34.0], "columns_used": ["Age", "Survived"]}
#
# Question: What are the oldest 3 ages among the survivors?
# Pred Answer: {56.0, 34.0, 47.0}, Gold Answer: {56.0, 42.0, 47.0}
# Pred Columns: {'Age', 'Survived'}, Gold Columns: {'Age', 'Survived'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [20.525, 39.0, 133.65, 26.55], "columns_used": ["Fare", "Survived"]}
#
# Question: Which are the top 4 fares paid by survivors?
# Pred Answer: {26.55, 20.525, 133.65, 39.0}, Gold Answer: {35.5, 133.65, 30.5, 39.0}
# Pred Columns: {'Survived', 'Fare'}, Gold Columns: {'Survived', 'Fare'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [14.0, 17.0, 24.0], "columns_used": ["Age"]}
#
# Question: Could you list the youngest 3 ages among the survivors?
# Pred Answer: {24.0, 17.0, 14.0}, Gold Answer: {24.0, 28.0, 14.0}
# Pred Columns: {'Age'}, Gold Columns: {'Age', 'Survived'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [0.0, 7.75, 7.2292, 8.05], "columns_used": ["Fare"]}
#
# Question: Which are the lowest 4 fares among those who didn't survive?
# Pred Answer: {0.0, 8.05, 7.2292, 7.75}, Gold Answer: {0.0, 8.05, 7.75, 7.22}
# Pred Columns: {'Fare'}, Gold Columns: {'Survived', 'Fare'}
#
# === Answer Accuracy by Type ===
# boolean        : 50.00% (2/4)
# number         : 50.00% (2/4)
# category       : 25.00% (1/4)
# list[category] : 0.00% (0/4)
# list[number]   : 0.00% (0/4)
#
# === Column Selection Accuracy ===
# 70.00% (14/20)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 004_Taxi ###
# # Questions in 004_Taxi: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["trip_distance"]}
#
# Question: Are there any trips with a total distance greater than 30 miles?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'trip_distance'}, Gold Columns: {'trip_distance'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": true,
# "columns_used": ["fare_amount"]
# }
#
# Question: Were there any trips that cost more than $100 in total?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'fare_amount'}, Gold Columns: {'total_amount'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["passenger_count"]
# }
#
# Question: Is there any trip with more than 6 passengers?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'passenger_count'}, Gold Columns: {'passenger_count'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": true, "columns_used": ["payment_type"]}
#
# Question: Did all the trips use a payment type of either 1 or 2?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'payment_type'}, Gold Columns: {'payment_type'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 40.8,
# "columns_used": ["fare_amount"]
# }
#
# Question: What is the maximum fare amount charged for a trip?
# Pred Answer: 40.8, Gold Answer: 40.8
# Pred Columns: {'fare_amount'}, Gold Columns: {'fare_amount'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 11, "columns_used": ["PULocationID"]}
#
# Question: How many unique pickup locations are in the dataset?
# Pred Answer: 11.0, Gold Answer: 18.0
# Pred Columns: {'PULocationID'}, Gold Columns: {'PULocationID'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 2.8333333333333335, "columns_used": ["tip_amount"]}
#
# Question: What is the average tip amount given by passengers?
# Pred Answer: 2.8333333333333335, Gold Answer: 1.5
# Pred Columns: {'tip_amount'}, Gold Columns: {'tip_amount'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 11, "columns_used": ["DOLocationID", "trip_distance"]}
#
# Question: How many trips took place in the airport area?
# Pred Answer: 11.0, Gold Answer: 0.0
# Pred Columns: {'DOLocationID', 'trip_distance'}, Gold Columns: {'Airport_fee'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": 1.0, "columns_used": ["payment_type"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'float'>
#
# Question: Which payment type is the most common in the dataset?
# Pred Answer: None, Gold Answer: 1
# Pred Columns: {'payment_type'}, Gold Columns: {'payment_type'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {
#     "answer": 2.0,
#     "columns_used": ["VendorID"]
# }
# normalize_answer error for type 'category': Expected string for category, got: <class 'float'>
#
# Question: Which vendor has the most trips recorded?
# Pred Answer: None, Gold Answer: 2
# Pred Columns: {'VendorID'}, Gold Columns: {'VendorID'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"DOLocationID": 90.0}, "columns_used": ["DOLocationID"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: What is the most common drop-off location?
# Pred Answer: None, Gold Answer: 90
# Pred Columns: {'DOLocationID'}, Gold Columns: {'DOLocationID'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "2023-02-01T02:59:27Z", "columns_used": ["tpep_pickup_datetime"]}
#
# Question: On which date did the first recorded trip occur?
# Pred Answer: 2023-02-01T02:59:27Z, Gold Answer: 2023-02-01
# Pred Columns: {'tpep_pickup_datetime'}, Gold Columns: {'tpep_pickup_datetime'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"PULocationID": 161, "count": 2}, {"PULocationID": 163, "count": 2}], "columns_used": ["PULocationID"]}
#
# Question: Which are the top 2 most frequent pickup locations?
# Pred Answer: {"{'PULocationID': 161, 'count': 2}", "{'PULocationID': 163, 'count': 2}"}, Gold Answer: {'161', '163'}
# Pred Columns: {'PULocationID'}, Gold Columns: {'PULocationID'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["1.0", "1.0", "1.0", "2.0"], "columns_used": ["RatecodeID"]}
#
# Question: Name the 4 most common rate codes used.
# Pred Answer: {'1.0', '2.0'}, Gold Answer: {'1'}
# Pred Columns: {'RatecodeID'}, Gold Columns: {'RatecodeID'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["N", "N"], "columns_used": ["store_and_fwd_flag"]}
#
# Question: list the 2 most frequent store and forward flags.
# Pred Answer: {'N'}, Gold Answer: {'Y', 'N'}
# Pred Columns: {'store_and_fwd_flag'}, Gold Columns: {'store_and_fwd_flag'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1.0, 1.0, 2.0, 3.0], "columns_used": ["payment_type"]}
#
# Question: Identify the top 4 payment types used by frequency
# Pred Answer: {'1.0', '2.0', '3.0'}, Gold Answer: {'1', '3', '2'}
# Pred Columns: {'payment_type'}, Gold Columns: {'payment_type'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [0.0, 0.0, 0.0, 0.0],
# "columns_used": ["tolls_amount"]
# }
#
# Question: Report the 4 highest toll amounts paid.
# Pred Answer: {0.0}, Gold Answer: {0.0}
# Pred Columns: {'tolls_amount'}, Gold Columns: {'tolls_amount'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {
#     "answer": [
#         8.32,
#         5.93,
#         2.8
#     ],
#     "columns_used": ["trip_distance"]
# }
#
# Question: list the top 3 longest trip distances
# Pred Answer: {8.32, 2.8, 5.93}, Gold Answer: {8.32, 2.8, 5.93}
# Pred Columns: {'trip_distance'}, Gold Columns: {'trip_distance'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [45.8, 39.9, 33.2, 25.2, 24.9], "columns_used": ["total_amount"]}
#
# Question: Identify the 5 largest total amounts paid for trips.
# Pred Answer: {33.2, 39.9, 45.8, 24.9, 25.2}, Gold Answer: {33.2, 39.9, 45.8, 24.87, 25.2}
# Pred Columns: {'total_amount'}, Gold Columns: {'total_amount'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {
#     "answer": [40.8, 28.9, 21.2, 17.0, 14.9, 14.0],
#     "columns_used": ["fare_amount"]
# }
#
# Question: Report the 6 highest fare amounts charged.
# Pred Answer: {40.8, 14.9, 14.0, 17.0, 21.2, 28.9}, Gold Answer: {40.8, 13.5, 14.9, 17.0, 21.2, 28.9}
# Pred Columns: {'fare_amount'}, Gold Columns: {'fare_amount'}
#
# === Answer Accuracy by Type ===
# boolean        : 75.00% (3/4)
# number         : 25.00% (1/4)
# category       : 0.00% (0/4)
# list[category] : 0.00% (0/4)
# list[number]   : 50.00% (2/4)
#
# === Column Selection Accuracy ===
# 90.00% (18/20)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 005_NYC ###
# # Questions in 005_NYC: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["borough", "complaint_type"]}
#
# Question: Are there any complaints made in Brooklyn?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'borough', 'complaint_type'}, Gold Columns: {'borough'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["descriptor"]}
#
# Question: Do any complaints have 'Dog' as a descriptor?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'descriptor'}, Gold Columns: {'descriptor'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["month_name"]}
#
# Question: Were there any complaints raised in April?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'month_name'}, Gold Columns: {'month_name'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["agency"]}
#
# Question: Is the Mayor's office of special enforcement one of the agencies handling complaints?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 8, "columns_used": ["borough"]}
#
# Question: How many complaints have been made in Queens?
# Pred Answer: 8.0, Gold Answer: 0.0
# Pred Columns: {'borough'}, Gold Columns: {'borough'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["agency"]}
#
# Question: What's the total number of unique agencies handling complaints?
# Pred Answer: 6.0, Gold Answer: 7.0
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 2, "columns_used": ["hour", "unique_key"]}
#
# Question: How many complaints were raised at midnight?
# Pred Answer: 2.0, Gold Answer: 2.0
# Pred Columns: {'hour', 'unique_key'}, Gold Columns: {'hour'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 15,
# "columns_used": ["descriptor"]
# }
#
# Question: How many unique descriptors are present in the dataset?
# Pred Answer: 15.0, Gold Answer: 16.0
# Pred Columns: {'descriptor'}, Gold Columns: {'descriptor'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "QUEENS", "columns_used": ["borough"]}
#
# Question: Which borough has the most complaints?
# Pred Answer: QUEENS, Gold Answer: QUEENS
# Pred Columns: {'borough'}, Gold Columns: {'borough'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"February": 2, "January": 3, "March": 2, "April": 2, "May": 2, "June": 1, "July": 2, "August": 2, "September": 1, "November": 1, "December": 1}, "columns_used": ["month_name"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: Which month sees the highest number of complaints?
# Pred Answer: None, Gold Answer: January
# Pred Columns: {'month_name'}, Gold Columns: {'month_name'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": "Sunday",
# "columns_used": ["weekday_name"]
# }
#
# Question: Which weekday has the least complaints?
# Pred Answer: Sunday, Gold Answer: Thursday
# Pred Columns: {'weekday_name'}, Gold Columns: {'weekday_name'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"agency": "DPR", "frequency": 1}, "columns_used": ["agency"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: Which agency is least frequently handling complaints?
# Pred Answer: None, Gold Answer: DOHMH
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["HEAT/HOT WATER", "Noise - Commercial", "Noise - Street/Sidewalk", "Noise - Residential", "Building/Use"], "columns_used": ["complaint_type"]}
#
# Question: List the top 5 most frequent complaint types.
# Pred Answer: {'Noise - Residential', 'Building/Use', 'Noise - Street/Sidewalk', 'Noise - Commercial', 'HEAT/HOT WATER'}, Gold Answer: {'Air Quality', 'Noise - Residential', 'Building/Use', 'General Construction/Plumbing', 'HEAT/HOT WATER'}
# Pred Columns: {'complaint_type'}, Gold Columns: {'complaint_type'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"HPD": 4, "NYPD": 6, "DOB": 3, "DSNY": 2}, "columns_used": ["agency"]}
#
# Question: Which 4 agencies handle the most complaints?
# Pred Answer: set(), Gold Answer: {'DSNY', 'HPD', 'NYPD', 'DOB'}
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["With License Plate", "ENTIRE BUILDING"], "columns_used": ["descriptor"]}
#
# Question: Name the 2 least frequent descriptors for complaints by inverse alphabetical order.
# Pred Answer: {'With License Plate', 'ENTIRE BUILDING'}, Gold Answer: {'12 Dead Animals', 'Structure - Outdoors, Air: Odor/Fumes', 'Restaurant (AD2)'}
# Pred Columns: {'descriptor'}, Gold Columns: {'descriptor'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Monday", "Friday"], "columns_used": ["weekday_name"]}
#
# Question: Mention the 2 most common weekdays for complaints.
# Pred Answer: {'Friday', 'Monday'}, Gold Answer: {'Wednesday', 'Monday'}
# Pred Columns: {'weekday_name'}, Gold Columns: {'weekday_name'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [18, 21, 0, 11], "columns_used": ["hour"]}
#
# Question: What are the top 4 hours with the most complaints?
# Pred Answer: {0.0, 18.0, 11.0, 21.0}, Gold Answer: {0.0, 16.0, 18.0, 21.0}
# Pred Columns: {'hour'}, Gold Columns: {'hour'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [18311800, 22322205, 25369019], "columns_used": ["unique_key"]}
#
# Question: State the 3 lowest unique complaint keys.
# Pred Answer: {18311800.0, 25369019.0, 22322205.0}, Gold Answer: {18311800.0, 25369019.0, 22322205.0}
# Pred Columns: {'unique_key'}, Gold Columns: {'unique_key'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [7, 10], "columns_used": ["hour"]}
#
# Question: Which 2 hours see the least complaints?
# Pred Answer: {10.0, 7.0}, Gold Answer: {8.0, 7.0}
# Pred Columns: {'hour'}, Gold Columns: {'hour'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [54188773, 45481177, 43260648, 43655624, 43259964, 42173087],
# "columns_used": ["unique_key"]
# }
#
# Question: List the 6 highest complaint numbers from the dataset.
# Pred Answer: {54188773.0, 43260648.0, 43655624.0, 45481177.0, 43259964.0, 42173087.0}, Gold Answer: {49874401.0, 54188773.0, 51990440.0, 43655624.0, 45481177.0, 50082845.0}
# Pred Columns: {'unique_key'}, Gold Columns: {'unique_key'}
#
# === Answer Accuracy by Type ===
# boolean        : 100.00% (4/4)
# number         : 25.00% (1/4)
# category       : 25.00% (1/4)
# list[category] : 0.00% (0/4)
# list[number]   : 25.00% (1/4)
#
# === Column Selection Accuracy ===
# 90.00% (18/20)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 006_London ###
# # Questions in 006_London: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["neighbourhood_cleansed"]}
#
# Question: Are all properties in the dataset located in the same neighbourhood?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'neighbourhood_cleansed'}, Gold Columns: {'neighbourhood_cleansed'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["host_identity_verified"]}
#
# Question: Do all hosts verify their identity?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'host_identity_verified'}, Gold Columns: {'host_identity_verified'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["reviews_per_month"]
# }
#
# Question: Are all reviews_per_month values greater than 5?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'reviews_per_month'}, Gold Columns: {'reviews_per_month'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["room_type"]}
#
# Question: Are there any listings without a specified room type?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'room_type'}, Gold Columns: {'room_type'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 9, "columns_used": ["neighbourhood_cleansed"]}
#
# Question: How many unique neighbourhoods are there in the dataset?
# Pred Answer: 9.0, Gold Answer: 20.0
# Pred Columns: {'neighbourhood_cleansed'}, Gold Columns: {'host_neighbourhood'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["calculated_host_listings_count_entire_homes"]}
#
# Question: How many listings don't have a valid price?
# Pred Answer: 6.0, Gold Answer: 0.0
# Pred Columns: {'calculated_host_listings_count_entire_homes'}, Gold Columns: {'price'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["review_scores_communication"]}
#
# Question: How many properties have received the worst possible (0-5) review score for communication?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: {'review_scores_communication'}, Gold Columns: {'review_scores_communication'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3, "columns_used": ["bedrooms"]}
#
# Question: What is the maximum number of bedrooms a property has in this dataset?
# Pred Answer: 3.0, Gold Answer: 3.0
# Pred Columns: {'bedrooms'}, Gold Columns: {'bedrooms'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Hammersmith and Fulham", "columns_used": ["neighbourhood_cleansed", "calculated_host_listings_count_entire_homes"]}
#
# Question: Which neighbourhood has the most listings?
# Pred Answer: Hammersmith and Fulham, Gold Answer: Hammersmith and Fulham
# Pred Columns: {'neighbourhood_cleansed', 'calculated_host_listings_count_entire_homes'}, Gold Columns: {'neighbourhood_cleansed'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Private room", "columns_used": ["room_type"]}
#
# Question: What is the most common room type in the listings?
# Pred Answer: Private room, Gold Answer: Private room
# Pred Columns: {'room_type'}, Gold Columns: {'room_type'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": "Private room in rental unit",
# "columns_used": ["property_type"]
# }
#
# Question: What property type has the most listings?
# Pred Answer: Private room in rental unit, Gold Answer: Private room in rental unit
# Pred Columns: {'property_type'}, Gold Columns: {'property_type'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "phone", "columns_used": ["host_verifications"]}
#
# Question: Which host verification method is the least used?
# Pred Answer: phone, Gold Answer: [phone]
# Pred Columns: {'host_verifications'}, Gold Columns: {'host_verifications'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": "[{\"neighbourhood_cleansed\":\"Hammersmith and Fulham\",\"count\":3},{\"neighbourhood_cleansed\":\"Westminster\",\"count\":3},{\"neighbourhood_cleansed\":\"Hackney\",\"count\":3}]", "columns_used": ["neighbourhood_cleansed", "calculated_host_listings_count_entire_homes"]}
#
# Question: List the top 3 neighbourhoods with the most listings.
# Pred Answer: {"{'neighbourhood_cleansed': 'Hammersmith and Fulham', 'count': 3}", "{'neighbourhood_cleansed': 'Hackney', 'count': 3}", "{'neighbourhood_cleansed': 'Westminster', 'count': 3}"}, Gold Answer: {'Hackney', 'Westminster', 'Hammersmith and Fulham'}
# Pred Columns: {'neighbourhood_cleansed', 'calculated_host_listings_count_entire_homes'}, Gold Columns: {'neighbourhood_cleansed'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Private room in rental unit", "Entire home", "Entire condo", "Entire rental unit"], "columns_used": ["property_type"]}
#
# Question: Which are the top 4 most common property types?
# Pred Answer: {'Private room in rental unit', 'Entire home', 'Entire condo', 'Entire rental unit'}, Gold Answer: {'Private room in rental unit', 'Entire home', 'Private room in home', 'Entire rental unit'}
# Pred Columns: {'property_type'}, Gold Columns: {'property_type'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["email", "phone"], "columns_used": ["host_verifications"]}
#
# Question: List the 2 most common host verification methods.
# Pred Answer: {'phone', 'email'}, Gold Answer: {'phone', 'email'}
# Pred Columns: {'host_verifications'}, Gold Columns: {'host_verifications'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Entire home/apt", "Private room"], "columns_used": ["room_type"]}
#
# Question: Which are the 2 most preferred room types?
# Pred Answer: {'Entire home/apt', 'Private room'}, Gold Answer: {'Entire home/apt', 'Private room'}
# Pred Columns: {'room_type'}, Gold Columns: {'room_type'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [5.0, 5.0, 4.95], "columns_used": ["review_scores_location"]}
#
# Question: What are the top 3 highest review scores for location?
# Pred Answer: {4.95, 5.0}, Gold Answer: {4.89, 4.0, 5.0}
# Pred Columns: {'review_scores_location'}, Gold Columns: {'review_scores_location'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [1.0, 1.0, 2.0, 3.0],
# "columns_used": ["bedrooms"]
# }
#
# Question: What are the 4 most common number of bedrooms in properties?
# Pred Answer: {1.0, 2.0, 3.0}, Gold Answer: {1.0, 2.0, 3.0}
# Pred Columns: {'bedrooms'}, Gold Columns: {'bedrooms'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [92, 260, 11, 1, 3],
# "columns_used": ["calculated_host_listings_count_entire_homes"]
# [process_response] Failed to parse response for question: What are the 5 highest counts of listings by a single host for entire homes?
# Error: invalid syntax (<unknown>, line 0)
#
# Question: What are the 5 highest counts of listings by a single host for entire homes?
# Pred Answer: None, Gold Answer: {1.0}
# Pred Columns: [], Gold Columns: {'calculated_host_listings_count_entire_homes'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [
# 4.0,
# 4.0,
# 4.44,
# 4.5,
# 4.75,
# 4.84
# ],
# "columns_used": ["review_scores_communication"]
# }
#
# Question: List the 6 lowest review scores for communication.
# Pred Answer: {4.84, 4.5, 4.75, 4.0, 4.44}, Gold Answer: {4.95, 4.5, 4.75, 4.4, 4.89, 4.94}
# Pred Columns: {'review_scores_communication'}, Gold Columns: {'review_scores_communication'}
#
# === Answer Accuracy by Type ===
# boolean        : 50.00% (2/4)
# number         : 50.00% (2/4)
# category       : 75.00% (3/4)
# list[category] : 50.00% (2/4)
# list[number]   : 25.00% (1/4)
#
# === Column Selection Accuracy ===
# 75.00% (15/20)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 007_Fifa ###
# # Questions in 007_Fifa: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": true,
# "columns_used": ["Overall", "Potential"]
# }
#
# Question: Are there players who have a greater overall score than their potential score?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'Potential', 'Overall'}, Gold Columns: {'Potential', 'Overall'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Age", "Joined"]}
#
# Question: Are there any players who joined their current club before they were 18 years old?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Age', 'Joined'}, Gold Columns: {'Age', 'Joined'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": false, "columns_used": ["Preferred Foot", "Nationality"]}
#
# Question: Are there any players whose preferred foot is left and are from a nationality that starts with 'B'?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Nationality', 'Preferred Foot'}, Gold Columns: {'Nationality', 'Preferred Foot'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["Height_ft", "Agility"]}
#
# Question: Are there any players who are taller than 6 feet and have an agility score above 90?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Height_ft', 'Agility'}, Gold Columns: {'Height_ft', 'Agility'}
#
# --- Query 5/20 ---
# normalize_answer error for type 'number': Expected numeric type for number, got: <class 'NoneType'>
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["Overall", "Nationality"]}
#
# Question: What is the average overall score of players from France?
# Pred Answer: 0.0, Gold Answer: None
# Pred Columns: {'Nationality', 'Overall'}, Gold Columns: {'Nationality', 'Overall'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 15, "columns_used": ["Club"]}
#
# Question: How many unique clubs are there in the dataset?
# Pred Answer: 15.0, Gold Answer: 19.0
# Pred Columns: {'Club'}, Gold Columns: {'Club'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 13500000.0, "columns_used": ["Value_€"]}
#
# Question: What is the highest value (in €) of a player in the dataset?
# Pred Answer: 13500000.0, Gold Answer: 13500000.0
# Pred Columns: {'Value_€'}, Gold Columns: {'Value_€'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 1,
# "columns_used": ["Position"]
# }
#
# Question: How many players have the position 'ST'?
# Pred Answer: 1.0, Gold Answer: 1.0
# Pred Columns: {'Position'}, Gold Columns: {'Position'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Ghana", "columns_used": ["Nationality"]}
#
# Question: What is the most common nationality in the dataset?
# Pred Answer: Ghana, Gold Answer: Ghana
# Pred Columns: {'Nationality'}, Gold Columns: {'Nationality'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {
#     "answer": "Right",
#     "columns_used": ["Preferred Foot"]
# }
#
# Question: What is the most common preferred foot amongst players?
# Pred Answer: Right, Gold Answer: Right
# Pred Columns: {'Preferred Foot'}, Gold Columns: {'Preferred Foot'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"Hannover 96": 2}, "columns_used": ["Club"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: Which club has the most players in the dataset?
# Pred Answer: None, Gold Answer: Lech Poznań
# Pred Columns: {'Club'}, Gold Columns: {'Club'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "SUB", "columns_used": ["Position"]}
#
# Question: What is the most common position of players in the dataset?
# Pred Answer: SUB, Gold Answer: SUB
# Pred Columns: {'Position'}, Gold Columns: {'Position'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [
# {"Nationality": "Brazil", "Average": 75.5},
# {"Nationality": "Ghana", "Average": 72.5},
# {"Nationality": "Netherlands", "Average": 68.5},
# {"Nationality": "Germany", "Average": 64.5},
# {"Nationality": "Portugal", "Average": 79.0}
# ],
# "columns_used": ["Nationality", "Overall"]
# }
#
# Question: Which are the top 5 nationalities in terms of the average overall score of their players?
# Pred Answer: {"{'Nationality': 'Ghana', 'Average': 72.5}", "{'Nationality': 'Portugal', 'Average': 79.0}", "{'Nationality': 'Netherlands', 'Average': 68.5}", "{'Nationality': 'Germany', 'Average': 64.5}", "{'Nationality': 'Brazil', 'Average': 75.5}"}, Gold Answer: {'Brazil', 'Ghana', 'Ivory Coast', 'Portugal', 'United States'}
# Pred Columns: {'Nationality', 'Overall'}, Gold Columns: {'Nationality', 'Overall'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"Club": "Sassuolo", "Value_€": 13500000}, {"Club": "Sporting CP", "Value_€": 5500000}, {"Club": "Atalanta", "Value_€": 7500000}], "columns_used": ["Club", "Value_€"]}
#
# Question: Which are the top 3 clubs in terms of the total value (in €) of their players?
# Pred Answer: {"{'Club': 'Atalanta', 'Value_€': 7500000}", "{'Club': 'Sassuolo', 'Value_€': 13500000}", "{'Club': 'Sporting CP', 'Value_€': 5500000}"}, Gold Answer: {'Sassuolo', 'DC United', 'Atalanta'}
# Pred Columns: {'Value_€', 'Club'}, Gold Columns: {'Value_€', 'Club'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"Nationality": "Guyana", "Average_Agility": 38.0}, {"Nationality": "United States", "Average_Agility": 34.0}, {"Nationality": "Poland", "Average_Agility": 53.0}, {"Nationality": "Uruguay", "Average_Agility": 64.0}], "columns_used": ["Nationality", "Agility"]}
#
# Question: Which are the bottom 4 nationalities in terms of the average agility of their players?
# Pred Answer: {"{'Nationality': 'United States', 'Average_Agility': 34.0}", "{'Nationality': 'Poland', 'Average_Agility': 53.0}", "{'Nationality': 'Uruguay', 'Average_Agility': 64.0}", "{'Nationality': 'Guyana', 'Average_Agility': 38.0}"}, Gold Answer: {'Saudi Arabia', 'Guyana', 'United States', 'Poland'}
# Pred Columns: {'Nationality', 'Agility'}, Gold Columns: {'Nationality', 'Agility'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"Club": "Sassuolo", "Average_Potential": 86}, {"Club": "Sporting CP", "Average_Potential": 79}, {"Club": "Atalanta", "Average_Potential": 77}, {"Club": "DC United", "Average_Potential": 77}, {"Club": "Inter", "Average_Potential": 77}, {"Club": "SG Dynamo Dresden", "Average_Potential": 75}], "columns_used": ["Club", "Potential"]}
#
# Question: Which are the top 6 clubs in terms of the average potential score of their players?
# Pred Answer: {"{'Club': 'DC United', 'Average_Potential': 77}", "{'Club': 'SG Dynamo Dresden', 'Average_Potential': 75}", "{'Club': 'Sassuolo', 'Average_Potential': 86}", "{'Club': 'Sporting CP', 'Average_Potential': 79}", "{'Club': 'Atalanta', 'Average_Potential': 77}", "{'Club': 'Inter', 'Average_Potential': 77}"}, Gold Answer: {'Atalanta', 'Sporting CP', 'Sassuolo', 'DC United', 'Inter', '1. FSV Mainz 05'}
# Pred Columns: {'Potential', 'Club'}, Gold Columns: {'Potential', 'Club'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [79, 77, 77],
# "columns_used": ["Overall"]
# }
#
# Question: What are the top 3 overall scores in the dataset?
# Pred Answer: {77.0, 79.0}, Gold Answer: {77.0, 79.0}
# Pred Columns: {'Overall'}, Gold Columns: {'Overall'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [60.0, 65.0, 66.0, 67.0, 68.0],
# "columns_used": ["Potential"]
# }
#
# Question: What are the bottom 5 potential scores in the dataset?
# Pred Answer: {65.0, 66.0, 67.0, 68.0, 60.0}, Gold Answer: {65.0, 66.0, 67.0, 68.0, 60.0}
# Pred Columns: {'Potential'}, Gold Columns: {'Potential'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [13500000, 5500000, 7750000, 5500000], "columns_used": ["Value_€"]}
#
# Question: What are the top 4 values (in €) of players in the dataset?
# Pred Answer: {13500000.0, 5500000.0, 7750000.0}, Gold Answer: {13500000.0, 5500000.0, 7500000.0}
# Pred Columns: {'Value_€'}, Gold Columns: {'Value_€'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [29000, 47000], "columns_used": ["Wage_€"]}
#
# Question: What are the top 2 wages (in €) of players in the dataset?
# Pred Answer: {29000.0, 47000.0}, Gold Answer: {47000.0, 29000.0}
# Pred Columns: {'Wage_€'}, Gold Columns: {'Wage_€'}
#
# === Answer Accuracy by Type ===
# boolean        : 75.00% (3/4)
# number         : 50.00% (2/4)
# category       : 75.00% (3/4)
# list[category] : 0.00% (0/4)
# list[number]   : 75.00% (3/4)
#
# === Column Selection Accuracy ===
# 100.00% (20/20)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 008_Tornados ###
# # Questions in 008_Tornados: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["inj", "mo"]
# }
#
# Question: There are no tornadoes that resulted in more than 500 injuries.
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'inj', 'mo'}, Gold Columns: {'inj'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["yr"]}
#
# Question: All tornadoes in the dataset occurred in the 21st century.
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'yr'}, Gold Columns: {'yr'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["mag"]
# }
#
# Question: No tornado has a length greater than 100 miles.
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'mag'}, Gold Columns: {'len'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["fat"]
# }
#
# Question: There are no tornadoes that resulted in more than 100 fatalities.
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'fat'}, Gold Columns: {'fat'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["mo"]}
#
# Question: How many unique states are represented in the dataset?
# Pred Answer: 0.0, Gold Answer: 12.0
# Pred Columns: {'mo'}, Gold Columns: {'st'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 2,
# "columns_used": ["mag"]
# }
#
# Question: What is the highest magnitude of tornado recorded in the dataset?
# Pred Answer: 2.0, Gold Answer: 2.0
# Pred Columns: {'mag'}, Gold Columns: {'mag'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 72.2, "columns_used": ["len"]}
#
# Question: What is the longest length of a tornado path in the dataset?
# Pred Answer: 72.2, Gold Answer: 72.2
# Pred Columns: {'len'}, Gold Columns: {'len'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3.0, "columns_used": ["inj"]}
#
# Question: What is the maximum number of injuries caused by a single tornado?
# Pred Answer: 3.0, Gold Answer: 3.0
# Pred Columns: {'inj'}, Gold Columns: {'inj'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "IL", "columns_used": ["st"]}
#
# Question: Which state has experienced the most tornadoes?
# Pred Answer: IL, Gold Answer: IL
# Pred Columns: {'st'}, Gold Columns: {'st'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"Apr": 5, "May": 5, "Jun": 4, "Jul": 2, "Aug": 1, "Sep": 1, "Oct": 2, "Nov": 1, "Feb": 1, "Mar": 1}, "columns_used": ["date", "yr", "st", "mag"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'dict'>
#
# Question: In which month do most tornadoes occur?
# Pred Answer: None, Gold Answer: 6
# Pred Columns: {'date', 'yr', 'st', 'mag'}, Gold Columns: {'mo'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {
#   "answer": "1973-07-23",
#   "columns_used": ["date"]
# }
#
# Question: On what date did the most destructive tornado (by injuries) occur?
# Pred Answer: 1973-07-23, Gold Answer: 1973-03-15
# ...
# Error: invalid syntax (<unknown>, line 0)
#
# Question: What are the top 5 entity IDs in terms of weight?
# Pred Answer: None, Gold Answer: {91203.0, 527.0, 498.0, 411.0, 8031.0}
# Pred Columns: [], Gold Columns: {'weight', 'id'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [204402, 43941, 91203, 527], "columns_used": ["id", "page_rank_norm"]}
#
# Question: What are the bottom 4 entity IDs in terms of page rank norm?
# Pred Answer: {204402.0, 91203.0, 43941.0, 527.0}, Gold Answer: {35046.0, 35106.0, 35070.0, 35054.0}
# Pred Columns: {'page_rank_norm', 'id'}, Gold Columns: {'page_rank_norm', 'id'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [0.4905835057931528, 0.2171608658929857, 0.1023296876109954, 0.0857382638801249, 0.0366773129253865, 0.0362281625727942], "columns_used": ["page_rank_norm"]}
#
# Question: What are the top 6 page rank norms of the entities?
# Pred Answer: {0.4905835057931528, 0.0857382638801249, 0.2171608658929857, 0.1023296876109954, 0.0366773129253865, 0.0362281625727942}, Gold Answer: {0.4905835057931528, 0.1213462154304343, 0.2194061763508274, 0.2858285808469396, 0.2171608658929857, 0.1023296876109954}
# Pred Columns: {'page_rank_norm'}, Gold Columns: {'page_rank_norm'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [3.0, 5.0, 7.0], "columns_used": ["weight"]}
#
# Question: What are the bottom 3 weights of the entities?
# Pred Answer: {3.0, 5.0, 7.0}, Gold Answer: {3.0, 5.0, 7.0}
# Pred Columns: {'weight'}, Gold Columns: {'weight'}
#
# === Answer Accuracy by Type ===
# boolean        : 100.00% (4/4)
# number         : 25.00% (1/4)
# category       : 0.00% (0/4)
# list[category] : 0.00% (0/4)
# list[number]   : 25.00% (1/4)
#
# === Column Selection Accuracy ===
# 60.00% (12/20)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 064_Clustering ###
# # Questions in 064_Clustering: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": true, "columns_used": ["feathers"]}
#
# Question: Are there any animals with feathers in the dataset?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'feathers'}, Gold Columns: {'feathers'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": true, "columns_used": ["venomous", "animal_name"]}
#
# Question: Are there any venomous animals in the dataset?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'animal_name', 'venomous'}, Gold Columns: {'venomous'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": true,
# "columns_used": ["breathes"]
# }
#
# Question: Do all animals breathe?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'breathes'}, Gold Columns: {'breathes'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {
#     "answer": True,
#     "columns_used": ["domestic"]
# }
#
# Question: Are there any domesticated animals in the dataset?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'domestic'}, Gold Columns: {'domestic'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 9,
# "columns_used": ["class_type"]
# }
#
# Question: How many unique types of animals are there?
# Pred Answer: 9.0, Gold Answer: 4.0
# Pred Columns: {'class_type'}, Gold Columns: {'class_type'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 3.4,
# "columns_used": ["legs"]
# }
#
# Question: What is the average number of legs?
# Pred Answer: 3.4, Gold Answer: 3.1
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["legs"]}
#
# Question: What is the maximum number of legs an animal has?
# Pred Answer: 6.0, Gold Answer: 6.0
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3, "columns_used": ["legs"]}
#
# Question: How many animals are there with 2 legs?
# Pred Answer: 3.0, Gold Answer: 4.0
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 1,
# "columns_used": ["class_type"]
# }
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: What is the most common class type?
# Pred Answer: None, Gold Answer: 1
# Pred Columns: {'class_type'}, Gold Columns: {'class_type'}
#
# --- Query 10/20 ---
# normalize_answer error for type 'category': Expected string for category, got: <class 'NoneType'>
#
# --- Raw LLM Response ---
# {"answer": null, "columns_used": ["legs", "animal_name"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'NoneType'>
#
# Question: What is the name of the first animal with 8 legs?
# Pred Answer: None, Gold Answer: None
# Pred Columns: {'animal_name', 'legs'}, Gold Columns: {'animal_name', 'legs'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["class_type", "legs"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: What is the class type of the animals with the most legs?
# Pred Answer: None, Gold Answer: 6
# Pred Columns: {'legs', 'class_type'}, Gold Columns: {'legs', 'class_type'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "honeybee", "columns_used": ["animal_name"]}
#
# Question: What is the name of the first animal in the dataset that is venomous?
# Pred Answer: honeybee, Gold Answer: honeybee
# Pred Columns: {'animal_name'}, Gold Columns: {'animal_name', 'venomous'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["honeybee", "oryx", "puma"], "columns_used": ["legs", "animal_name"]}
#
# Question: What are the top 3 animal names with the most legs? If there are more than two with the lowest number go with alphabetical order
# Pred Answer: {'puma', 'honeybee', 'oryx'}, Gold Answer: {'wasp', 'honeybee', 'gnat'}
# Pred Columns: {'animal_name', 'legs'}, Gold Columns: {'animal_name', 'legs'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["chub", "dogfish"], "columns_used": ["animal_name", "legs"]}
#
# Question: What are the bottom 2 animal names in terms of the number of legs? If there are more than two with the lowest number go with alphabetical order
# Pred Answer: {'dogfish', 'chub'}, Gold Answer: {'porpoise', 'dogfish'}
# Pred Columns: {'animal_name', 'legs'}, Gold Columns: {'animal_name', 'legs'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"class_type": 1, "count": 9}, {"class_type": 6, "count": 2}, {"class_type": 2, "count": 2}, {"class_type": 4, "count": 2}], "columns_used": ["class_type"]}
#
# Question: What are the most common 4 class types with the most animals?
# Pred Answer: {"{'class_type': 1, 'count': 9}", "{'class_type': 2, 'count': 2}", "{'class_type': 4, 'count': 2}", "{'class_type': 6, 'count': 2}"}, Gold Answer: {'1', '6', '4', '2'}
# Pred Columns: {'class_type'}, Gold Columns: {'class_type'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": [{"class_type": 6, "count": 3}, {"class_type": 4, "count": 2}, {"class_type": 7, "count": 1}], "columns_used": ["class_type"]}
#
# Question: What are the least common 3 class types with the least animals?
# Pred Answer: {"{'class_type': 7, 'count': 1}", "{'class_type': 6, 'count': 3}", "{'class_type': 4, 'count': 2}"}, Gold Answer: {'7', '4', '2'}
# Pred Columns: {'class_type'}, Gold Columns: {'class_type'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [
# {"class_type": 1, "total_legs": 24},
# {"class_type": 6, "total_legs": 12},
# {"class_type": 2, "total_legs": 4},
# {"class_type": 4, "total_legs": 2},
# {"class_type": 7, "total_legs": 0}
# ],
# "columns_used": ["class_type", "legs"]
# [process_response] Failed to parse response for question: What are the most common 5 class types with the most combined total legs?
# Error: '[' was never closed (<unknown>, line 2)
#
# Question: What are the most common 5 class types with the most combined total legs?
# Pred Answer: None, Gold Answer: {1.0, 2.0, 4.0, 6.0, 7.0}
# Pred Columns: [], Gold Columns: {'legs', 'class_type'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1, 4, 4, 7], "columns_used": ["class_type", "legs"]}
#
# Question: What are the bottom 4 class types with the least combined total legs?
# Pred Answer: {1.0, 4.0, 7.0}, Gold Answer: {2.0, 4.0, 6.0, 7.0}
# Pred Columns: {'legs', 'class_type'}, Gold Columns: {'legs', 'class_type'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [4, 4, 2, 0],
# "columns_used": ["legs"]
# }
#
# Question: What are the most common 4 numbers of legs that animals have?
# Pred Answer: {0.0, 2.0, 4.0}, Gold Answer: {0.0, 2.0, 4.0, 6.0}
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [0, 2, 6],
# "columns_used": ["legs"]
# }
#
# Question: What are the least common 3 numbers of legs that animals have?
# Pred Answer: {0.0, 2.0, 6.0}, Gold Answer: {0.0, 2.0, 6.0}
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# === Answer Accuracy by Type ===
# boolean        : 75.00% (3/4)
# number         : 25.00% (1/4)
# category       : 50.00% (2/4)
# list[category] : 0.00% (0/4)
# list[number]   : 25.00% (1/4)
#
# === Column Selection Accuracy ===
# 85.00% (17/20)
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Evaluating 065_RFM ###
# # Questions in 065_RFM: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": False,
# "columns_used": ["Quantity"]
# }
#
# Question: Are all the quantities greater than 0?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Quantity'}, Gold Columns: {'Quantity'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": True,
# "columns_used": ["UnitPrice"]
# }
#
# Question: Are all the unit prices greater than 0?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'UnitPrice'}, Gold Columns: {'UnitPrice'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["CustomerID"]}
#
# Question: Are there any missing customer IDs?
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'CustomerID'}, Gold Columns: {'CustomerID'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Country"]}
#
# Question: Are there any transactions from the United Kingdom?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 14, "columns_used": ["StockCode"]}
#
# Question: How many unique stock codes are there?
# Pred Answer: 14.0, Gold Answer: 20.0
# Pred Columns: {'StockCode'}, Gold Columns: {'StockCode'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3.431666666666667, "columns_used": ["UnitPrice"]}
#
# Question: What is the average unit price?
# Pred Answer: 3.431666666666667, Gold Answer: 3.5415
# Pred Columns: {'UnitPrice'}, Gold Columns: {'UnitPrice'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 25,
# "columns_used": ["Quantity"]
# }
#
# Question: What is the maximum quantity ordered in a single transaction?
# Pred Answer: 25.0, Gold Answer: 25.0
# Pred Columns: {'Quantity'}, Gold Columns: {'Quantity'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": 19,
# "columns_used": ["Country"]
# }
#
# Question: How many transactions were made in the United Kingdom?
# Pred Answer: 19.0, Gold Answer: 19.0
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "United Kingdom", "columns_used": ["Country"]}
#
# Question: Which country made the most transactions?
# Pred Answer: United Kingdom, Gold Answer: United Kingdom
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": "SWEETHEART WIRE FRUIT BOWL",
# "columns_used": ["Description", "UnitPrice"]
# [process_response] Failed to parse response for question: What is the description of the item with the highest unit price?
# Error: invalid syntax (<unknown>, line 0)
#
# Question: What is the description of the item with the highest unit price?
# Pred Answer: None, Gold Answer: RETROSPOT LAMP
# Pred Columns: [], Gold Columns: {'UnitPrice', 'Description'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "BLUE POLKADOT WRAP", "columns_used": ["Description"]}
#
# Question: What is the description of the item with the highest quantity ordered?
# Pred Answer: BLUE POLKADOT WRAP, Gold Answer: BLUE POLKADOT WRAP
# Pred Columns: {'Description'}, Gold Columns: {'Description', 'Quantity'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": "United Kingdom",
# "columns_used": ["CustomerID", "Country"]
# }
#
# Question: Which country does the customer with the lowest ID come from?
# Pred Answer: United Kingdom, Gold Answer: Australia
# Pred Columns: {'CustomerID', 'Country'}, Gold Columns: {'CustomerID', 'Country'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["PACK 3 BOXES CHRISTMAS PANETTONE", "PACK OF 12 SPACEBOY TISSUES", "BLUE POLKADOT WRAP"], "columns_used": ["Description", "Quantity"]}
#
# Question: What are the descriptions of the 3 items with the highest quantities ordered?
# Pred Answer: {'BLUE POLKADOT WRAP', 'PACK 3 BOXES CHRISTMAS PANETTONE', 'PACK OF 12 SPACEBOY TISSUES'}, Gold Answer: {'BLUE POLKADOT WRAP', 'FAIRY CAKE FLANNEL ASSORTED COLOUR', 'HANGING JAM JAR T-LIGHT HOLDER'}
# Pred Columns: {'Description', 'Quantity'}, Gold Columns: {'Description', 'Quantity'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": ["GOLD FISHING GNOME", "SET/6 RED SPOTTY PAPER CUPS"],
# "columns_used": ["Description", "Quantity"]
# }
#
# Question: What are the descriptions of the 2 items with the lowest quantities ordered? If there is a tie then solve it with the alphabetical order of descriptions.
# Pred Answer: {'SET/6 RED SPOTTY PAPER CUPS', 'GOLD FISHING GNOME'}, Gold Answer: {'HANGING METAL STAR LANTERN', 'LARGE CAKE TOWEL CHOCOLATE SPOTS'}
# Pred Columns: {'Description', 'Quantity'}, Gold Columns: {'Description', 'Quantity'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": {
# "United Kingdom": 15,
# "Australia": 1
# },
# "columns_used": ["Country"]
# }
#
# Question: Which 2 countries made the most transactions?
# Pred Answer: set(), Gold Answer: {'United Kingdom', 'Australia'}
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": {
# "Countries": ["Australia"]
# },
# "columns_used": ["Country"]
# }
#
# Question: Which 2 countries made the least transactions?
# Pred Answer: set(), Gold Answer: {'United Kingdom', 'Australia'}
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": ["576652", "577076", "573399", "568909", "540418"],
# "columns_used": ["InvoiceNo", "Quantity"]
# }
#
# Question: What are the invoice numbers of the top 5 transactions with the highest quantities ordered?
# Pred Answer: {540418.0, 576652.0, 568909.0, 577076.0, 573399.0}, Gold Answer: {555200.0, 563745.0, 548005.0, 568909.0, 573399.0}
# Pred Columns: {'InvoiceNo', 'Quantity'}, Gold Columns: {'InvoiceNo', 'Quantity'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": ["22465", "22812", "22180", "21109", "82600"],
# "columns_used": ["StockCode", "Quantity"]
# }
#
# Question: What are the stock codes of the bottom 5 transactions with the lowest quantities ordered? If there is a tie go with numerical order.
# Pred Answer: {22465.0, 22180.0, 82600.0, 21109.0, 22812.0}, Gold Answer: {22465.0, 82600.0, 22799.0, 82484.0, 21109.0}
# Pred Columns: {'Quantity', 'StockCode'}, Gold Columns: {'InvoiceNo', 'Quantity'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [4, 2, 12, 6], "columns_used": ["Quantity"]}
#
# Question: What are the four most commonly ordered quantities?
# Pred Answer: {2.0, 4.0, 12.0, 6.0}, Gold Answer: {1.0, 2.0, 4.0, 12.0}
# Pred Columns: {'Quantity'}, Gold Columns: {'Quantity'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": {"Description1": 2, "Description2": 2}, "columns_used": ["Description", "Quantity"]}
# normalize_list_number error: could not convert string to float: 'Description1'
#
# Question: What are the times the two most common descriptions are repeated?
# Pred Answer: None, Gold Answer: {1.0}
# Pred Columns: {'Description', 'Quantity'}, Gold Columns: {'Description'}
#
# === Answer Accuracy by Type ===
# boolean        : 75.00% (3/4)
# number         : 50.00% (2/4)
# category       : 50.00% (2/4)
# list[category] : 0.00% (0/4)
# list[number]   : 0.00% (0/4)
#
# === Column Selection Accuracy ===
# 80.00% (16/20)

# %% [markdown]
# ## Print Metrics Table

# %%
# Table 1: Main Metrics Table
results_df = pd.DataFrame(model_results).T.round(3)
print("### Main Metrics Table:")
print(results_df.to_markdown())

# Table 2: Column Quality Table
col_df = pd.DataFrame(column_quality_table)
print("\n### Column Quality Table:")
print(col_df.to_markdown(index=False))

# Table 3: Formatting Errors by Type
print("\n### Formatting Errors by Question Type:")
for qtype, count in formatting_errors_summary.items():
    print(f"{qtype:15}: {count} formatting errors")
# Out:
# ### Main Metrics Table:
# |                   |   avg |   boolean |   number |   category |   list[category] |   list[number] |   single col |   multiple cols |
# |:------------------|------:|----------:|---------:|-----------:|-----------------:|---------------:|-------------:|----------------:|
# | 001_Forbes        |  0.24 |      0.2  |    0.4   |       0.2  |            0     |           0.4  |        0.286 |           0.222 |
# | 002_Titanic       |  0.25 |      0.5  |    0.5   |       0.25 |            0     |           0    |        0.429 |           0.154 |
# | 004_Taxi          |  0.3  |      0.75 |    0.25  |       0    |            0     |           0.5  |        0.3   |           0     |
# | 005_NYC           |  0.25 |      0.75 |    0     |       0.25 |            0     |           0.25 |        0.25  |           0     |
# | 006_London        |  0.45 |      0.5  |    0.5   |       0.5  |            0.5   |           0.25 |        0.45  |           0     |
# | 007_Fifa          |  0.55 |      0.75 |    0.5   |       0.75 |            0     |           0.75 |        0.727 |           0.333 |
# | 008_Tornados      |  0.2  |      0    |    0.75  |       0.25 |            0     |           0    |        0.286 |           0     |
# | 009_Central       |  0.5  |      0.25 |    1     |       0.5  |            0.25  |           0.5  |        0.636 |           0.333 |
# | 010_ECommerce     |  0.35 |      0.25 |    0.25  |       0.5  |            0.25  |           0.5  |        0.35  |           0     |
# | 011_SF            |  0.2  |      0.25 |    0     |       0.5  |            0.25  |           0    |        0.167 |           0.25  |
# | 012_Heart         |  0.5  |      1    |    0.5   |       0.5  |            0.25  |           0.25 |        0.562 |           0.25  |
# | 013_Roller        |  0.3  |      0.5  |    0.5   |       0    |            0     |           0.5  |        0.667 |           0     |
# | 015_Food          |  0.4  |      0.75 |    0     |       1    |            0.25  |           0    |        0.267 |           0.8   |
# | 016_Holiday       |  0.65 |      1    |    0.5   |       0.5  |            0.5   |           0.75 |        0.733 |           0.4   |
# | 017_Hacker        |  0.3  |      0.25 |    0.25  |       0.5  |            0.25  |           0.25 |        0.316 |           0     |
# | 018_Staff         |  0.4  |      0.75 |    0.5   |       0.5  |            0.25  |           0    |        0.571 |           0     |
# | 019_Aircraft      |  0.15 |      0.25 |    0     |       0    |            0.25  |           0.25 |        0.176 |           0     |
# | 021_Telco         |  0.45 |      0.5  |    0.5   |       0.5  |            0.5   |           0.25 |        0.5   |           0.25  |
# | 022_Airbnbs       |  0.4  |      1    |    0.25  |       0.5  |            0.25  |           0    |        0.368 |           1     |
# | 023_Climate       |  0.1  |      0    |    0     |       0    |            0     |           0.5  |        0.333 |           0     |
# | 024_Salary        |  0.55 |      0.75 |    0.25  |       0.5  |            0.75  |           0.5  |        0.562 |           0.5   |
# | 025_Data          |  0.2  |      0.25 |    0.5   |       0    |            0     |           0.25 |        0.5   |           0.125 |
# | 026_Predicting    |  0.25 |      1    |    0.25  |       0    |            0     |           0    |        0.571 |           0.077 |
# | 027_Supermarket   |  0.25 |      0.25 |    0.75  |       0.25 |            0     |           0    |        0.667 |           0.071 |
# | 028_Predict       |  0.15 |      0.5  |    0.25  |       0    |            0     |           0    |        0.5   |           0     |
# | 029_NYTimes       |  0.2  |      0.5  |    0.25  |       0.25 |            0     |           0    |        0.333 |           0.091 |
# | 030_Professionals |  0.25 |      0.25 |    0.5   |       0.25 |            0.167 |           0    |        0.263 |           0     |
# | 031_Trustpilot    |  0.4  |      1    |    0.25  |       0.25 |            0.25  |           0.25 |        0.364 |           0.444 |
# | 032_Delicatessen  |  0.45 |      0.75 |    0.5   |       0.25 |            0.5   |           0.25 |        0.562 |           0     |
# | 033_Employee      |  0.4  |      1    |    0.333 |       0.2  |            0.25  |           0.25 |        0.5   |           0.167 |
# | 034_World         |  0.1  |      0.25 |    0     |       0.25 |            0     |           0    |        0     |           0.1   |
# | 036_US            |  0.3  |      1    |    0.25  |       0    |            0     |           0.25 |        0.545 |           0     |
# | 037_Ted           |  0.25 |      1    |    0.25  |       0    |            0     |           0    |        0.357 |           0     |
# | 038_Stroke        |  0.2  |      0.5  |    0.25  |       0.25 |            0     |           0    |        0.333 |           0.176 |
# | 039_Happy         |  0.45 |      0.75 |    0.5   |       0.25 |            0.5   |           0.25 |        0.636 |           0.222 |
# | 040_Speed         |  0.05 |      0    |    0.25  |       0    |            0     |           0    |        0.333 |           0     |
# | 041_Airline       |  0.25 |      1    |    0.25  |       0    |            0     |           0    |        0.25  |           0.25  |
# | 042_Predict       |  0.3  |      0.5  |    0.5   |       0.5  |            0     |           0    |        0.667 |           0.235 |
# | 043_Predict       |  0.15 |      0.25 |    0.25  |       0.25 |            0     |           0    |        0.333 |           0.118 |
# | 044_IMDb          |  0.05 |      0.25 |    0     |       0    |            0     |           0    |        0     |           0.05  |
# | 045_Predict       |  0.45 |      0.75 |    0.25  |       0.25 |            0.5   |           0.5  |        0.375 |           0.5   |
# | 046_120           |  0.3  |      0.25 |    0.25  |       0.25 |            0.25  |           0.5  |        0.333 |           0.25  |
# | 047_Bank          |  0.5  |      0.5  |    0.5   |       0.75 |            0.5   |           0.25 |        0.529 |           0.333 |
# | 048_Data          |  0.35 |      0.75 |    0.5   |       0    |            0.25  |           0.25 |        0.438 |           0     |
# | 050_ING           |  0.4  |      0.5  |    0.25  |       0.5  |            0.25  |           0.5  |        0.333 |           0.455 |
# | 051_Pokemon       |  0.3  |      0.75 |    0.5   |       0    |            0     |           0.25 |        0.556 |           0.091 |
# | 052_Professional  |  0.3  |      0.75 |    0.25  |       0.5  |            0     |           0    |        0.143 |           0.385 |
# | 053_Patents       |  0.25 |      0.75 |    0     |       0.5  |            0     |           0    |        0.312 |           0     |
# | 055_German        |  0.35 |      0.25 |    0.5   |       0.75 |            0     |           0.25 |        0.5   |           0.125 |
# | 056_Emoji         |  0.15 |      0.5  |    0.25  |       0    |            0     |           0    |        0.25  |           0     |
# | 057_Spain         |  0.2  |      0.25 |    0.25  |       0.25 |            0     |           0.25 |        0.211 |           0     |
# | 058_US            |  0.4  |      0.75 |    0     |       0.75 |            0     |           0.5  |        0.353 |           0.667 |
# | 059_Second        |  0.55 |      0.5  |    0.25  |       1    |            0.5   |           0.5  |        0.526 |           1     |
# | 060_Bakery        |  0.3  |      0.75 |    0.25  |       0.25 |            0.25  |           0    |        0.429 |           0.231 |
# | 061_Disneyland    |  0.2  |      0.25 |    0.25  |       0.25 |            0     |           0.25 |        0.25  |           0.167 |
# | 062_Trump         |  0.3  |      0.5  |    0.25  |       0.75 |            0     |           0    |        0.312 |           0.25  |
# | 063_Influencers   |  0.3  |      1    |    0.25  |       0    |            0     |           0.25 |        0.545 |           0     |
# | 064_Clustering    |  0.25 |      0.5  |    0.25  |       0.25 |            0     |           0.25 |        0.308 |           0.143 |
# | 065_RFM           |  0.3  |      0.75 |    0.5   |       0.25 |            0     |           0    |        0.462 |           0     |
#
# ### Column Quality Table:
# | model             | wrong cols   | right cols   | format error   |
# |:------------------|:-------------|:-------------|:---------------|
# | 001_Forbes        | 36.0 (9)     | 60.0 (15)    | 4.0 (1)        |
# | 002_Titanic       | 25.0 (5)     | 70.0 (14)    | 5.0 (1)        |
# | 004_Taxi          | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 005_NYC           | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 006_London        | 20.0 (4)     | 75.0 (15)    | 5.0 (1)        |
# | 007_Fifa          | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 008_Tornados      | 45.0 (9)     | 50.0 (10)    | 5.0 (1)        |
# | 009_Central       | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 010_ECommerce     | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 011_SF            | 40.0 (8)     | 45.0 (9)     | 15.0 (3)       |
# | 012_Heart         | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 013_Roller        | 30.0 (6)     | 50.0 (10)    | 20.0 (4)       |
# | 015_Food          | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 016_Holiday       | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 017_Hacker        | 25.0 (5)     | 70.0 (14)    | 5.0 (1)        |
# | 018_Staff         | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 019_Aircraft      | 35.0 (7)     | 55.0 (11)    | 10.0 (2)       |
# | 021_Telco         | 20.0 (4)     | 75.0 (15)    | 5.0 (1)        |
# | 022_Airbnbs       | 15.0 (3)     | 80.0 (16)    | 5.0 (1)        |
# | 023_Climate       | 80.0 (16)    | 20.0 (4)     | 0.0 (0)        |
# | 024_Salary        | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 025_Data          | 45.0 (9)     | 50.0 (10)    | 5.0 (1)        |
# | 026_Predicting    | 20.0 (4)     | 75.0 (15)    | 5.0 (1)        |
# | 027_Supermarket   | 65.0 (13)    | 35.0 (7)     | 0.0 (0)        |
# | 028_Predict       | 50.0 (10)    | 50.0 (10)    | 0.0 (0)        |
# | 029_NYTimes       | 20.0 (4)     | 55.0 (11)    | 25.0 (5)       |
# | 030_Professionals | 40.0 (8)     | 45.0 (9)     | 15.0 (3)       |
# | 031_Trustpilot    | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 032_Delicatessen  | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 033_Employee      | 20.0 (4)     | 70.0 (14)    | 10.0 (2)       |
# | 034_World         | 30.0 (6)     | 60.0 (12)    | 10.0 (2)       |
# | 036_US            | 50.0 (10)    | 45.0 (9)     | 5.0 (1)        |
# | 037_Ted           | 5.0 (1)      | 90.0 (18)    | 5.0 (1)        |
# | 038_Stroke        | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 039_Happy         | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 040_Speed         | 25.0 (5)     | 60.0 (12)    | 15.0 (3)       |
# | 041_Airline       | 15.0 (3)     | 75.0 (15)    | 10.0 (2)       |
# | 042_Predict       | 25.0 (5)     | 65.0 (13)    | 10.0 (2)       |
# | 043_Predict       | 25.0 (5)     | 70.0 (14)    | 5.0 (1)        |
# | 044_IMDb          | 35.0 (7)     | 55.0 (11)    | 10.0 (2)       |
# | 045_Predict       | 15.0 (3)     | 80.0 (16)    | 5.0 (1)        |
# | 046_120           | 30.0 (6)     | 65.0 (13)    | 5.0 (1)        |
# | 047_Bank          | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 048_Data          | 20.0 (4)     | 80.0 (16)    | 0.0 (0)        |
# | 050_ING           | 5.0 (1)      | 80.0 (16)    | 15.0 (3)       |
# | 051_Pokemon       | 45.0 (9)     | 55.0 (11)    | 0.0 (0)        |
# | 052_Professional  | 15.0 (3)     | 75.0 (15)    | 10.0 (2)       |
# | 053_Patents       | 20.0 (4)     | 70.0 (14)    | 10.0 (2)       |
# | 055_German        | 25.0 (5)     | 70.0 (14)    | 5.0 (1)        |
# | 056_Emoji         | 10.0 (2)     | 85.0 (17)    | 5.0 (1)        |
# | 057_Spain         | 0.0 (0)      | 95.0 (19)    | 5.0 (1)        |
# | 058_US            | 30.0 (6)     | 65.0 (13)    | 5.0 (1)        |
# | 059_Second        | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 060_Bakery        | 20.0 (4)     | 75.0 (15)    | 5.0 (1)        |
# | 061_Disneyland    | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 062_Trump         | 40.0 (8)     | 55.0 (11)    | 5.0 (1)        |
# | 063_Influencers   | 35.0 (7)     | 60.0 (12)    | 5.0 (1)        |
# | 064_Clustering    | 10.0 (2)     | 85.0 (17)    | 5.0 (1)        |
# | 065_RFM           | 15.0 (3)     | 80.0 (16)    | 5.0 (1)        |
#
# ### Formatting Errors by Question Type:
# list[category] : 23 formatting errors
# list[number]   : 24 formatting errors
# category       : 10 formatting errors
# boolean        : 2 formatting errors
# number         : 1 formatting errors

# %% [markdown]
# ## Compute weighted global averages

# %%
# Store dataset sizes
dataset_sizes = {dataset_id: len(semeval_train.filter(lambda s: s["dataset"] == dataset_id)) for dataset_id in unique_train_datasets}

def compute_weighted_global_metrics(model_results, dataset_sizes):
    weighted_sums = defaultdict(float)
    total_size = sum(dataset_sizes[ds] for ds in model_results if ds != "GLOBAL")

    for dataset_id, metrics in model_results.items():
        if dataset_id == "GLOBAL":
            continue
        weight = dataset_sizes[dataset_id]
        for k, v in metrics.items():
            weighted_sums[k] += v * weight

    return {k: weighted_sums[k] / total_size for k in weighted_sums}

# Compute and store weighted global average
global_model_results = {}
global_model_results["GLOBAL"] = compute_weighted_global_metrics(model_results, dataset_sizes)

# Display as markdown table
global_df = pd.DataFrame(global_model_results).T.round(3)
print("\n### Global Metrics Across All Datasets (Weighted):")
print(global_df.to_markdown())
# Out:
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]
# ### Global Metrics Across All Datasets (Weighted):
# |        |   avg |   boolean |   number |   category |   list[category] |   list[number] |   single col |   multiple cols |
# |:-------|------:|----------:|---------:|-----------:|-----------------:|---------------:|-------------:|----------------:|
# | GLOBAL |  0.31 |     0.557 |    0.322 |      0.311 |            0.146 |          0.211 |        0.403 |            0.19 |
