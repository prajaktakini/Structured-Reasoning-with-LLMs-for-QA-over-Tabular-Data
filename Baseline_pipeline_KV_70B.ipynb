# %%
USE_GROQ = True  # Set to False to use OpenAI
REQUEST_DELAY = 0.5

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# !pip install openai
# !pip install groq
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.76.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: groq in /usr/local/lib/python3.11/dist-packages (0.24.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.0)

# %%
# Core libraries
import os
import re
import json
from groq import Groq
import openai
import json
import ast

# Data handling
import pandas as pd
from datasets import load_dataset
from collections import defaultdict


# Model & inference (if using Hugging Face transformers)
# from transformers import (
#     AutoTokenizer,
#     AutoModelForCausalLM,
#     BitsAndBytesConfig,
#     pipeline
# )

# Evaluation (optional at this stage since you're not doing full metrics yet)
from sklearn.metrics import accuracy_score

# PyTorch (only if needed for model management or tensor ops)
import torch

from itertools import cycle

from huggingface_hub import login
login("TOKEN")

# %%
# Set your Groq API key here or via Colab secrets
# os.environ["GROQ_API_KEY"] = "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"
# List of your GROQ API keys
GROQ_API_KEYS = [
    # paid
    "API_KEY",
]


# Create a cycling iterator over the API keys
groq_clients = [Groq(api_key=key) for key in GROQ_API_KEYS]
groq_client_cycle = cycle(groq_clients)

# os.environ["OPENAI_KEY"] = "<insert OpenAI key here>"

# Initialize Groq client
# groq_client = Groq(api_key=os.environ["GROQ_API_KEY"])

# %%
dataset_name = "cardiffnlp/databench"
semeval_train = load_dataset(dataset_name, name="qa", split="train")
# semeval_dev = load_dataset(dataset_name, name="semeval", split="dev")

# dev_target_datasets = ['051_Pokemon', '052_Professional', '055_German']
# semeval_dev = semeval_dev.filter(lambda sample: sample['dataset'] in dev_target_datasets)

# train_target_datasets = ['051_Pokemon', '052_Professional', '055_German']

# Not running:  "014_Airbnb", "020_Real", "035_Billboard", "049_Boris", "054_Joe",

train_target_datasets = [
    "001_Forbes", "002_Titanic", "004_Taxi", "005_NYC",
    "006_London", "007_Fifa", "008_Tornados", "009_Central", "010_ECommerce",
    "011_SF", "012_Heart", "013_Roller", "015_Food",
    "016_Holiday", "017_Hacker", "018_Staff", "019_Aircraft",
    "021_Telco", "022_Airbnbs", "023_Climate", "024_Salary", "025_Data",
    "026_Predicting", "027_Supermarket", "028_Predict", "029_NYTimes", "030_Professionals",
    "031_Trustpilot", "032_Delicatessen", "033_Employee", "034_World",
    "036_US", "037_Ted", "038_Stroke", "039_Happy", "040_Speed",
    "041_Airline", "042_Predict", "043_Predict", "044_IMDb", "045_Predict",
    "046_120", "047_Bank", "048_Data",  "050_ING",
    "051_Pokemon", "052_Professional", "053_Patents", "055_German",
    "056_Emoji", "057_Spain", "058_US", "059_Second", "060_Bakery",
    "061_Disneyland", "062_Trump", "063_Influencers", "064_Clustering", "065_RFM"
]

semeval_train = semeval_train.filter(lambda sample: sample['dataset'] in train_target_datasets)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Filter:   0%|          | 0/1308 [00:00<?, ? examples/s]

# %%
dev_dataset_map = {}
unique_dev_datasets = list(set(semeval_train.unique("dataset")))

for dataset in unique_dev_datasets:
    dev_dataset_map[dataset] = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{dataset}/sample.parquet")
# Out:
# Flattening the indices:   0%|          | 0/1185 [00:00<?, ? examples/s]

# %%
def clean_column_name(col_name):
    # Use regex to remove the <gx:...> part
    cleaned = re.sub(r'<gx:[^>]+>', '', col_name)
    return cleaned

for ds in dev_dataset_map.keys():
    # Get the original dataframe
    df = dev_dataset_map[ds]

    column_mapping = {col: clean_column_name(col) for col in df.columns}

    # Rename the columns in the dataframe
    df = df.rename(columns=column_mapping)

    # Store the updated dataframe back in the hashmap
    dev_dataset_map[ds] = df

# %%
def safe_parse_list(raw):
    import ast
    import re

    if isinstance(raw, list):
        return raw

    if isinstance(raw, str):
        try:
            # Step 1: Try literal_eval first (may work if quotes are fine)
            parsed = ast.literal_eval(raw)
            if isinstance(parsed, list):
                return parsed
        except:
            pass

        try:
            # Step 2: Manually repair unquoted or single-quoted elements
            if raw.startswith("[") and raw.endswith("]"):
                inner = raw[1:-1].strip()
                if inner and not inner.startswith(("'", '"')):
                    # Case: [Weight, Height]
                    parts = [p.strip() for p in inner.split(",")]
                    quoted = [f'"{p}"' for p in parts if p]
                    fixed = "[" + ", ".join(quoted) + "]"
                else:
                    # Case: ["What's your name?"]
                    # Escape inner quotes
                    inner = raw[1:-1]
                    fixed_inner = re.sub(r'(["\'])', r'\\\1', inner)
                    fixed = f'["{fixed_inner}"]'
                parsed = ast.literal_eval(fixed)
                if isinstance(parsed, list):
                    return parsed
        except Exception as e:
            print(f"Failed to parse used_cols string: {raw} | Reason: {e}")

    return raw # should never happen

def clean_columns_used(col_list):
    parsed = safe_parse_list(col_list)

    if not isinstance(parsed, list):
        return [str(parsed)] if parsed is not None else []

    cleaned = []
    for col in parsed:
        col = str(col)
        col = re.sub(r"<gx:[^>]+>", "", col).strip()
        cleaned.append(col)
    return cleaned

def update_columns_used(example):
    example["columns_used"] = clean_columns_used(example.get("columns_used"))
    return example

semeval_train = semeval_train.map(update_columns_used)
# Out:
# Map:   0%|          | 0/1185 [00:00<?, ? examples/s]

# %%
def serialize_to_kv_format(df, dropna=True):
    kv_serialized = []
    for _, row in df.iterrows():
        kv_pairs = []
        for col, val in row.items():
            if pd.isna(val) and dropna:
                continue
            if isinstance(val, str):
                val = f'"{val}"'
            kv_pairs.append(f"{col}: {val}")
        row_str = "{" + ", ".join(kv_pairs) + "}"
        kv_serialized.append(row_str)
    return kv_serialized

def build_prompt(df: pd.DataFrame, question: str, explain: bool = False) -> str:
    kv_serialized = serialize_to_kv_format(df)
    response_format = (
        'You must answer in a single JSON with two fields:\n'
        '* "answer": your final answer based on the records.\n'
        '* "columns_used": list of relevant columns.'
    )
    # prompt_body = f"""You are an assistant tasked with answering the questions asked of a given dataset in JSON format.\n{response_format}\nRequirements:\n* Only respond with the JSON. Your answer must contain only the final value(s), not explanations or full objects.\nIn the following key-value formatted data:\n```kv\n{kv_serialized}\n```\nUSER: {question}\nASSISTANT:"""
    prompt_body = (
        "You are an assistant tasked with answering questions asked of a given dataset in JSON format.\n"
        f"{response_format}\n"
        "Requirements:\n"
        "* Only respond with the JSON. Do not include explanations or full objects.\n"
        "* Your answer must use valid Python data types:\n"
        "  - Use `True` or `False` (capitalized) for boolean values.\n"
        "  - Use numbers as Python `int` or `float` (e.g., `3`, `3.14`).\n"
        "  - Use double-quoted Python strings for categorical values (e.g., \"USA\").\n"
        "  - Use Python lists for answers involving multiple values:\n"
        "    - For list[category], return a list of strings.\n"
        "    - For list[number], return a list of ints or floats.\n"
        "    - Ensure all inner values match the correct type.\n"
        "* Do not include explanations or justification.\n\n"
        "In the following key-value formatted data:\n"
        "  ⁠kv\n"
        f"{kv_serialized}\n"
        "⁠  \n"
        f"USER: {question}\n"
        "ASSISTANT:"
    )

    return f"[INST]\n{prompt_body}\n[/INST]"

# %%
# def generate_model_response(prompt):
#     if USE_GROQ:
#         response = groq_client.chat.completions.create(
#             # model="llama3-8b-8192",
#             model="meta-llama/llama-4-scout-17b-16e-instruct",
#             messages=[{"role": "user", "content": prompt}],
#             temperature=0.7,
#             max_tokens=512,
#             top_p=1.0
#         )
#         return response.choices[0].message.content

#     else:
#         response = openai.ChatCompletion.create(
#             model="gpt-3.5-turbo",
#             messages=[{"role": "user", "content": prompt}],
#             temperature=0.7,
#             max_tokens=512,
#             top_p=1.0
#         )
#         return response.choices[0].message["content"]

def generate_model_response(prompt):
    """
    Generates a response using Groq (LLaMA-3) or OpenAI (GPT-3.5).
    Falls back across multiple Groq keys if needed.
    """
    if USE_GROQ:
        for attempt in range(len(groq_clients)):
            groq_client = next(groq_client_cycle)

            try:
                response = groq_client.chat.completions.create(
                    # model="llama3-8b-8192",
                    model="llama3-70b-8192",
                    messages=[{"role": "user", "content": prompt}],
                    temperature=0.7,
                    max_tokens=512,
                    top_p=1.0
                )
                return response.choices[0].message.content

            except Exception as e:
                print(f"[Groq Attempt {attempt + 1}] Error: {e}")
                continue

        return "All Groq API keys exhausted or rate limited."

    else:
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.7,
                max_tokens=512,
                top_p=1.0
            )
            return response.choices[0].message["content"]

        except Exception as e:
            return f"OpenAI request failed: {e}"

# %%
def normalize_number(value):
    if isinstance(value, (int, float)):
        return float(value)
    if isinstance(value, str):
        return float(value.strip())
    raise ValueError(f"Expected numeric type for number, got: {type(value)}")

def normalize_category(value):
    if isinstance(value, str):
        return value.strip()
    raise ValueError(f"Expected string for category, got: {type(value)}")

def normalize_boolean(value):
    if isinstance(value, bool):
        return value
    if isinstance(value, str):
        val = value.strip().lower()
        if val in {"true", "1", "yes"}:
            return True
        elif val in {"false", "0", "no"}:
            return False
        else:
            raise ValueError(f"Unrecognized string for boolean: {value!r}")
    if isinstance(value, (int, float)):
        if value == 1:
            return True
        elif value == 0:
            return False
        else:
            raise ValueError(f"Numeric value not valid for boolean: {value}")
    raise ValueError(f"Expected bool, int, float, or string for boolean, got: {type(value)}")

# %%
def normalize_list_category(answer):
    """
    Normalize an answer of type list[category] into a set of cleaned strings.
    Handles both true lists and stringified list representations,
    and removes stray square brackets from individual elements.
    """
    def clean_item(x):
        x = str(x).strip()
        if x.startswith("["):
            x = x[1:]
        if x.endswith("]"):
            x = x[:-1]
        return x.strip()

    if isinstance(answer, str):
        try:
            parsed = ast.literal_eval(answer)
            if isinstance(parsed, list):
                answer = parsed
            else:
                answer = [item.strip() for item in answer.split(",") if item.strip()]
        except:
            answer = [item.strip() for item in answer.split(",") if item.strip()]

    if isinstance(answer, list):
        return set(clean_item(x) for x in answer)

    return set()  # fallback

# %%
def normalize_list_number(value):
    """
    Normalizes a predicted or gold value for list[number] questions.

    Expected input:
    - a string representing a list of numbers, e.g., "[2, 2, 2]"
    - OR a Python list of numbers
    - OR a stringified CSV like "2, 2, 2"

    Returns:
    - A set of floats
    """
    try:
        if isinstance(value, str):
            try:
                # Try parsing as JSON list
                value = json.loads(value)
            except json.JSONDecodeError:
                try:
                    value = ast.literal_eval(value)
                except:
                    # fallback: comma-separated
                    value = [item.strip() for item in value.split(",") if item.strip()]
        return set(float(v) for v in value)
    except Exception as e:
        print(f"normalize_list_number error: {e}")
        return None

# %%
def normalize_answer(value, expected_type):
    """
    Dispatches to the appropriate normalization function based on expected_type.
    """
    try:
        if expected_type == "number":
            return normalize_number(value)
        elif expected_type == "category":
            return normalize_category(value)
        elif expected_type == "boolean":
            return normalize_boolean(value)
        elif expected_type == "list[category]":
            return normalize_list_category(value)
        elif expected_type == "list[number]":
            return normalize_list_number(value)
        else:
            raise ValueError(f"Unsupported expected type: {expected_type}")
    except Exception as e:
        print(f"normalize_answer error for type '{expected_type}': {e}")
        return None

# %%
def normalize_columns(value):
    """
    Normalize a gold or predicted column list into a set of strings,
    preserving casing and special characters.
    """
    try:
        if isinstance(value, str):
            # Try parsing as a list
            try:
                parsed = ast.literal_eval(value)
                if isinstance(parsed, list):
                    value = parsed
                else:
                    # fallback: comma-split string
                    value = [item.strip() for item in value.split(",") if item.strip()]
            except:
                value = [item.strip() for item in value.split(",") if item.strip()]

        if isinstance(value, list):
            return set(str(x).strip() for x in value)

    except Exception as e:
        print(f"normalize_columns error: {e}")

    return set()  # fallback

# %%
error_dict = {}

# %%
import json
import ast

def process_response(generated_text, question, expected_type, error_set):
    """
    Processes the raw LLM response to extract and normalize the answer and columns.

    Args:
        generated_text (str): Raw text output from the LLM.
        question (str): The question (used for debugging).
        expected_type (str): The expected type of the answer (e.g., boolean, number).
        error_set (set): A set to store questions that had format errors.

    Returns:
        Tuple[bool, Any, List[str]]:
            - is_error (bool): True if formatting/parsing failed.
            - norm_answer: normalized answer or None on failure.
            - norm_columns: normalized list of columns or [] on failure.
    """
    is_error = False
    norm_answer = None
    norm_columns = []

    try:
        # Step 1: Trim response
        generated_text = generated_text.strip()

        # Step 2: Try to isolate a dictionary from the output
        start = generated_text.find('{')
        end = generated_text.rfind('}') + 1
        if start == -1 or end == -1:
            raise ValueError("Could not find a JSON-like object")

        json_str = generated_text[start:end]

        # Fix lowercase true/false if needed
        json_str_fixed = json_str.replace("true", "True").replace("false", "False")

        # Step 3: Try parsing as JSON first, fallback to ast.literal_eval
        try:
            response_json = json.loads(json_str)
        except json.JSONDecodeError:
            response_json = ast.literal_eval(json_str_fixed)

        # Step 4: Ensure expected keys exist
        if "answer" not in response_json or "columns_used" not in response_json:
            raise KeyError("Missing 'answer' or 'columns_used' in response")

        raw_answer = response_json["answer"]
        raw_columns = response_json["columns_used"]

        # Step 5: Normalize both fields
        norm_answer = normalize_answer(raw_answer, expected_type)
        norm_columns = normalize_columns(raw_columns)

    except Exception as e:
        # On any failure, flag error and return safe defaults
        print(f"[process_response] Failed to parse response for question: {question}")
        print(f"Error: {e}")
        is_error = True
        error_set.add(question)
        norm_answer = None
        norm_columns = []

    # Return tuple: (was error?, normalized answer, normalized columns)
    return is_error, norm_answer, norm_columns

# %%
example = semeval_train[0]
question = example["question"]
dataset_id = example["dataset"]
expected_type = example["type"]
true_answer = normalize_answer(example["sample_answer"], expected_type)
true_columns = normalize_columns(example["columns_used"])

print(f"Type(true_answer) {type(true_answer)}")
print(f"Type(true_columns) {type(true_columns)}")

df = dev_dataset_map[dataset_id]
prompt = build_prompt(df, question)
# print("=== Prompt ===\n", prompt[:1000])  # Truncated for readability

model_output = generate_model_response(prompt)
# print("=== Raw Model Output ===\n", model_output)

sample_error_set = set()

isPredError, pred_answer, pred_cols = process_response(model_output, question, expected_type, sample_error_set)

print(f"\nType(pred_answer) {type(pred_answer)}")
print(f"Type(pred_columns) {type(pred_cols)}")

print(f"\nQuestion: {question}")
print(f"Is Error? : {isPredError}")
print(f"Gold Answer: {true_answer}, Predicted: {pred_answer}")
print(f"Gold Columns: {true_columns}, Predicted: {pred_cols}\n")
# Out:
# Type(true_answer) <class 'bool'>
# Type(true_columns) <class 'set'>
#
# Type(pred_answer) <class 'bool'>
# Type(pred_columns) <class 'set'>
#
# Question: Is the person with the highest net worth self-made?
# Is Error? : False
# Gold Answer: False, Predicted: False
# Gold Columns: {'selfMade', 'finalWorth'}, Predicted: {'selfMade', 'finalWorth'}

# %%
import time

def safe_generate_response(prompt, retries=1, delay=3):
    attempts = 0
    while attempts <= retries:
        try:
            return generate_model_response(prompt)
        except Exception as e:
            print(f"[Attempt {attempts+1}] Error: {repr(e)}")
            time.sleep(delay)
            attempts += 1
    print("Failed all attempts. Returning empty response.")
    return ""

# %%
def evaluate_dataset(dataset_rows, dataset_name, dev_dataset_map, request_delay=1.5):
    pred_answers = []
    gold_answers = []
    pred_columns = []
    gold_columns = []
    question_types = []

    type_wise_correct = defaultdict(int)
    type_wise_total = defaultdict(int)
    column_match_count = 0
    error_set = set()
    formatting_errors_by_type = defaultdict(int)

    print(f"# Questions in {dataset_name}: {len(dataset_rows)}")

    for i, row in enumerate(dataset_rows):
        print(f"\n--- Query {i+1}/{len(dataset_rows)} ---")

        question = row["question"]
        dataset = row["dataset"]
        expected_type = row["type"]

        gold_answer = normalize_answer(row["sample_answer"], expected_type)
        gold_cols = normalize_columns(row["columns_used"])

        df = dev_dataset_map[dataset]
        prompt = build_prompt(df, question)

        response = safe_generate_response(prompt)
        time.sleep(request_delay)
        print("\n--- Raw LLM Response ---")
        print(response)

        is_error, pred_answer, pred_cols = process_response(response, question, expected_type, error_set)
        if is_error:
            formatting_errors_by_type[expected_type] += 1

        print(f"\nQuestion: {question}")
        print(f"Pred Answer: {pred_answer}, Gold Answer: {gold_answer}")
        print(f"Pred Columns: {pred_cols}, Gold Columns: {gold_cols}")

        pred_answers.append(pred_answer)
        gold_answers.append(gold_answer)
        pred_columns.append(pred_cols)
        gold_columns.append(gold_cols)
        question_types.append(expected_type)
        type_wise_total[expected_type] += 1

        correct = False
        try:
            if expected_type == "number":
                correct = abs(pred_answer - gold_answer) < 1e-3
            else:
                correct = pred_answer == gold_answer
        except:
            correct = False

        if correct:
            type_wise_correct[expected_type] += 1

        if isinstance(pred_cols, (list, set)) and set(pred_cols) == set(gold_cols):
            column_match_count += 1

    print("\n=== Answer Accuracy by Type ===")
    for qtype in type_wise_total:
        total = type_wise_total[qtype]
        correct = type_wise_correct[qtype]
        acc = correct / total if total else 0
        print(f"{qtype:15}: {acc:.2%} ({correct}/{total})")

    total = len(dataset_rows)
    col_acc = column_match_count / total if total else 0
    print(f"\n=== Column Selection Accuracy ===\n{col_acc:.2%} ({column_match_count}/{total})")

    eval_records = []
    for i in range(len(dataset_rows)):
        eval_records.append({
            "type": question_types[i],
            "gold_answer": gold_answers[i],
            "pred_answer": pred_answers[i],
            "gold_columns": gold_columns[i],
            "pred_columns": pred_columns[i],
        })

    # Final column stats
    wrong_cols = 0
    right_cols = 0
    format_errors = 0
    for i, (pred, gold) in enumerate(zip(pred_columns, gold_columns)):
        question = dataset_rows[i]["question"]

        if question in error_set:
            format_errors += 1
            continue

        if isinstance(pred, (list, set)):
            if set(pred) == set(gold):
                right_cols += 1
            else:
                wrong_cols += 1
        else:
            format_errors += 1  # fallback, shouldn't happen


    column_stats = {
        "wrong_cols": wrong_cols,
        "right_cols": right_cols,
        "format_error": format_errors,
        "total": len(dataset_rows)
    }

    return eval_records, column_stats, formatting_errors_by_type

# %%
def compute_metrics(eval_records, model_name, model_results):
    results = defaultdict(float)
    total = len(eval_records)
    correct_all = 0
    typewise = defaultdict(lambda: [0, 0])
    colwise = {'single': [0, 0], 'multi': [0, 0]}

    for record in eval_records:
        t = record['type'].strip().lower()
        gold_answer = record['gold_answer']
        pred_answer = record['pred_answer']
        gold_cols = set(record['gold_columns'])
        pred_cols = set(record['pred_columns'])

        try:
            if t == "number":
                answer_match = abs(pred_answer - gold_answer) < 1e-3
            else:
                answer_match = pred_answer == gold_answer
        except:
            answer_match = False

        col_match = gold_cols == pred_cols
        joint_match = answer_match and col_match
        if joint_match:
            correct_all += 1

        typewise[t][1] += 1
        if joint_match:
            typewise[t][0] += 1

        col_count = len(gold_cols)
        if col_count == 1:
            colwise['single'][1] += 1
            if joint_match:
                colwise['single'][0] += 1
        else:
            colwise['multi'][1] += 1
            if joint_match:
                colwise['multi'][0] += 1

    def get_acc(dic, key):
        correct, total = dic[key]
        return correct / total if total else 0

    results['avg'] = correct_all / total if total else 0
    results['boolean'] = get_acc(typewise, 'boolean')
    results['number'] = get_acc(typewise, 'number')
    results['category'] = get_acc(typewise, 'category')
    results['list[category]'] = get_acc(typewise, 'list[category]')
    results['list[number]'] = get_acc(typewise, 'list[number]')
    results['single col'] = get_acc(colwise, 'single')
    results['multiple cols'] = get_acc(colwise, 'multi')

    model_results[model_name] = dict(results)

# %%
def format_percent_and_count(val, total):
    percent = 100 * val / total if total else 0
    return f"{percent:.1f} ({val})"

# %%
# # Step 1: Filter dataset
# pokemon_rows = semeval_dev.filter(lambda sample: sample["dataset"] == "051_Pokemon")

# # Step 2: Dictionary to hold results
# model_results = {}

# # Step 3: Run evaluation
# records, col_stats, formatting_errors_by_type = evaluate_dataset(
#     pokemon_rows, dataset_name="Pokemon", dev_dataset_map=dev_dataset_map
# )

# # Step 4: Compute main metrics
# compute_metrics(records, "baseline_llm", model_results)

# # Step 5a: Table 1 – main metrics
# results_df = pd.DataFrame(model_results).T.round(3)
# print("### Main Metrics Table:")
# print(results_df.to_markdown())

# # Step 5b: Table 2 – column quality summary

# col_eval_table = [{
#     "model": "baseline_llm",
#     "wrong cols": format_percent_and_count(col_stats["wrong_cols"], col_stats["total"]),
#     "right cols": format_percent_and_count(col_stats["right_cols"], col_stats["total"]),
#     "format error": format_percent_and_count(col_stats["format_error"], col_stats["total"]),
# }]

# col_df = pd.DataFrame(col_eval_table)
# print("\n### Column Quality Table:")
# print(col_df.to_markdown(index=False))

# # Step 5c: Formatting errors by type
# print("\n### Formatting Errors by Question Type:")
# for qtype, count in formatting_errors_by_type.items():
#     print(f"{qtype:15}: {count} formatting errors")

# %%
# model_results = {}
# column_quality_table = []
# formatting_errors_summary = defaultdict(int)

# for dataset_id in train_target_datasets:

#     dataset_rows = semeval_train.filter(lambda sample: sample["dataset"] == dataset_id)
#     print(f"\n\n### Evaluating {dataset_id} ###")

#     records, col_stats, formatting_errors_by_type = evaluate_dataset(
#         dataset_rows, dataset_name=dataset_id, dev_dataset_map=dev_dataset_map
#     )

#     compute_metrics(records, dataset_id, model_results)

#     column_quality_table.append({
#         "model": dataset_id,
#         "wrong cols": format_percent_and_count(col_stats["wrong_cols"], col_stats["total"]),
#         "right cols": format_percent_and_count(col_stats["right_cols"], col_stats["total"]),
#         "format error": format_percent_and_count(col_stats["format_error"], col_stats["total"]),
#     })

#     for qtype, count in formatting_errors_by_type.items():
#         formatting_errors_summary[qtype] += count



all_eval_records = []
model_results = {}
column_quality_table = []
formatting_errors_summary = defaultdict(int)

for dataset_id in train_target_datasets:

    dataset_rows = semeval_train.filter(lambda sample: sample["dataset"] == dataset_id)
    print(f"\n\n### Evaluating {dataset_id} ###")

    records, col_stats, formatting_errors_by_type = evaluate_dataset(
        dataset_rows, dataset_name=dataset_id, dev_dataset_map=dev_dataset_map
    )

    compute_metrics(records, dataset_id, model_results)

    all_eval_records.extend(records)

    column_quality_table.append({
        "model": dataset_id,
        "wrong cols": format_percent_and_count(col_stats["wrong_cols"], col_stats["total"]),
        "right cols": format_percent_and_count(col_stats["right_cols"], col_stats["total"]),
        "format error": format_percent_and_count(col_stats["format_error"], col_stats["total"]),
    })

    for qtype, count in formatting_errors_by_type.items():
        formatting_errors_summary[qtype] += count
# Out:
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 001_Forbes ###
# # Questions in 001_Forbes: 25
#
# --- Query 1/25 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["finalWorth", "selfMade"]}
#
# Question: Is the person with the highest net worth self-made?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'selfMade', 'finalWorth'}, Gold Columns: {'selfMade', 'finalWorth'}
#
# --- Query 2/25 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["gender", "age"]}
#
# Question: Does the youngest billionaire identify as male?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'gender', 'age'}, Gold Columns: {'gender', 'age'}
#
# --- Query 3/25 ---
#
# --- Raw LLM Response ---
# {"answer": "New York", "columns_used": ["city", "country"]}
# normalize_answer error for type 'boolean': Unrecognized string for boolean: 'New York'
#
# Question: Is the city with the most billionaires in the United States?
# Pred Answer: None, Gold Answer: True
# Pred Columns: {'country', 'city'}, Gold Columns: {'country', 'city'}
#
# --- Query 4/25 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["selfMade", "rank"]}
#
# Question: Is there a non-self-made billionaire in the top 5 ranks?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'selfMade', 'rank'}, Gold Columns: {'selfMade', 'rank'}
#
# --- Query 5/25 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["age", "philanthropyScore"]}
#
# Question: Does the oldest billionaire have a philanthropy score of 5?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'philanthropyScore', 'age'}, Gold Columns: {'philanthropyScore', 'age'}
#
# --- Query 6/25 ---
#
# --- Raw LLM Response ---
# {"answer": 32.0, "columns_used": ["age"]}
#
# Question: What is the age of the youngest billionaire?
# Pred Answer: 32.0, Gold Answer: 32.0
# Pred Columns: {'age'}, Gold Columns: {'age'}
#
# --- Query 7/25 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["category"]}
#
# Question: How many billionaires are there from the 'Technology' category?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: {'category'}, Gold Columns: {'category'}
#
# --- Query 8/25 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["finalWorth", "category", "source"]}
#
# Question: What's the total worth of billionaires in the 'Automotive' category?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: {'finalWorth', 'source', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# --- Query 9/25 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["philanthropyScore"]}
#
# Question: How many billionaires have a philanthropy score above 3?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: {'philanthropyScore'}, Gold Columns: {'philanthropyScore'}
#
# --- Query 10/25 ---
#
# --- Raw LLM Response ---
# {"answer": 288, "columns_used": ["finalWorth", "selfMade", "rank"]}
#
# Question: What's the rank of the wealthiest non-self-made billionaire?
# Pred Answer: 288.0, Gold Answer: 288.0
# Pred Columns: {'selfMade', 'rank', 'finalWorth'}, Gold Columns: {'selfMade', 'rank'}
#
# --- Query 11/25 ---
#
# --- Raw LLM Response ---
# {"answer": "Media & Entertainment", "columns_used": ["finalWorth", "category"]}
#
# Question: Which category does the richest billionaire belong to?
# Pred Answer: Media & Entertainment, Gold Answer: Food & Beverage
# Pred Columns: {'finalWorth', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# --- Query 12/25 ---
#
# --- Raw LLM Response ---
# {"answer": "United Kingdom", "columns_used": ["country", "age"]}
#
# Question: What's the country of origin of the oldest billionaire?
# Pred Answer: United Kingdom, Gold Answer: United Kingdom
# Pred Columns: {'country', 'age'}, Gold Columns: {'country', 'age'}
#
# --- Query 13/25 ---
#
# --- Raw LLM Response ---
# {"answer": "M", "columns_used": ["philanthropyScore", "gender"]}
#
# Question: What's the gender of the billionaire with the highest philanthropy score?
# Pred Answer: M, Gold Answer: M
# Pred Columns: {'philanthropyScore', 'gender'}, Gold Columns: {'philanthropyScore', 'gender'}
#
# --- Query 14/25 ---
#
# --- Raw LLM Response ---
# {"answer": "fintech", "columns_used": ["age", "source"]}
#
# Question: What's the source of wealth for the youngest billionaire?
# Pred Answer: fintech, Gold Answer: fintech
# Pred Columns: {'age', 'source'}, Gold Columns: {'age', 'source'}
#
# --- Query 15/25 ---
# normalize_answer error for type 'category': Expected string for category, got: <class 'NoneType'>
#
# --- Raw LLM Response ---
# {"answer": "Chairman", "columns_used": ["title", "rank"]}
#
# Question: What is the title of the billionaire with the lowest rank?
# Pred Answer: Chairman, Gold Answer: None
# Pred Columns: {'title', 'rank'}, Gold Columns: {'title', 'rank'}
#
# --- Query 16/25 ---
#
# --- Raw LLM Response ---
# {"answer": ["United States", "China", "Brazil"], "columns_used": ["country"]}
#
# Question: List the top 3 countries with the most billionaires.
# Pred Answer: {'Brazil', 'China', 'United States'}, Gold Answer: {'Brazil', 'China', 'United States'}
# Pred Columns: {'country'}, Gold Columns: {'country'}
#
# --- Query 17/25 ---
#
# --- Raw LLM Response ---
# {"answer": ["media, automotive", "real estate"], "columns_used": ["source"]}
#
# Question: List the top 2 most common sources of wealth for billionaires.
# Pred Answer: {'real estate', 'media, automotive'}, Gold Answer: {'media, automotive', 'diversified'}
# Pred Columns: {'source'}, Gold Columns: {'source'}
#
# --- Query 18/25 ---
#
# --- Raw LLM Response ---
# {"answer": ["San Francisco", "Singapore", "Toronto", "New York"], "columns_used": ["city", "age"]}
#
# Question: List the 4 cities where the four youngest billionaires live.
# Pred Answer: {'San Francisco', 'Toronto', 'Singapore', 'New York'}, Gold Answer: {'San Francisco', 'Bangalore', 'Wuhan', 'New York'}
# Pred Columns: {'age', 'city'}, Gold Columns: {'city', 'age'}
#
# --- Query 19/25 ---
#
# --- Raw LLM Response ---
# {"answer": ["Service", "Finance & Investments", "Manufacturing", "Food & Beverage"], "columns_used": ["category"]}
#
# Question: List the 4 categories with the fewest billionaires.
# Pred Answer: {'Service', 'Manufacturing', 'Food & Beverage', 'Finance & Investments'}, Gold Answer: {'Service', 'Fashion & Retail', 'Manufacturing', 'Real Estate'}
# Pred Columns: {'category'}, Gold Columns: {'category'}
#
# --- Query 20/25 ---
#
# --- Raw LLM Response ---
# {"answer": ["Canada", "Egypt"], "columns_used": ["country"]}
#
# Question: List the 2 countries with the least number of billionaires. If there are more than two with the same number take the first two alphabetically.
# Pred Answer: {'Canada', 'Egypt'}, Gold Answer: {'Canada', 'Egypt'}
# Pred Columns: {'country'}, Gold Columns: {'country'}
#
# --- Query 21/25 ---
#
# --- Raw LLM Response ---
# {"answer": [296, 523, 288, 601, 1196], "columns_used": ["rank", "selfMade"]}
#
# Question: List the top 5 ranks of billionaires who are not self-made.
# Pred Answer: {288.0, 296.0, 523.0, 1196.0, 601.0}, Gold Answer: {288.0, 296.0, 523.0, 601.0, 509.0}
# Pred Columns: {'selfMade', 'rank'}, Gold Columns: {'selfMade', 'rank'}
#
# --- Query 22/25 ---
#
# --- Raw LLM Response ---
# {"answer": [], "columns_used": ["age", "philanthropyScore"]}
#
# Question: List the youngest 3 ages of billionaires who have a philanthropy score of 5.
# Pred Answer: set(), Gold Answer: set()
# Pred Columns: {'philanthropyScore', 'age'}, Gold Columns: {'philanthropyScore', 'age'}
#
# --- Query 23/25 ---
#
# --- Raw LLM Response ---
# {"answer": [], "columns_used": ["finalWorth", "category"]}
#
# Question: List the highest 6 final worth values of billionaires in the 'Technology' category.
# Pred Answer: set(), Gold Answer: set()
# Pred Columns: {'finalWorth', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# --- Query 24/25 ---
#
# --- Raw LLM Response ---
# {"answer": [523, 288], "columns_used": ["rank", "gender"]}
#
# Question: List the top 4 ranks of female billionaires.
# Pred Answer: {288.0, 523.0}, Gold Answer: set()
# Pred Columns: {'gender', 'rank'}, Gold Columns: {'gender', 'rank'}
#
# --- Query 25/25 ---
#
# --- Raw LLM Response ---
# {"answer": [7800], "columns_used": ["finalWorth", "category", "source"]}
#
# Question: List the top 2 final worth values of billionaires in the 'Automotive' category.
# Pred Answer: {7800.0}, Gold Answer: set()
# Pred Columns: {'finalWorth', 'source', 'category'}, Gold Columns: {'finalWorth', 'category'}
#
# === Answer Accuracy by Type ===
# boolean        : 60.00% (3/5)
# number         : 100.00% (5/5)
# category       : 60.00% (3/5)
# list[category] : 40.00% (2/5)
# list[number]   : 40.00% (2/5)
#
# === Column Selection Accuracy ===
# 88.00% (22/25)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 002_Titanic ###
# # Questions in 002_Titanic: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Age", "Survived"]}
#
# Question: Did any children below the age of 18 survive?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Age', 'Survived'}, Gold Columns: {'Age', 'Survived'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["Fare"]}
#
# Question: Were there any passengers who paid a fare of more than $500?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Fare'}, Gold Columns: {'Fare'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Name"]}
#
# Question: Is every passenger's name unique?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Name'}, Gold Columns: {'Name'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Pclass", "Sex", "Survived"]}
#
# Question: Were there any female passengers in the 3rd class who survived?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Pclass', 'Sex', 'Survived'}, Gold Columns: {'Pclass', 'Sex', 'Survived'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3, "columns_used": ["Pclass"]}
#
# Question: How many unique passenger classes are present in the dataset?
# Pred Answer: 3.0, Gold Answer: 3.0
# Pred Columns: {'Pclass'}, Gold Columns: {'Pclass'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 69.0, "columns_used": ["Age"]}
#
# Question: What's the maximum age of the passengers?
# Pred Answer: 69.0, Gold Answer: 69.0
# Pred Columns: {'Age'}, Gold Columns: {'Age'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 13, "columns_used": ["Siblings_Spouses Aboard"]}
#
# Question: How many passengers boarded without any siblings or spouses?
# Pred Answer: 13.0, Gold Answer: 12.0
# Pred Columns: {'Siblings_Spouses Aboard'}, Gold Columns: {'Siblings_Spouses Aboard'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 21.4795, "columns_used": ["Fare"]}
#
# Question: On average, how much fare did the passengers pay?
# Pred Answer: 21.4795, Gold Answer: 23.096459999999997
# Pred Columns: {'Fare'}, Gold Columns: {'Fare'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": 1, "columns_used": ["Pclass", "Survived"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: Which passenger class has the highest number of survivors?
# Pred Answer: None, Gold Answer: 3
# Pred Columns: {'Pclass', 'Survived'}, Gold Columns: {'Pclass', 'Survived'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": "female", "columns_used": ["Sex", "Survived"]}
#
# Question: What's the most common gender among the survivors?
# Pred Answer: female, Gold Answer: female
# Pred Columns: {'Sex', 'Survived'}, Gold Columns: {'Sex', 'Survived'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "0-50", "columns_used": ["Fare", "Survived"]}
#
# Question: Among those who survived, which fare range was the most common: (0-50, 50-100, 100-150, 150+)?
# Pred Answer: 0-50, Gold Answer: 0-50
# Pred Columns: {'Fare', 'Survived'}, Gold Columns: {'Fare', 'Survived'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "30-50", "columns_used": ["Age"]}
#
# Question: What's the most common age range among passengers: (0-18, 18-30, 30-50, 50+)?
# Pred Answer: 30-50, Gold Answer: 18-30
# Pred Columns: {'Age'}, Gold Columns: {'Age'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Pclass: 1", "Pclass: 2", "Pclass: 3"], "columns_used": ["Pclass", "Survived"]}
#
# Question: Name the top 3 passenger classes by survival rate.
# Pred Answer: {'Pclass: 3', 'Pclass: 2', 'Pclass: 1'}, Gold Answer: {'1', '3', '2'}
# Pred Columns: {'Pclass', 'Survived'}, Gold Columns: {'Pclass', 'Survived'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["0-50", "50-100", "100-150"], "columns_used": ["Fare", "Survived"]}
#
# Question: Could you list the 3 fare ranges present in the dataset with the least survivors: (0-50, 50-100, 100-150, 150+)?
# Pred Answer: {'0-50', '100-150', '50-100'}, Gold Answer: {'0-50', '100-150'}
# Pred Columns: {'Fare', 'Survived'}, Gold Columns: {'Fare', 'Survived'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["30-50", "18-30", "50+", "0-18"], "columns_used": ["Age", "Survived"]}
#
# Question: What are the top 4 age ranges ('30-50', '18-30', '0-18', '50+') with the highest number of survivors?
# Pred Answer: {'18-30', '0-18', '30-50', '50+'}, Gold Answer: {'18-30', '0-18', '30-50', '50+'}
# Pred Columns: {'Age', 'Survived'}, Gold Columns: {'Age', 'Survived'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["female", "male"], "columns_used": ["Sex", "Fare"]}
#
# Question: What are the top 2 genders by average fare paid?
# Pred Answer: {'male', 'female'}, Gold Answer: {'male', 'female'}
# Pred Columns: {'Fare', 'Sex'}, Gold Columns: {'Fare', 'Sex'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [56.0, 47.0, 42.0], "columns_used": ["Age", "Survived"]}
#
# Question: What are the oldest 3 ages among the survivors?
# Pred Answer: {56.0, 42.0, 47.0}, Gold Answer: {56.0, 42.0, 47.0}
# Pred Columns: {'Age', 'Survived'}, Gold Columns: {'Age', 'Survived'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [133.65, 39.0, 35.5, 30.5], "columns_used": ["Fare", "Survived"]}
#
# Question: Which are the top 4 fares paid by survivors?
# Pred Answer: {35.5, 133.65, 30.5, 39.0}, Gold Answer: {35.5, 133.65, 30.5, 39.0}
# Pred Columns: {'Fare', 'Survived'}, Gold Columns: {'Fare', 'Survived'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [14.0, 24.0, 28.0], "columns_used": ["Age", "Survived"]}
#
# Question: Could you list the youngest 3 ages among the survivors?
# Pred Answer: {24.0, 28.0, 14.0}, Gold Answer: {24.0, 28.0, 14.0}
# Pred Columns: {'Age', 'Survived'}, Gold Columns: {'Age', 'Survived'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [0.0, 7.75, 8.05, 10.1708], "columns_used": ["Fare", "Survived"]}
#
# Question: Which are the lowest 4 fares among those who didn't survive?
# Pred Answer: {0.0, 8.05, 10.1708, 7.75}, Gold Answer: {0.0, 8.05, 7.75, 7.22}
# Pred Columns: {'Fare', 'Survived'}, Gold Columns: {'Fare', 'Survived'}
#
# === Answer Accuracy by Type ===
# boolean        : 100.00% (4/4)
# number         : 50.00% (2/4)
# category       : 50.00% (2/4)
# list[category] : 50.00% (2/4)
# list[number]   : 75.00% (3/4)
#
# === Column Selection Accuracy ===
# 100.00% (20/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 004_Taxi ###
# # Questions in 004_Taxi: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["trip_distance"]}
#
# Question: Are there any trips with a total distance greater than 30 miles?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'trip_distance'}, Gold Columns: {'trip_distance'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["total_amount"]}
#
# Question: Were there any trips that cost more than $100 in total?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'total_amount'}, Gold Columns: {'total_amount'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["passenger_count"]}
#
# Question: Is there any trip with more than 6 passengers?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'passenger_count'}, Gold Columns: {'passenger_count'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["payment_type"]}
#
# Question: Did all the trips use a payment type of either 1 or 2?
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'payment_type'}, Gold Columns: {'payment_type'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 40.8, "columns_used": ["fare_amount"]}
#
# Question: What is the maximum fare amount charged for a trip?
# Pred Answer: 40.8, Gold Answer: 40.8
# Pred Columns: {'fare_amount'}, Gold Columns: {'fare_amount'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 24, "columns_used": ["PULocationID"]}
#
# Question: How many unique pickup locations are in the dataset?
# Pred Answer: 24.0, Gold Answer: 18.0
# Pred Columns: {'PULocationID'}, Gold Columns: {'PULocationID'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3.1368421052631578, "columns_used": ["tip_amount"]}
#
# Question: What is the average tip amount given by passengers?
# Pred Answer: 3.136842105263158, Gold Answer: 1.5
# Pred Columns: {'tip_amount'}, Gold Columns: {'tip_amount'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 4, "columns_used": ["PULocationID", "DOLocationID"]}
#
# Question: How many trips took place in the airport area?
# Pred Answer: 4.0, Gold Answer: 0.0
# Pred Columns: {'PULocationID', 'DOLocationID'}, Gold Columns: {'Airport_fee'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": 1, "columns_used": ["payment_type"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: Which payment type is the most common in the dataset?
# Pred Answer: None, Gold Answer: 1
# Pred Columns: {'payment_type'}, Gold Columns: {'payment_type'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": 2, "columns_used": ["VendorID"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: Which vendor has the most trips recorded?
# Pred Answer: None, Gold Answer: 2
# Pred Columns: {'VendorID'}, Gold Columns: {'VendorID'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "163", "columns_used": ["PULocationID"]}
#
# Question: What is the most common drop-off location?
# Pred Answer: 163, Gold Answer: 90
# Pred Columns: {'PULocationID'}, Gold Columns: {'DOLocationID'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "2023-02-01", "columns_used": ["tpep_pickup_datetime"]}
#
# Question: On which date did the first recorded trip occur?
# Pred Answer: 2023-02-01, Gold Answer: 2023-02-01
# Pred Columns: {'tpep_pickup_datetime'}, Gold Columns: {'tpep_pickup_datetime'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": [90, 163], "columns_used": ["DOLocationID"]}
#
# Question: Which are the top 2 most frequent pickup locations?
# Pred Answer: {'90', '163'}, Gold Answer: {'163', '161'}
# Pred Columns: {'DOLocationID'}, Gold Columns: {'PULocationID'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1], "columns_used": ["RatecodeID"]}
#
# Question: Name the 4 most common rate codes used.
# Pred Answer: {'1'}, Gold Answer: {'1'}
# Pred Columns: {'RatecodeID'}, Gold Columns: {'RatecodeID'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["N", "Y"], "columns_used": ["store_and_fwd_flag"]}
#
# Question: list the 2 most frequent store and forward flags.
# Pred Answer: {'Y', 'N'}, Gold Answer: {'Y', 'N'}
# Pred Columns: {'store_and_fwd_flag'}, Gold Columns: {'store_and_fwd_flag'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1, 1, 2, 3], "columns_used": ["payment_type"]}
#
# Question: Identify the top 4 payment types used by frequency
# Pred Answer: {'1', '3', '2'}, Gold Answer: {'1', '3', '2'}
# Pred Columns: {'payment_type'}, Gold Columns: {'payment_type'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [0, 0, 0, 0], "columns_used": ["tolls_amount"]}
#
# Question: Report the 4 highest toll amounts paid.
# Pred Answer: {0.0}, Gold Answer: {0.0}
# Pred Columns: {'tolls_amount'}, Gold Columns: {'tolls_amount'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [8.32, 5.93, 2.8], "columns_used": ["trip_distance"]}
#
# Question: list the top 3 longest trip distances
# Pred Answer: {8.32, 2.8, 5.93}, Gold Answer: {8.32, 2.8, 5.93}
# Pred Columns: {'trip_distance'}, Gold Columns: {'trip_distance'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [45.8, 39.9, 33.2, 24.87, 23.15], "columns_used": ["total_amount"]}
#
# Question: Identify the 5 largest total amounts paid for trips.
# Pred Answer: {33.2, 39.9, 45.8, 23.15, 24.87}, Gold Answer: {33.2, 39.9, 45.8, 24.87, 25.2}
# Pred Columns: {'total_amount'}, Gold Columns: {'total_amount'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [40.8, 28.9, 21.2, 17.0, 14.9, 13.5], "columns_used": ["fare_amount"]}
#
# Question: Report the 6 highest fare amounts charged.
# Pred Answer: {40.8, 13.5, 14.9, 17.0, 21.2, 28.9}, Gold Answer: {40.8, 13.5, 14.9, 17.0, 21.2, 28.9}
# Pred Columns: {'fare_amount'}, Gold Columns: {'fare_amount'}
#
# === Answer Accuracy by Type ===
# boolean        : 75.00% (3/4)
# number         : 25.00% (1/4)
# category       : 25.00% (1/4)
# list[category] : 75.00% (3/4)
# list[number]   : 75.00% (3/4)
#
# === Column Selection Accuracy ===
# 85.00% (17/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 005_NYC ###
# # Questions in 005_NYC: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["borough"]}
#
# Question: Are there any complaints made in Brooklyn?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'borough'}, Gold Columns: {'borough'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["descriptor"]}
#
# Question: Do any complaints have 'Dog' as a descriptor?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'descriptor'}, Gold Columns: {'descriptor'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["month_name"]}
#
# Question: Were there any complaints raised in April?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'month_name'}, Gold Columns: {'month_name'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["agency"]}
#
# Question: Is the Mayor's office of special enforcement one of the agencies handling complaints?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 9, "columns_used": ["borough"]}
#
# Question: How many complaints have been made in Queens?
# Pred Answer: 9.0, Gold Answer: 0.0
# Pred Columns: {'borough'}, Gold Columns: {'borough'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["agency"]}
#
# Question: What's the total number of unique agencies handling complaints?
# Pred Answer: 6.0, Gold Answer: 7.0
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 2, "columns_used": ["hour"]}
#
# Question: How many complaints were raised at midnight?
# Pred Answer: 2.0, Gold Answer: 2.0
# Pred Columns: {'hour'}, Gold Columns: {'hour'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 17, "columns_used": ["descriptor"]}
#
# Question: How many unique descriptors are present in the dataset?
# Pred Answer: 17.0, Gold Answer: 16.0
# Pred Columns: {'descriptor'}, Gold Columns: {'descriptor'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "QUEENS", "columns_used": ["borough"]}
#
# Question: Which borough has the most complaints?
# Pred Answer: QUEENS, Gold Answer: QUEENS
# Pred Columns: {'borough'}, Gold Columns: {'borough'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": "January", "columns_used": ["month_name"]}
#
# Question: Which month sees the highest number of complaints?
# Pred Answer: January, Gold Answer: January
# Pred Columns: {'month_name'}, Gold Columns: {'month_name'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Wednesday", "columns_used": ["weekday_name"]}
#
# Question: Which weekday has the least complaints?
# Pred Answer: Wednesday, Gold Answer: Thursday
# Pred Columns: {'weekday_name'}, Gold Columns: {'weekday_name'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "DPR", "columns_used": ["agency"]}
#
# Question: Which agency is least frequently handling complaints?
# Pred Answer: DPR, Gold Answer: DOHMH
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Noise - Residential", "Building/Use", "HEAT/HOT WATER", "Noise - Commercial", "Noise - Street/Sidewalk"], "columns_used": ["complaint_type"]}
#
# Question: List the top 5 most frequent complaint types.
# Pred Answer: {'Noise - Residential', 'Building/Use', 'Noise - Street/Sidewalk', 'HEAT/HOT WATER', 'Noise - Commercial'}, Gold Answer: {'Noise - Residential', 'Air Quality', 'Building/Use', 'HEAT/HOT WATER', 'General Construction/Plumbing'}
# Pred Columns: {'complaint_type'}, Gold Columns: {'complaint_type'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["NYPD", "HPD", "DOB", "DEP"], "columns_used": ["agency"]}
#
# Question: Which 4 agencies handle the most complaints?
# Pred Answer: {'DOB', 'HPD', 'NYPD', 'DEP'}, Gold Answer: {'DOB', 'DSNY', 'HPD', 'NYPD'}
# Pred Columns: {'agency'}, Gold Columns: {'agency'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["With License Plate", "Structure - Outdoors"], "columns_used": ["descriptor"]}
#
# Question: Name the 2 least frequent descriptors for complaints by inverse alphabetical order.
# Pred Answer: {'With License Plate', 'Structure - Outdoors'}, Gold Answer: {'12 Dead Animals', 'Restaurant (AD2)', 'Structure - Outdoors, Air: Odor/Fumes'}
# Pred Columns: {'descriptor'}, Gold Columns: {'descriptor'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Monday", "Tuesday"], "columns_used": ["weekday_name"]}
#
# Question: Mention the 2 most common weekdays for complaints.
# Pred Answer: {'Monday', 'Tuesday'}, Gold Answer: {'Monday', 'Wednesday'}
# Pred Columns: {'weekday_name'}, Gold Columns: {'weekday_name'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [18, 16, 11, 10], "columns_used": ["hour"]}
#
# Question: What are the top 4 hours with the most complaints?
# Pred Answer: {16.0, 10.0, 18.0, 11.0}, Gold Answer: {0.0, 16.0, 18.0, 21.0}
# Pred Columns: {'hour'}, Gold Columns: {'hour'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [18311800, 22322205, 25369019], "columns_used": ["unique_key"]}
#
# Question: State the 3 lowest unique complaint keys.
# Pred Answer: {18311800.0, 25369019.0, 22322205.0}, Gold Answer: {18311800.0, 25369019.0, 22322205.0}
# Pred Columns: {'unique_key'}, Gold Columns: {'unique_key'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [0, 7], "columns_used": ["hour"]}
#
# Question: Which 2 hours see the least complaints?
# Pred Answer: {0.0, 7.0}, Gold Answer: {8.0, 7.0}
# Pred Columns: {'hour'}, Gold Columns: {'hour'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [54188773, 51990440, 50082845, 49874401, 43655624, 43260648],
# "columns_used": ["unique_key"]
# }
#
# Question: List the 6 highest complaint numbers from the dataset.
# Pred Answer: {49874401.0, 54188773.0, 51990440.0, 43655624.0, 43260648.0, 50082845.0}, Gold Answer: {49874401.0, 54188773.0, 51990440.0, 43655624.0, 45481177.0, 50082845.0}
# Pred Columns: {'unique_key'}, Gold Columns: {'unique_key'}
#
# === Answer Accuracy by Type ===
# boolean        : 100.00% (4/4)
# number         : 25.00% (1/4)
# category       : 50.00% (2/4)
# list[category] : 0.00% (0/4)
# list[number]   : 25.00% (1/4)
#
# === Column Selection Accuracy ===
# 100.00% (20/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 006_London ###
# # Questions in 006_London: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["neighbourhood_cleansed"]}
#
# Question: Are all properties in the dataset located in the same neighbourhood?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'neighbourhood_cleansed'}, Gold Columns: {'neighbourhood_cleansed'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["host_identity_verified"]}
#
# Question: Do all hosts verify their identity?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'host_identity_verified'}, Gold Columns: {'host_identity_verified'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["reviews_per_month"]}
#
# Question: Are all reviews_per_month values greater than 5?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'reviews_per_month'}, Gold Columns: {'reviews_per_month'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["room_type"]}
#
# Question: Are there any listings without a specified room type?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'room_type'}, Gold Columns: {'room_type'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 19, "columns_used": ["neighbourhood_cleansed", "host_neighbourhood"]}
#
# Question: How many unique neighbourhoods are there in the dataset?
# Pred Answer: 19.0, Gold Answer: 20.0
# Pred Columns: {'neighbourhood_cleansed', 'host_neighbourhood'}, Gold Columns: {'host_neighbourhood'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": []}
#
# Question: How many listings don't have a valid price?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: set(), Gold Columns: {'price'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 0, "columns_used": ["review_scores_communication"]}
#
# Question: How many properties have received the worst possible (0-5) review score for communication?
# Pred Answer: 0.0, Gold Answer: 0.0
# Pred Columns: {'review_scores_communication'}, Gold Columns: {'review_scores_communication'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3.0, "columns_used": ["bedrooms"]}
#
# Question: What is the maximum number of bedrooms a property has in this dataset?
# Pred Answer: 3.0, Gold Answer: 3.0
# Pred Columns: {'bedrooms'}, Gold Columns: {'bedrooms'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Hammersmith and Fulham", "columns_used": ["neighbourhood_cleansed"]}
#
# Question: Which neighbourhood has the most listings?
# Pred Answer: Hammersmith and Fulham, Gold Answer: Hammersmith and Fulham
# Pred Columns: {'neighbourhood_cleansed'}, Gold Columns: {'neighbourhood_cleansed'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Private room", "columns_used": ["room_type"]}
#
# Question: What is the most common room type in the listings?
# Pred Answer: Private room, Gold Answer: Private room
# Pred Columns: {'room_type'}, Gold Columns: {'room_type'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Private room in rental unit", "columns_used": ["property_type"]}
#
# Question: What property type has the most listings?
# Pred Answer: Private room in rental unit, Gold Answer: Private room in rental unit
# Pred Columns: {'property_type'}, Gold Columns: {'property_type'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "work_email", "columns_used": ["host_verifications"]}
#
# Question: Which host verification method is the least used?
# Pred Answer: work_email, Gold Answer: [phone]
# Pred Columns: {'host_verifications'}, Gold Columns: {'host_verifications'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Hammersmith and Fulham", "Westminster", "Hackney"], "columns_used": ["neighbourhood_cleansed"]}
#
# Question: List the top 3 neighbourhoods with the most listings.
# Pred Answer: {'Westminster', 'Hackney', 'Hammersmith and Fulham'}, Gold Answer: {'Westminster', 'Hackney', 'Hammersmith and Fulham'}
# Pred Columns: {'neighbourhood_cleansed'}, Gold Columns: {'neighbourhood_cleansed'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Private room in rental unit", "Entire home/apt", "Entire rental unit", "Private room in home"], "columns_used": ["property_type"]}
#
# Question: Which are the top 4 most common property types?
# Pred Answer: {'Private room in rental unit', 'Entire rental unit', 'Entire home/apt', 'Private room in home'}, Gold Answer: {'Private room in rental unit', 'Entire rental unit', 'Entire home', 'Private room in home'}
# Pred Columns: {'property_type'}, Gold Columns: {'property_type'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": ["email", "phone"],
# "columns_used": ["host_verifications"]
# }
#
# Question: List the 2 most common host verification methods.
# Pred Answer: {'phone', 'email'}, Gold Answer: {'phone', 'email'}
# Pred Columns: {'host_verifications'}, Gold Columns: {'host_verifications'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Private room", "Entire home/apt"], "columns_used": ["room_type"]}
#
# Question: Which are the 2 most preferred room types?
# Pred Answer: {'Entire home/apt', 'Private room'}, Gold Answer: {'Entire home/apt', 'Private room'}
# Pred Columns: {'room_type'}, Gold Columns: {'room_type'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [5.0, 5.0, 4.95], "columns_used": ["review_scores_location"]}
#
# Question: What are the top 3 highest review scores for location?
# Pred Answer: {4.95, 5.0}, Gold Answer: {4.89, 4.0, 5.0}
# Pred Columns: {'review_scores_location'}, Gold Columns: {'review_scores_location'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1.0, 2.0, 3.0], "columns_used": ["bedrooms"]}
#
# Question: What are the 4 most common number of bedrooms in properties?
# Pred Answer: {1.0, 2.0, 3.0}, Gold Answer: {1.0, 2.0, 3.0}
# Pred Columns: {'bedrooms'}, Gold Columns: {'bedrooms'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [260, 92, 11, 3, 1], "columns_used": ["calculated_host_listings_count_entire_homes", "property_type"]}
#
# Question: What are the 5 highest counts of listings by a single host for entire homes?
# Pred Answer: {1.0, 3.0, 260.0, 11.0, 92.0}, Gold Answer: {1.0}
# Pred Columns: {'calculated_host_listings_count_entire_homes', 'property_type'}, Gold Columns: {'calculated_host_listings_count_entire_homes'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [4.0, 4.0, 4.0, 4.2, 4.4, 4.5], "columns_used": ["review_scores_communication"]}
#
# Question: List the 6 lowest review scores for communication.
# Pred Answer: {4.5, 4.0, 4.2, 4.4}, Gold Answer: {4.95, 4.5, 4.75, 4.4, 4.89, 4.94}
# Pred Columns: {'review_scores_communication'}, Gold Columns: {'review_scores_communication'}
#
# === Answer Accuracy by Type ===
# boolean        : 100.00% (4/4)
# number         : 75.00% (3/4)
# category       : 75.00% (3/4)
# list[category] : 75.00% (3/4)
# list[number]   : 25.00% (1/4)
#
# === Column Selection Accuracy ===
# 85.00% (17/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 007_Fifa ###
# # Questions in 007_Fifa: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["Overall", "Potential"]}
#
# Question: Are there players who have a greater overall score than their potential score?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Potential', 'Overall'}, Gold Columns: {'Potential', 'Overall'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Age", "Joined"]}
#
# Question: Are there any players who joined their current club before they were 18 years old?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Age', 'Joined'}, Gold Columns: {'Joined', 'Age'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["Preferred Foot", "Nationality"]}
#
# Question: Are there any players whose preferred foot is left and are from a nationality that starts with 'B'?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Nationality', 'Preferred Foot'}, Gold Columns: {'Nationality', 'Preferred Foot'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Height_ft", "Agility"]}
#
# Question: Are there any players who are taller than 6 feet and have an agility score above 90?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'Agility', 'Height_ft'}, Gold Columns: {'Agility', 'Height_ft'}
#
# --- Query 5/20 ---
# normalize_answer error for type 'number': Expected numeric type for number, got: <class 'NoneType'>
#
# --- Raw LLM Response ---
# {"answer": None, "columns_used": ["Nationality", "Overall"]}
# normalize_answer error for type 'number': Expected numeric type for number, got: <class 'NoneType'>
#
# Question: What is the average overall score of players from France?
# Pred Answer: None, Gold Answer: None
# Pred Columns: {'Nationality', 'Overall'}, Gold Columns: {'Nationality', 'Overall'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 21, "columns_used": ["Club"]}
#
# Question: How many unique clubs are there in the dataset?
# Pred Answer: 21.0, Gold Answer: 19.0
# Pred Columns: {'Club'}, Gold Columns: {'Club'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 13500000, "columns_used": ["Value_€"]}
#
# Question: What is the highest value (in €) of a player in the dataset?
# Pred Answer: 13500000.0, Gold Answer: 13500000.0
# Pred Columns: {'Value_€'}, Gold Columns: {'Value_€'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 1, "columns_used": ["Position"]}
#
# Question: How many players have the position 'ST'?
# Pred Answer: 1.0, Gold Answer: 1.0
# Pred Columns: {'Position'}, Gold Columns: {'Position'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Ghana", "columns_used": ["Nationality"]}
#
# Question: What is the most common nationality in the dataset?
# Pred Answer: Ghana, Gold Answer: Ghana
# Pred Columns: {'Nationality'}, Gold Columns: {'Nationality'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Right", "columns_used": ["Preferred Foot"]}
#
# Question: What is the most common preferred foot amongst players?
# Pred Answer: Right, Gold Answer: Right
# Pred Columns: {'Preferred Foot'}, Gold Columns: {'Preferred Foot'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "Lech Poznań", "columns_used": ["Club"]}
#
# Question: Which club has the most players in the dataset?
# Pred Answer: Lech Poznań, Gold Answer: Lech Poznań
# Pred Columns: {'Club'}, Gold Columns: {'Club'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "SUB", "columns_used": ["Position"]}
#
# Question: What is the most common position of players in the dataset?
# Pred Answer: SUB, Gold Answer: SUB
# Pred Columns: {'Position'}, Gold Columns: {'Position'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Brazil", "Germany", "Spain", "Ivory Coast", "Portugal"], "columns_used": ["Nationality", "Overall"]}
#
# Question: Which are the top 5 nationalities in terms of the average overall score of their players?
# Pred Answer: {'Ivory Coast', 'Portugal', 'Germany', 'Brazil', 'Spain'}, Gold Answer: {'Ivory Coast', 'Ghana', 'Portugal', 'United States', 'Brazil'}
# Pred Columns: {'Nationality', 'Overall'}, Gold Columns: {'Nationality', 'Overall'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Sassuolo", "Sporting CP", "Hannover 96"], "columns_used": ["Club", "Value_€"]}
#
# Question: Which are the top 3 clubs in terms of the total value (in €) of their players?
# Pred Answer: {'Sassuolo', 'Sporting CP', 'Hannover 96'}, Gold Answer: {'Atalanta', 'Sassuolo', 'DC United'}
# Pred Columns: {'Club', 'Value_€'}, Gold Columns: {'Club', 'Value_€'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Guyana", "Uruguay", "Luxembourg", "Saudi Arabia"], "columns_used": ["Nationality", "Agility"]}
#
# Question: Which are the bottom 4 nationalities in terms of the average agility of their players?
# Pred Answer: {'Luxembourg', 'Uruguay', 'Guyana', 'Saudi Arabia'}, Gold Answer: {'Poland', 'Guyana', 'Saudi Arabia', 'United States'}
# Pred Columns: {'Nationality', 'Agility'}, Gold Columns: {'Nationality', 'Agility'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Sassuolo", "Hellas Verona", "Sporting CP", "Atalanta", "Hannover 96", "Inter"], "columns_used": ["Club", "Potential"]}
#
# Question: Which are the top 6 clubs in terms of the average potential score of their players?
# Pred Answer: {'Hellas Verona', 'Sporting CP', 'Hannover 96', 'Atalanta', 'Inter', 'Sassuolo'}, Gold Answer: {'Sporting CP', 'Atalanta', 'Inter', '1. FSV Mainz 05', 'Sassuolo', 'DC United'}
# Pred Columns: {'Potential', 'Club'}, Gold Columns: {'Potential', 'Club'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [79, 77, 77], "columns_used": ["Overall"]]}
# [process_response] Failed to parse response for question: What are the top 3 overall scores in the dataset?
# Error: closing parenthesis ']' does not match opening parenthesis '{' (<unknown>, line 1)
#
# Question: What are the top 3 overall scores in the dataset?
# Pred Answer: None, Gold Answer: {77.0, 79.0}
# Pred Columns: [], Gold Columns: {'Overall'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [60, 65, 66, 67, 68], "columns_used": ["Potential"]}
#
# Question: What are the bottom 5 potential scores in the dataset?
# Pred Answer: {65.0, 66.0, 67.0, 68.0, 60.0}, Gold Answer: {65.0, 66.0, 67.0, 68.0, 60.0}
# Pred Columns: {'Potential'}, Gold Columns: {'Potential'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [13500000, 5500000, 3800000, 3300000], "columns_used": ["Value_€"]}
#
# Question: What are the top 4 values (in €) of players in the dataset?
# Pred Answer: {13500000.0, 5500000.0, 3300000.0, 3800000.0}, Gold Answer: {13500000.0, 5500000.0, 7500000.0}
# Pred Columns: {'Value_€'}, Gold Columns: {'Value_€'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [29000, 47000], "columns_used": ["Wage_€"]}
#
# Question: What are the top 2 wages (in €) of players in the dataset?
# Pred Answer: {29000.0, 47000.0}, Gold Answer: {47000.0, 29000.0}
# Pred Columns: {'Wage_€'}, Gold Columns: {'Wage_€'}
#
# === Answer Accuracy by Type ===
# boolean        : 75.00% (3/4)
# number         : 50.00% (2/4)
# category       : 100.00% (4/4)
# list[category] : 0.00% (0/4)
# list[number]   : 50.00% (2/4)
#
# === Column Selection Accuracy ===
# 95.00% (19/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 008_Tornados ###
# # Questions in 008_Tornados: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["inj"]}
#
# Question: There are no tornadoes that resulted in more than 500 injuries.
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'inj'}, Gold Columns: {'inj'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["yr"]}
#
# Question: All tornadoes in the dataset occurred in the 21st century.
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'yr'}, Gold Columns: {'yr'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["len"]}
#
# Question: No tornado has a length greater than 100 miles.
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'len'}, Gold Columns: {'len'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["fat"]}
#
# Question: There are no tornadoes that resulted in more than 100 fatalities.
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'fat'}, Gold Columns: {'fat'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 12, "columns_used": ["st"]}
#
# Question: How many unique states are represented in the dataset?
# Pred Answer: 12.0, Gold Answer: 12.0
# Pred Columns: {'st'}, Gold Columns: {'st'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 2, "columns_used": ["mag"]}
#
# Question: What is the highest magnitude of tornado recorded in the dataset?
# Pred Answer: 2.0, Gold Answer: 2.0
# Pred Columns: {'mag'}, Gold Columns: {'mag'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 72.2, "columns_used": ["len"]}
#
# Question: What is the longest length of a tornado path in the dataset?
# Pred Answer: 72.2, Gold Answer: 72.2
# Pred Columns: {'len'}, Gold Columns: {'len'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3, "columns_used": ["inj"]}
#
# Question: What is the maximum number of injuries caused by a single tornado?
# Pred Answer: 3.0, Gold Answer: 3.0
# Pred Columns: {'inj'}, Gold Columns: {'inj'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "IL", "columns_used": ["st"]}
#
# Question: Which state has experienced the most tornadoes?
# Pred Answer: IL, Gold Answer: IL
# Pred Columns: {'st'}, Gold Columns: {'st'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["mo"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: In which month do most tornadoes occur?
# Pred Answer: None, Gold Answer: 6
# Pred Columns: {'mo'}, Gold Columns: {'mo'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "1973-03-15", "columns_used": ["date", "inj"]}
#
# Question: On what date did the most destructive tornado (by injuries) occur?
# Pred Answer: 1973-03-15, Gold Answer: 1973-03-15
# Pred Columns: {'inj', 'date'}, Gold Columns: {'inj', 'date'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "1955-06-04", "columns_used": ["date", "len"]}
#
# Question: On what date did the longest tornado (by path length) occur?
# Pred Answer: 1955-06-04, Gold Answer: 1955-06-04
# Pred Columns: {'date', 'len'}, Gold Columns: {'date', 'len'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["KS", "GA", "IL", "TX", "TN"], "columns_used": ["st", "mag"]}
#
# Question: Which are the top 5 states with the highest average tornado magnitude?
# Pred Answer: {'GA', 'IL', 'TX', 'KS', 'TN'}, Gold Answer: {'GA', 'IN', 'OK', 'TX', 'TN'}
# Pred Columns: {'mag', 'st'}, Gold Columns: {'mag', 'st'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["IL", "TX"], "columns_used": ["st", "inj"]}
#
# Question: Which are the top 2 states with the most tornado-related injuries? If in a tie then select alphabetically.
# Pred Answer: {'IL', 'TX'}, Gold Answer: {'TN', 'IL'}
# Pred Columns: {'inj', 'st'}, Gold Columns: {'inj', 'st'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["GA", "IL", "IN", "KS"], "columns_used": ["st", "fat"]}
#
# Question: Which are the top 4 states with the most tornado-related fatalities? If you find a tie select alphabetically.
# Pred Answer: {'IN', 'GA', 'IL', 'KS'}, Gold Answer: {'TN', 'GA', 'AR', 'FL'}
# Pred Columns: {'fat', 'st'}, Gold Columns: {'fat', 'st'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["WY", "MO"], "columns_used": ["st", "len"]}
#
# Question: Which are the bottom 2 states in terms of the average tornado path length?
# Pred Answer: {'MO', 'WY'}, Gold Answer: {'TN', 'WY'}
# Pred Columns: {'len', 'st'}, Gold Columns: {'len', 'st'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# { "answer": [3, 0, 0], "columns_used": ["inj"] }
#
# Question: What are the top 3 number of injuries caused by tornadoes in the dataset?
# Pred Answer: {0.0, 3.0}, Gold Answer: {0.0, 1.0, 3.0}
# Pred Columns: {'inj'}, Gold Columns: {'inj'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [2, 1, 1, 1, 1], "columns_used": ["mag"]}
#
# Question: What are the top 5 magnitudes of tornadoes in the dataset?
# Pred Answer: {1.0, 2.0}, Gold Answer: {1.0, 2.0}
# Pred Columns: {'mag'}, Gold Columns: {'mag'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [72.2, 4.7, 4.3, 3.2], "columns_used": ["len"]]}
# [process_response] Failed to parse response for question: What are the top 4 path lengths of tornadoes in the dataset?
# Error: closing parenthesis ']' does not match opening parenthesis '{' (<unknown>, line 1)
#
# Question: What are the top 4 path lengths of tornadoes in the dataset?
# Pred Answer: None, Gold Answer: {72.2, 3.2, 4.7, 4.3}
# Pred Columns: [], Gold Columns: {'len'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1, 0, 0, 0, 0, 0], "columns_used": ["fat"]}
#
# Question: What are the top 6 number of fatalities caused by tornadoes in the dataset?
# Pred Answer: {0.0, 1.0}, Gold Answer: {0.0, 1.0}
# Pred Columns: {'fat'}, Gold Columns: {'fat'}
#
# === Answer Accuracy by Type ===
# boolean        : 100.00% (4/4)
# number         : 100.00% (4/4)
# category       : 75.00% (3/4)
# list[category] : 0.00% (0/4)
# list[number]   : 50.00% (2/4)
#
# === Column Selection Accuracy ===
# 95.00% (19/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 009_Central ###
# # Questions in 009_Central: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["PRCP"]}
#
# Question: There were no days when the precipitation was greater than 5 inches.
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'PRCP'}, Gold Columns: {'PRCP'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["TMIN"]}
#
# Question: All recorded temperatures are above freezing point.
# Pred Answer: False, Gold Answer: False
# ...
# {"answer": ["WikipediaLiveMonitor", "ESFL", "Alberto Perdomo"], "columns_used": ["y", "name"]}
#
# Question: What are the bottom 3 entities in terms of y-coordinates?
# Pred Answer: {'ESFL', 'WikipediaLiveMonitor', 'Alberto Perdomo'}, Gold Answer: {'ESFL', 'WikipediaLiveMonitor', 'Alberto Perdomo'}
# Pred Columns: {'y', 'name'}, Gold Columns: {'y', 'name'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [527, 498, 43941, 91203, 411], "columns_used": ["id", "weight"]}
#
# Question: What are the top 5 entity IDs in terms of weight?
# Pred Answer: {91203.0, 43941.0, 527.0, 498.0, 411.0}, Gold Answer: {91203.0, 527.0, 498.0, 411.0, 8031.0}
# Pred Columns: {'weight', 'id'}, Gold Columns: {'weight', 'id'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [181, 267, 35046, 35070], "columns_used": ["id", "page_rank_norm"]}
#
# Question: What are the bottom 4 entity IDs in terms of page rank norm?
# Pred Answer: {35070.0, 267.0, 181.0, 35046.0}, Gold Answer: {35046.0, 35106.0, 35070.0, 35054.0}
# Pred Columns: {'page_rank_norm', 'id'}, Gold Columns: {'page_rank_norm', 'id'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {
# "answer": [0.4905835057931528, 0.2858285808469396, 0.2194061763508274, 0.2171608658929857, 0.1213462154304343, 0.1023296876109954],
# "columns_used": ["page_rank_norm"]
# }
#
# Question: What are the top 6 page rank norms of the entities?
# Pred Answer: {0.4905835057931528, 0.1213462154304343, 0.2194061763508274, 0.2858285808469396, 0.2171608658929857, 0.1023296876109954}, Gold Answer: {0.4905835057931528, 0.1213462154304343, 0.2194061763508274, 0.2858285808469396, 0.2171608658929857, 0.1023296876109954}
# Pred Columns: {'page_rank_norm'}, Gold Columns: {'page_rank_norm'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [3.0, 5.0, 7.0], "columns_used": ["weight"]}
#
# Question: What are the bottom 3 weights of the entities?
# Pred Answer: {3.0, 5.0, 7.0}, Gold Answer: {3.0, 5.0, 7.0}
# Pred Columns: {'weight'}, Gold Columns: {'weight'}
#
# === Answer Accuracy by Type ===
# boolean        : 100.00% (4/4)
# number         : 25.00% (1/4)
# category       : 50.00% (2/4)
# list[category] : 50.00% (2/4)
# list[number]   : 50.00% (2/4)
#
# === Column Selection Accuracy ===
# 95.00% (19/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 064_Clustering ###
# # Questions in 064_Clustering: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["feathers", "animal_name"]}
#
# Question: Are there any animals with feathers in the dataset?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'animal_name', 'feathers'}, Gold Columns: {'feathers'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["venomous"]}
#
# Question: Are there any venomous animals in the dataset?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'venomous'}, Gold Columns: {'venomous'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["breathes"]}
#
# Question: Do all animals breathe?
# Pred Answer: True, Gold Answer: False
# Pred Columns: {'breathes'}, Gold Columns: {'breathes'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["domestic"]}
#
# Question: Are there any domesticated animals in the dataset?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'domestic'}, Gold Columns: {'domestic'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 19, "columns_used": ["animal_name"]}
#
# Question: How many unique types of animals are there?
# Pred Answer: 19.0, Gold Answer: 4.0
# Pred Columns: {'animal_name'}, Gold Columns: {'class_type'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 2.75, "columns_used": ["legs"]}
#
# Question: What is the average number of legs?
# Pred Answer: 2.75, Gold Answer: 3.1
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["legs"]}
#
# Question: What is the maximum number of legs an animal has?
# Pred Answer: 6.0, Gold Answer: 6.0
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 4, "columns_used": ["legs"]}
#
# Question: How many animals are there with 2 legs?
# Pred Answer: 4.0, Gold Answer: 4.0
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": 1, "columns_used": ["class_type"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: What is the most common class type?
# Pred Answer: None, Gold Answer: 1
# Pred Columns: {'class_type'}, Gold Columns: {'class_type'}
#
# --- Query 10/20 ---
# normalize_answer error for type 'category': Expected string for category, got: <class 'NoneType'>
#
# --- Raw LLM Response ---
# {"answer": null, "columns_used": ["legs", "animal_name"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'NoneType'>
#
# Question: What is the name of the first animal with 8 legs?
# Pred Answer: None, Gold Answer: None
# Pred Columns: {'animal_name', 'legs'}, Gold Columns: {'animal_name', 'legs'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": 6, "columns_used": ["legs", "class_type"]}
# normalize_answer error for type 'category': Expected string for category, got: <class 'int'>
#
# Question: What is the class type of the animals with the most legs?
# Pred Answer: None, Gold Answer: 6
# Pred Columns: {'legs', 'class_type'}, Gold Columns: {'legs', 'class_type'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "honeybee", "columns_used": ["animal_name", "venomous"]}
#
# Question: What is the name of the first animal in the dataset that is venomous?
# Pred Answer: honeybee, Gold Answer: honeybee
# Pred Columns: {'animal_name', 'venomous'}, Gold Columns: {'animal_name', 'venomous'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["honeybee", "gnat", "wasp"], "columns_used": ["animal_name", "legs"]}
#
# Question: What are the top 3 animal names with the most legs? If there are more than two with the lowest number go with alphabetical order
# Pred Answer: {'gnat', 'honeybee', 'wasp'}, Gold Answer: {'gnat', 'honeybee', 'wasp'}
# Pred Columns: {'animal_name', 'legs'}, Gold Columns: {'animal_name', 'legs'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["dogfish", "porpoise"], "columns_used": ["legs", "animal_name"]}
#
# Question: What are the bottom 2 animal names in terms of the number of legs? If there are more than two with the lowest number go with alphabetical order
# Pred Answer: {'dogfish', 'porpoise'}, Gold Answer: {'porpoise', 'dogfish'}
# Pred Columns: {'animal_name', 'legs'}, Gold Columns: {'animal_name', 'legs'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1, 6, 1, 4], "columns_used": ["class_type", "animal_name"]}
#
# Question: What are the most common 4 class types with the most animals?
# Pred Answer: {'1', '4', '6'}, Gold Answer: {'1', '4', '2', '6'}
# Pred Columns: {'animal_name', 'class_type'}, Gold Columns: {'class_type'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": [4, 7, 2], "columns_used": ["class_type"]}
#
# Question: What are the least common 3 class types with the least animals?
# Pred Answer: {'4', '2', '7'}, Gold Answer: {'4', '2', '7'}
# Pred Columns: {'class_type'}, Gold Columns: {'class_type'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1, 6, 1, 1, 1], "columns_used": ["class_type", "legs"]}
#
# Question: What are the most common 5 class types with the most combined total legs?
# Pred Answer: {1.0, 6.0}, Gold Answer: {1.0, 2.0, 4.0, 6.0, 7.0}
# Pred Columns: {'legs', 'class_type'}, Gold Columns: {'legs', 'class_type'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": [7, 4, 2, 6], "columns_used": ["class_type", "legs"]}
#
# Question: What are the bottom 4 class types with the least combined total legs?
# Pred Answer: {2.0, 4.0, 6.0, 7.0}, Gold Answer: {2.0, 4.0, 6.0, 7.0}
# Pred Columns: {'legs', 'class_type'}, Gold Columns: {'legs', 'class_type'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [4, 2", 0, 6], "columns_used": ["legs"]}
# [process_response] Failed to parse response for question: What are the most common 4 numbers of legs that animals have?
# Error: unterminated string literal (detected at line 1) (<unknown>, line 1)
#
# Question: What are the most common 4 numbers of legs that animals have?
# Pred Answer: None, Gold Answer: {0.0, 2.0, 4.0, 6.0}
# Pred Columns: [], Gold Columns: {'legs'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [0, 2, 6], "columns_used": ["legs"]}
#
# Question: What are the least common 3 numbers of legs that animals have?
# Pred Answer: {0.0, 2.0, 6.0}, Gold Answer: {0.0, 2.0, 6.0}
# Pred Columns: {'legs'}, Gold Columns: {'legs'}
#
# === Answer Accuracy by Type ===
# boolean        : 75.00% (3/4)
# number         : 50.00% (2/4)
# category       : 50.00% (2/4)
# list[category] : 75.00% (3/4)
# list[number]   : 50.00% (2/4)
#
# === Column Selection Accuracy ===
# 80.00% (16/20)
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Evaluating 065_RFM ###
# # Questions in 065_RFM: 20
#
# --- Query 1/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["Quantity"]}
#
# Question: Are all the quantities greater than 0?
# Pred Answer: False, Gold Answer: False
# Pred Columns: {'Quantity'}, Gold Columns: {'Quantity'}
#
# --- Query 2/20 ---
#
# --- Raw LLM Response ---
# {"answer": TRUE, "columns_used": ["UnitPrice"]}
# [process_response] Failed to parse response for question: Are all the unit prices greater than 0?
# Error: malformed node or string on line 1: <ast.Name object at 0x7aeb53243280>
#
# Question: Are all the unit prices greater than 0?
# Pred Answer: None, Gold Answer: True
# Pred Columns: [], Gold Columns: {'UnitPrice'}
#
# --- Query 3/20 ---
#
# --- Raw LLM Response ---
# {"answer": False, "columns_used": ["CustomerID"]}
#
# Question: Are there any missing customer IDs?
# Pred Answer: False, Gold Answer: True
# Pred Columns: {'CustomerID'}, Gold Columns: {'CustomerID'}
#
# --- Query 4/20 ---
#
# --- Raw LLM Response ---
# {"answer": True, "columns_used": ["Country"]}
#
# Question: Are there any transactions from the United Kingdom?
# Pred Answer: True, Gold Answer: True
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 5/20 ---
#
# --- Raw LLM Response ---
# {"answer": 24, "columns_used": ["StockCode"]}
#
# Question: How many unique stock codes are there?
# Pred Answer: 24.0, Gold Answer: 20.0
# Pred Columns: {'StockCode'}, Gold Columns: {'StockCode'}
#
# --- Query 6/20 ---
#
# --- Raw LLM Response ---
# {"answer": 3.3846153846153846, "columns_used": ["UnitPrice"]}
#
# Question: What is the average unit price?
# Pred Answer: 3.3846153846153846, Gold Answer: 3.5415
# Pred Columns: {'UnitPrice'}, Gold Columns: {'UnitPrice'}
#
# --- Query 7/20 ---
#
# --- Raw LLM Response ---
# {"answer": 24, "columns_used": ["Quantity"]}
#
# Question: What is the maximum quantity ordered in a single transaction?
# Pred Answer: 24.0, Gold Answer: 25.0
# Pred Columns: {'Quantity'}, Gold Columns: {'Quantity'}
#
# --- Query 8/20 ---
#
# --- Raw LLM Response ---
# {"answer": 24, "columns_used": ["Country"]}
#
# Question: How many transactions were made in the United Kingdom?
# Pred Answer: 24.0, Gold Answer: 19.0
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 9/20 ---
#
# --- Raw LLM Response ---
# {"answer": "United Kingdom", "columns_used": ["Country"]}
#
# Question: Which country made the most transactions?
# Pred Answer: United Kingdom, Gold Answer: United Kingdom
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 10/20 ---
#
# --- Raw LLM Response ---
# {"answer": "SWEETHEART WIRE FRUIT BOWL", "columns_used": ["Description", "UnitPrice"]}
#
# Question: What is the description of the item with the highest unit price?
# Pred Answer: SWEETHEART WIRE FRUIT BOWL, Gold Answer: RETROSPOT LAMP
# Pred Columns: {'UnitPrice', 'Description'}, Gold Columns: {'UnitPrice', 'Description'}
#
# --- Query 11/20 ---
#
# --- Raw LLM Response ---
# {"answer": "BLUE POLKADOT WRAP", "columns_used": ["Quantity", "Description"]}
#
# Question: What is the description of the item with the highest quantity ordered?
# Pred Answer: BLUE POLKADOT WRAP, Gold Answer: BLUE POLKADOT WRAP
# Pred Columns: {'Description', 'Quantity'}, Gold Columns: {'Description', 'Quantity'}
#
# --- Query 12/20 ---
#
# --- Raw LLM Response ---
# {"answer": "United Kingdom", "columns_used": ["Country", "CustomerID"]}
#
# Question: Which country does the customer with the lowest ID come from?
# Pred Answer: United Kingdom, Gold Answer: Australia
# Pred Columns: {'CustomerID', 'Country'}, Gold Columns: {'CustomerID', 'Country'}
#
# --- Query 13/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["BLUE POLKADOT WRAP", "HANGING JAM JAR T-LIGHT HOLDER", "CHRISTMAS STAR WISH LIST CHALKBOARD"], "columns_used": ["Description", "Quantity"]}
#
# Question: What are the descriptions of the 3 items with the highest quantities ordered?
# Pred Answer: {'BLUE POLKADOT WRAP', 'CHRISTMAS STAR WISH LIST CHALKBOARD', 'HANGING JAM JAR T-LIGHT HOLDER'}, Gold Answer: {'BLUE POLKADOT WRAP', 'FAIRY CAKE FLANNEL ASSORTED COLOUR', 'HANGING JAM JAR T-LIGHT HOLDER'}
# Pred Columns: {'Description', 'Quantity'}, Gold Columns: {'Description', 'Quantity'}
#
# --- Query 14/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["LARGE CAKE TOWEL CHOCOLATE SPOTS", "WOOD BLACK BOARD ANT WHITE FINISH"], "columns_used": ["Description", "Quantity"]}
#
# Question: What are the descriptions of the 2 items with the lowest quantities ordered? If there is a tie then solve it with the alphabetical order of descriptions.
# Pred Answer: {'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE CAKE TOWEL CHOCOLATE SPOTS'}, Gold Answer: {'LARGE CAKE TOWEL CHOCOLATE SPOTS', 'HANGING METAL STAR LANTERN'}
# Pred Columns: {'Description', 'Quantity'}, Gold Columns: {'Description', 'Quantity'}
#
# --- Query 15/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["United Kingdom", "Australia"], "columns_used": ["Country"]}
#
# Question: Which 2 countries made the most transactions?
# Pred Answer: {'United Kingdom', 'Australia'}, Gold Answer: {'United Kingdom', 'Australia'}
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 16/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["Australia"], "columns_used": ["Country"]}
#
# Question: Which 2 countries made the least transactions?
# Pred Answer: {'Australia'}, Gold Answer: {'United Kingdom', 'Australia'}
# Pred Columns: {'Country'}, Gold Columns: {'Country'}
#
# --- Query 17/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["548005", "573399", "568909", "577076", "555200"], "columns_used": ["InvoiceNo", "Quantity"]}
#
# Question: What are the invoice numbers of the top 5 transactions with the highest quantities ordered?
# Pred Answer: {555200.0, 548005.0, 568909.0, 577076.0, 573399.0}, Gold Answer: {555200.0, 563745.0, 548005.0, 568909.0, 573399.0}
# Pred Columns: {'Quantity', 'InvoiceNo'}, Gold Columns: {'Quantity', 'InvoiceNo'}
#
# --- Query 18/20 ---
#
# --- Raw LLM Response ---
# {"answer": ["82484", "21109", "82600", "22465", "22180"], "columns_used": ["Quantity", "StockCode"]}
#
# Question: What are the stock codes of the bottom 5 transactions with the lowest quantities ordered? If there is a tie go with numerical order.
# Pred Answer: {22465.0, 22180.0, 82600.0, 82484.0, 21109.0}, Gold Answer: {22465.0, 82600.0, 22799.0, 82484.0, 21109.0}
# Pred Columns: {'StockCode', 'Quantity'}, Gold Columns: {'Quantity', 'InvoiceNo'}
#
# --- Query 19/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1, 2, 4, 12], "columns_used": ["Quantity"]}
#
# Question: What are the four most commonly ordered quantities?
# Pred Answer: {1.0, 2.0, 4.0, 12.0}, Gold Answer: {1.0, 2.0, 4.0, 12.0}
# Pred Columns: {'Quantity'}, Gold Columns: {'Quantity'}
#
# --- Query 20/20 ---
#
# --- Raw LLM Response ---
# {"answer": [1, 1], "columns_used": ["Description", "Quantity"]}
#
# Question: What are the times the two most common descriptions are repeated?
# Pred Answer: {1.0}, Gold Answer: {1.0}
# Pred Columns: {'Description', 'Quantity'}, Gold Columns: {'Description'}
#
# === Answer Accuracy by Type ===
# boolean        : 50.00% (2/4)
# number         : 0.00% (0/4)
# category       : 50.00% (2/4)
# list[category] : 25.00% (1/4)
# list[number]   : 50.00% (2/4)
#
# === Column Selection Accuracy ===
# 85.00% (17/20)

# %%
# # Table 1: Main Metrics Table
# results_df = pd.DataFrame(model_results).T.round(3)
# print("### Main Metrics Table:")
# print(results_df.to_markdown())

# # Table 2: Column Quality Table
# col_df = pd.DataFrame(column_quality_table)
# print("\n### Column Quality Table:")
# print(col_df.to_markdown(index=False))

# # Table 3: Formatting Errors by Type
# print("\n### Formatting Errors by Question Type:")
# for qtype, count in formatting_errors_summary.items():
#     print(f"{qtype:15}: {count} formatting errors")

# Table 1: Main Metrics Table (per dataset)
results_df = pd.DataFrame(model_results).T.round(3)
print("### Main Metrics Table:")
print(results_df.to_markdown())

# Table 2: Column Quality Table (per dataset)
col_df = pd.DataFrame(column_quality_table)
print("\n### Column Quality Table:")
print(col_df.to_markdown(index=False))

# Table 3: Formatting Errors by Question Type
print("\n### Formatting Errors by Question Type:")
for qtype, count in formatting_errors_summary.items():
    print(f"{qtype:15}: {count} formatting errors")
# Out:
# ### Main Metrics Table:
# |                   |   avg |   boolean |   number |   category |   list[category] |   list[number] |   single col |   multiple cols |
# |:------------------|------:|----------:|---------:|-----------:|-----------------:|---------------:|-------------:|----------------:|
# | 001_Forbes        |  0.52 |      0.6  |    0.6   |       0.6  |            0.4   |           0.4  |        0.714 |           0.444 |
# | 002_Titanic       |  0.65 |      1    |    0.5   |       0.5  |            0.5   |           0.75 |        0.571 |           0.692 |
# | 004_Taxi          |  0.55 |      0.75 |    0.25  |       0.25 |            0.75  |           0.75 |        0.55  |           0     |
# | 005_NYC           |  0.4  |      1    |    0.25  |       0.5  |            0     |           0.25 |        0.4   |           0     |
# | 006_London        |  0.65 |      1    |    0.5   |       0.75 |            0.75  |           0.25 |        0.65  |           0     |
# | 007_Fifa          |  0.55 |      0.75 |    0.5   |       1    |            0     |           0.5  |        0.727 |           0.333 |
# | 008_Tornados      |  0.65 |      1    |    1     |       0.75 |            0     |           0.5  |        0.786 |           0.333 |
# | 009_Central       |  0.75 |      0.5  |    1     |       0.75 |            0.5   |           1    |        0.909 |           0.556 |
# | 010_ECommerce     |  0.5  |      0.75 |    0.5   |       0.5  |            0.5   |           0.25 |        0.5   |           0     |
# | 011_SF            |  0.5  |      0.75 |    0.5   |       0.5  |            0.5   |           0.25 |        0.417 |           0.625 |
# | 012_Heart         |  0.6  |      1    |    0.5   |       0.75 |            0.5   |           0.25 |        0.625 |           0.5   |
# | 013_Roller        |  0.55 |      0.75 |    0.75  |       0.5  |            0     |           0.75 |        0.889 |           0.273 |
# | 015_Food          |  0.5  |      0.75 |    0.25  |       1    |            0.5   |           0    |        0.4   |           0.8   |
# | 016_Holiday       |  0.6  |      1    |    0.5   |       0.25 |            0.5   |           0.75 |        0.733 |           0.2   |
# | 017_Hacker        |  0.5  |      0.5  |    0.25  |       0.75 |            0.5   |           0.5  |        0.526 |           0     |
# | 018_Staff         |  0.65 |      0.75 |    0.75  |       0.5  |            0.5   |           0.75 |        0.786 |           0.333 |
# | 019_Aircraft      |  0.2  |      0.5  |    0.5   |       0    |            0     |           0    |        0.235 |           0     |
# | 021_Telco         |  0.7  |      0.5  |    0.5   |       0.75 |            0.75  |           1    |        0.75  |           0.5   |
# | 022_Airbnbs       |  0.45 |      0.5  |    0     |       0.75 |            0.25  |           0.75 |        0.421 |           1     |
# | 023_Climate       |  0.4  |      0.75 |    0.25  |       0.25 |            0.25  |           0.5  |        0.5   |           0.357 |
# | 024_Salary        |  0.5  |      1    |    0     |       0.75 |            0.5   |           0.25 |        0.5   |           0.5   |
# | 025_Data          |  0.25 |      0.5  |    0.5   |       0    |            0.25  |           0    |        0.5   |           0.188 |
# | 026_Predicting    |  0.35 |      1    |    0.75  |       0    |            0     |           0    |        0.857 |           0.077 |
# | 027_Supermarket   |  0.7  |      1    |    0.75  |       1    |            0.75  |           0    |        0.833 |           0.643 |
# | 028_Predict       |  0.2  |      0.5  |    0.5   |       0    |            0     |           0    |        0.667 |           0     |
# | 029_NYTimes       |  0.35 |      0.75 |    0.25  |       0.75 |            0     |           0    |        0.444 |           0.273 |
# | 030_Professionals |  0.5  |      0.5  |    0.5   |       1    |            0.167 |           0.5  |        0.526 |           0     |
# | 031_Trustpilot    |  0.5  |      1    |    0.25  |       0.5  |            0.5   |           0.25 |        0.455 |           0.556 |
# | 032_Delicatessen  |  0.65 |      1    |    0.5   |       0.5  |            0.5   |           0.75 |        0.812 |           0     |
# | 033_Employee      |  0.55 |      0.75 |    0.333 |       0.4  |            0.75  |           0.5  |        0.571 |           0.5   |
# | 034_World         |  0.15 |      0.25 |    0     |       0.5  |            0     |           0    |        0     |           0.15  |
# | 036_US            |  0.35 |      1    |    0.25  |       0    |            0     |           0.5  |        0.636 |           0     |
# | 037_Ted           |  0.4  |      1    |    0.25  |       0.5  |            0     |           0.25 |        0.429 |           0.333 |
# | 038_Stroke        |  0.5  |      0.75 |    0.5   |       0.75 |            0.5   |           0    |        0.667 |           0.471 |
# | 039_Happy         |  0.8  |      0.75 |    1     |       1    |            1     |           0.25 |        0.818 |           0.778 |
# | 040_Speed         |  0.5  |      0.5  |    0.75  |       0.25 |            0.5   |           0.5  |        1     |           0.412 |
# | 041_Airline       |  0.7  |      1    |    0.5   |       0.75 |            0.5   |           0.75 |        0.75  |           0.625 |
# | 042_Predict       |  0.5  |      0.5  |    0.5   |       1    |            0.5   |           0    |        0.667 |           0.471 |
# | 043_Predict       |  0.45 |      0.75 |    0.5   |       0.75 |            0     |           0.25 |        0.667 |           0.412 |
# | 044_IMDb          |  0.25 |      0.75 |    0.5   |       0    |            0     |           0    |        0     |           0.25  |
# | 045_Predict       |  0.4  |      0.75 |    0.25  |       0.25 |            0.25  |           0.5  |        0.375 |           0.417 |
# | 046_120           |  0.3  |      0.5  |    0.25  |       0    |            0.25  |           0.5  |        0.333 |           0.25  |
# | 047_Bank          |  0.45 |      0.25 |    0.75  |       0.5  |            0.5   |           0.25 |        0.529 |           0     |
# | 048_Data          |  0.4  |      0.5  |    0.5   |       0.25 |            0.25  |           0.5  |        0.5   |           0     |
# | 050_ING           |  0.45 |      0.75 |    0     |       0.75 |            0.5   |           0.25 |        0.333 |           0.545 |
# | 051_Pokemon       |  0.4  |      1    |    0.25  |       0.75 |            0     |           0    |        0.444 |           0.364 |
# | 052_Professional  |  0.5  |      1    |    0.5   |       0.5  |            0     |           0.5  |        0.429 |           0.538 |
# | 053_Patents       |  0.35 |      0.75 |    0.25  |       0.75 |            0     |           0    |        0.375 |           0.25  |
# | 055_German        |  0.55 |      0.75 |    0.5   |       1    |            0     |           0.5  |        0.667 |           0.375 |
# | 056_Emoji         |  0.6  |      0.75 |    0.75  |       0.75 |            0.25  |           0.5  |        0.667 |           0.5   |
# | 057_Spain         |  0.4  |      0.75 |    0.25  |       0.5  |            0     |           0.5  |        0.421 |           0     |
# | 058_US            |  0.55 |      0.5  |    0     |       1    |            0.75  |           0.5  |        0.588 |           0.333 |
# | 059_Second        |  0.7  |      1    |    0.5   |       1    |            0.75  |           0.25 |        0.684 |           1     |
# | 060_Bakery        |  0.5  |      0.25 |    0.5   |       0.75 |            0.75  |           0.25 |        0.143 |           0.692 |
# | 061_Disneyland    |  0.65 |      0.75 |    0.75  |       0.75 |            0.25  |           0.75 |        0.625 |           0.667 |
# | 062_Trump         |  0.7  |      1    |    0.5   |       0.75 |            0.75  |           0.5  |        0.688 |           0.75  |
# | 063_Influencers   |  0.55 |      1    |    0.25  |       0.5  |            0.5   |           0.5  |        0.636 |           0.444 |
# | 064_Clustering    |  0.55 |      0.5  |    0.5   |       0.5  |            0.75  |           0.5  |        0.462 |           0.714 |
# | 065_RFM           |  0.3  |      0.5  |    0     |       0.5  |            0.25  |           0.25 |        0.385 |           0.143 |
#
# ### Column Quality Table:
# | model             | wrong cols   | right cols   | format error   |
# |:------------------|:-------------|:-------------|:---------------|
# | 001_Forbes        | 12.0 (3)     | 88.0 (22)    | 0.0 (0)        |
# | 002_Titanic       | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 004_Taxi          | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 005_NYC           | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 006_London        | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 007_Fifa          | 0.0 (0)      | 95.0 (19)    | 5.0 (1)        |
# | 008_Tornados      | 0.0 (0)      | 95.0 (19)    | 5.0 (1)        |
# | 009_Central       | 5.0 (1)      | 90.0 (18)    | 5.0 (1)        |
# | 010_ECommerce     | 10.0 (2)     | 85.0 (17)    | 5.0 (1)        |
# | 011_SF            | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 012_Heart         | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 013_Roller        | 15.0 (3)     | 80.0 (16)    | 5.0 (1)        |
# | 015_Food          | 5.0 (1)      | 90.0 (18)    | 5.0 (1)        |
# | 016_Holiday       | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 017_Hacker        | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 018_Staff         | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 019_Aircraft      | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 021_Telco         | 15.0 (3)     | 85.0 (17)    | 0.0 (0)        |
# | 022_Airbnbs       | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 023_Climate       | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 024_Salary        | 10.0 (2)     | 85.0 (17)    | 5.0 (1)        |
# | 025_Data          | 45.0 (9)     | 55.0 (11)    | 0.0 (0)        |
# | 026_Predicting    | 0.0 (0)      | 95.0 (19)    | 5.0 (1)        |
# | 027_Supermarket   | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 028_Predict       | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 029_NYTimes       | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 030_Professionals | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 031_Trustpilot    | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 032_Delicatessen  | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 033_Employee      | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 034_World         | 15.0 (3)     | 75.0 (15)    | 10.0 (2)       |
# | 036_US            | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 037_Ted           | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 038_Stroke        | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 039_Happy         | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 040_Speed         | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 041_Airline       | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 042_Predict       | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 043_Predict       | 0.0 (0)      | 95.0 (19)    | 5.0 (1)        |
# | 044_IMDb          | 35.0 (7)     | 65.0 (13)    | 0.0 (0)        |
# | 045_Predict       | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 046_120           | 30.0 (6)     | 70.0 (14)    | 0.0 (0)        |
# | 047_Bank          | 5.0 (1)      | 85.0 (17)    | 10.0 (2)       |
# | 048_Data          | 20.0 (4)     | 75.0 (15)    | 5.0 (1)        |
# | 050_ING           | 5.0 (1)      | 90.0 (18)    | 5.0 (1)        |
# | 051_Pokemon       | 10.0 (2)     | 90.0 (18)    | 0.0 (0)        |
# | 052_Professional  | 20.0 (4)     | 80.0 (16)    | 0.0 (0)        |
# | 053_Patents       | 30.0 (6)     | 70.0 (14)    | 0.0 (0)        |
# | 055_German        | 0.0 (0)      | 95.0 (19)    | 5.0 (1)        |
# | 056_Emoji         | 5.0 (1)      | 90.0 (18)    | 5.0 (1)        |
# | 057_Spain         | 0.0 (0)      | 95.0 (19)    | 5.0 (1)        |
# | 058_US            | 5.0 (1)      | 90.0 (18)    | 5.0 (1)        |
# | 059_Second        | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 060_Bakery        | 15.0 (3)     | 80.0 (16)    | 5.0 (1)        |
# | 061_Disneyland    | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 062_Trump         | 0.0 (0)      | 100.0 (20)   | 0.0 (0)        |
# | 063_Influencers   | 5.0 (1)      | 95.0 (19)    | 0.0 (0)        |
# | 064_Clustering    | 15.0 (3)     | 80.0 (16)    | 5.0 (1)        |
# | 065_RFM           | 10.0 (2)     | 85.0 (17)    | 5.0 (1)        |
#
# ### Formatting Errors by Question Type:
# list[number]   : 4 formatting errors
# boolean        : 13 formatting errors
# number         : 2 formatting errors
# list[category] : 3 formatting errors

# %%
# Store dataset sizes
dataset_sizes = {dataset_id: len(semeval_train.filter(lambda s: s["dataset"] == dataset_id)) for dataset_id in train_target_datasets}

def compute_weighted_global_metrics(model_results, dataset_sizes):
    weighted_sums = defaultdict(float)
    total_size = sum(dataset_sizes[ds] for ds in model_results if ds != "GLOBAL")

    for dataset_id, metrics in model_results.items():
        if dataset_id == "GLOBAL":
            continue
        weight = dataset_sizes[dataset_id]
        for k, v in metrics.items():
            weighted_sums[k] += v * weight

    return {k: weighted_sums[k] / total_size for k in weighted_sums}

# Compute and store weighted global average
global_model_results = {}
global_model_results["GLOBAL"] = compute_weighted_global_metrics(model_results, dataset_sizes)

# Display as markdown table
global_df = pd.DataFrame(global_model_results).T.round(3)
print("\n### Global Metrics Across All Datasets (Weighted):")
print(global_df.to_markdown())
# Out:
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1185 [00:00<?, ? examples/s]
# ### Global Metrics Across All Datasets (Weighted):
# |        |   avg |   boolean |   number |   category |   list[category] |   list[number] |   single col |   multiple cols |
# |:-------|------:|----------:|---------:|-----------:|-----------------:|---------------:|-------------:|----------------:|
# | GLOBAL | 0.497 |     0.738 |    0.444 |      0.572 |            0.353 |           0.38 |        0.563 |           0.366 |
